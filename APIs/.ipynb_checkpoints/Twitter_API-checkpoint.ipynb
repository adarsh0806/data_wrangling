# %% [markdown]
# ## 1. Search for tweets that have a particular hashtag

# %%
# First, install twitter library - pip install twitter
from twitter import Twitter, OAuth

# Make sure to add the access tokens and consumer keys for your application
# These have been regenerated and are no longer valid.
consumer_key= ''
consumer_secret = ''
access_token_secret = ''
access_token = ''

# Set up Twitter OAuth
t = Twitter(auth=OAuth(access_token, access_token_secret, consumer_key, consumer_secret))

# Search for tweets with #python
pythonTweets = t.search.tweets(q = "#python")

print(pythonTweets)
# Out:
# {u'search_metadata': {u'count': 15, u'completed_in': 0.062, u'max_id_str': u'785615163583967232', u'since_id_str': u'0', u'next_results': u'?max_id=785612123414097919&q=%23python&include_entities=1', u'refresh_url': u'?since_id=785615163583967232&q=%23python&include_entities=1', u'since_id': 0, u'query': u'%23python', u'max_id': 785615163583967232}, u'statuses': [{u'contributors': None, u'truncated': False, u'text': u'Twin Cities #Riak Meetup "Easy Time Series Analysis with Riak TS, #Python and #Pandas" this Thursday details here https://t.co/h6N6cYlORH', u'is_quote_status': False, u'in_reply_to_status_id': None, u'id': 785615163583967232, u'favorite_count': 0, u'entities': {u'symbols': [], u'user_mentions': [], u'hashtags': [{u'indices': [12, 17], u'text': u'Riak'}, {u'indices': [66, 73], u'text': u'Python'}, {u'indices': [78, 85], u'text': u'Pandas'}], u'urls': [{u'url': u'https://t.co/h6N6cYlORH', u'indices': [114, 137], u'expanded_url': u'http://www.meetup.com/Twin-Cities-Riak-Me
# ...

# %% [markdown]
# ## 2. Updating your status on twitter ##

# %%
from twitter import Twitter

#Make sure to add the access tokens and consumer keys for your application
t = Twitter(auth=OAuth(access_token, access_token_secret, consumer_key, consumer_secret))

statusUpdate = t.statuses.update(status= 'Hello, friend2.')

print(statusUpdate)
# Out:
# {u'favorited': False, u'contributors': None, u'truncated': False, u'text': u'Hello, friend2.', u'is_quote_status': False, u'in_reply_to_status_id': None, u'user': {u'follow_request_sent': False, u'has_extended_profile': False, u'profile_use_background_image': False, u'default_profile_image': False, u'id': 44180201, u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme5/bg.gif', u'verified': False, u'profile_text_color': u'000000', u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/783898434495361024/P6rUcC46_normal.jpg', u'profile_sidebar_fill_color': u'000000', u'entities': {u'description': {u'urls': []}}, u'followers_count': 189, u'profile_sidebar_border_color': u'000000', u'id_str': u'44180201', u'profile_background_color': u'000000', u'listed_count': 11, u'is_translation_enabled': False, u'utc_offset': -25200, u'statuses_count': 269, u'description': u"Environmentalist. Data Scientist. Machine Learning Engineer. 'Computer Science is no 
# ...

# %% [markdown]
# ## 3. Retrieving status updates ##

# %%
from twitter import Twitter, OAuth

#Make sure to add the access tokens and consumer keys for your application
t = Twitter(auth=OAuth(access_token, access_token_secret, consumer_key, consumer_secret))

# Retrieve last 5 updates of SFBART
pythonStatuses = t.statuses.user_timeline(screen_name = "SFBART", count=5)

print(pythonStatuses)
# Out:
# [{u'contributors': None, u'truncated': False, u'text': u'RT @lawrenceskm: Whenever I pass by the @SFBART Milpitas construction, I have a wave of happiness hit me.', u'is_quote_status': False, u'in_reply_to_status_id': None, u'id': 785593230490345472, u'favorite_count': 0, u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', u'retweeted': False, u'coordinates': None, u'entities': {u'symbols': [], u'user_mentions': [{u'id': 114990488, u'indices': [3, 15], u'id_str': u'114990488', u'screen_name': u'lawrenceskm', u'name': u'Lawrencium, #103'}, {u'id': 15640533, u'indices': [40, 47], u'id_str': u'15640533', u'screen_name': u'SFBART', u'name': u'SFBART'}], u'hashtags': [], u'urls': []}, u'in_reply_to_screen_name': None, u'in_reply_to_user_id': None, u'retweet_count': 1, u'id_str': u'785593230490345472', u'favorited': False, u'retweeted_status': {u'contributors': None, u'truncated': False, u'text': u'Whenever I pass by the @SFBART Milpitas construction, I have a
# ...
