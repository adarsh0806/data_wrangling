# %% [markdown]
# # Objective: Script to crawl wikipedia, search for revision history pages and then looks for the IP addresses on the revision history pages.

# %%
# Test call to freegeoip.net
import json
from urllib2 import urlopen

def getCountry(ipAddress):
    response = urlopen("http://freegeoip.net/json/" + ipAddress).read().decode('utf-8')
    responseJson = json.loads(response)
    return responseJson.get("country_code")

print(getCountry("50.78.253.58"))
# Out:
# US

# %%
# Test call to understand JSON return calls
import json

jsonString = '{"arrayOfNums":[{"number":0}, \
                              {"number":1}, \
                              {"number":2}], \
              "arrayOfFruits":[{"fruit":"apple"}, \
                               {"fruit":"banana"}, \
                               {"fruit":"pear"}]}'
jsonObj = json.loads(jsonString)

# List of dictionary objects
print(jsonObj.get("arrayOfNums"))

# Dictionary object
print(jsonObj.get("arrayOfNums")[1])

# Integer
print(jsonObj.get("arrayOfNums")[1].get("number") + jsonObj.get("arrayOfNums")[2].get("number"))

# String
print(jsonObj.get("arrayOfFruits")[2].get("fruit"))
# Out:
# [{u'number': 0}, {u'number': 1}, {u'number': 2}]
# {u'number': 1}
# 3
# pear

# %%
'''
Script to crawl wikipedia, search for revision history pages and then looks for the IP addresses on the revision
history pages.

Steps followed:

1. Retrieves the histories of all Wikipdia articles linked to by the starting page -> getLinks()
2. It then selects a new page randomly and retrieves all revision history pages of articles linked to by that page ->
getHistoryIPs()
3. Maps the IP addresses to the countries they are found in using freegeoip API -> getcountry()
3. It will continue until it hits a page with no links.

'''
from urllib2 import urlopen
from urllib2 import HTTPError
from bs4 import BeautifulSoup
import datetime
import json
import random
import re

random.seed(datetime.datetime.now())

# Find all links in the URL fed in.
def getLinks(articleUrl):
    html = urlopen("http://en.wikipedia.org" + articleUrl)
    bsObj = BeautifulSoup(html, "html.parser")
    
    # Find all external links on Wikipedia page
    return bsObj.find("div", {"id":"bodyContent"}).findAll("a", href = re.compile("^(/wiki/)((?!:).)*$"))


# 
def getHistoryIPs(pageUrl):    
    # Format of revision history pages is: 
    # http://en.wikipedia.org/w/index.php?title=Title_in_URL&action=history    
    pageUrl = pageUrl.replace("/wiki/", "")
    historyUrl = "http://en.wikipedia.org/w/index.php?title=" + pageUrl + "&action=history"
    
    print("history url is: " + historyUrl)
    
    html = urlopen(historyUrl)
    bsObj = BeautifulSoup(html, "html.parser")
    
    # Finds only the links with class "mw-anonuserlink" which has IP addresses 
    # instead of usernames
    ipAddresses = bsObj.findAll("a", {"class":"mw-anonuserlink"})
    addressList = set()
    
    # Add ipAddress to list
    for ipAddress in ipAddresses:
        addressList.add(ipAddress.get_text())
    
    return addressList


def getCountry(ipAddress):
    try:
        # Use ipAddress obtained from user that made edit and feed to freegeoip.net API
        response = urlopen("http://freegeoip.net/json/" + ipAddress).read().decode('utf-8')
    
    except HTTPError:
        return None
    
    # Feed lat and long value to responseJson object
    responseJson = json.loads(response)
    
    # Get country code from responseJson object.
    return responseJson.get("country_code")
    

# Starting link
links = getLinks("/wiki/Python_(programming_language)")


while(len(links) > 0):
    for link in links:
        print("-------------------") 
        
        # Get ipAddresses
        historyIPs = getHistoryIPs(link.attrs["href"])
        
        for historyIP in historyIPs:
            country = getCountry(historyIP)
            if country is not None:
                print(historyIP + " is from " + country)

    newLink = links[random.randint(0, len(links)-1)].attrs["href"]
    links = getLinks(newLink)
# Out:
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Python_(genus)&action=history
# 66.61.83.123 is from US
# 76.1.125.190 is from US
# 69.193.219.186 is from US
# 148.88.244.103 is from GB
# 168.212.252.44 is from US
# 206.176.81.232 is from US
# 96.10.134.242 is from US
# 108.192.108.85 is from US
# 197.161.61.73 is from EG
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Python_(disambiguation)&action=history
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Programming_paradigm&action=history
# 216.186.131.29 is from US
# 43.252.233.5 is from MY
# 2607:fb90:5223:c275:0:17:a6be:ca01 is from US
# 162.247.124.52 is from CA
# 68.8.169.121 is from US
# 213.30.118.68 is from PT
# 196.47.102.43 is from NG
# 97.32.131.205 is from US
# 66.87.64.75 is from US
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Multi-paradigm_programming_language&action=history
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Object-oriented_programming&action=history
# 119.157.201.147 is from PK
# 124.217.188.219 is from HK
# 2602:306:ce95:6bb0:d5ce:67e8:51c6:49ef is from US
# 49.126.254.224 is from NP
# 41.136.96.19 is from MU
# 71.163.164.190 is from US
# 36.255.189.18 is from BD
# 176.104.51.69 is from UA
# 202.142.121.131 is from IN
# 94.124.165.9 is from RU
# 14.139.223.167 is from IN
# 107.1.229.152 is from US
# 74.202.112.4 is from US
# 157.139.21.1 is from US
# 117.211.110.69 is from IN
# 117.192.195.87 is from IN
# 182.190.96.145 is from PK
# 124.106.138.94 is from PH
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Imperative_programming&action=history
# 69.127.36.174 is from US
# 15.203.233.84 is from US
# 103.14.125.98 is from IN
# 2601:2:4d00:27b:7189:66f1:1135:7f00 is from US
# 2604:2000:b064:3300:6dd3:b07e:494d:c5cd is from US
# 5.199.208.23 is from RU
# 152.231.35.89 is from NI
# 114.79.32.242 is from ID
# 79.186.27.201 is from PL
# 94.118.222.35 is from GB
# 111.92.130.14 is from PK
# 80.175.63.138 is from GB
# 140.177.205.223 is from US
# 107.107.62.0 is from US
# 176.60.44.112 is from BY
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Functional_programming&action=history
# 2a00:1d40:146e:1:68d9:5c82:30f0:c7e4 is from GB
# 204.48.94.228 is from CA
# 217.91.53.64 is from DE
# 212.252.83.254 is from TR
# 86.61.7.10 is from SI
# 170.12.232.245 is from US
# 77.56.53.183 is from CH
# 99.246.86.48 is from CA
# 14.139.241.210 is from IN
# 104.162.245.137 is from US
# 118.200.185.145 is from SG
# 2602:306:ce6e:9420:9c11:f1e0:b219:bef0 is from US
# 208.71.62.32 is from US
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Procedural_programming&action=history
# 195.132.60.60 is from FR
# 107.1.229.152 is from US
# 198.233.104.154 is from US
# 212.132.0.22 is from GB
# 194.81.178.163 is from GB
# 37.211.33.26 is from QA
# 178.232.15.124 is from NO
# 62.253.69.42 is from GB
# 149.3.140.250 is from GB
# 90.222.80.124 is from GB
# 77.56.53.183 is from CH
# 86.152.129.204 is from GB
# 195.195.250.2 is from GB
# 14.139.234.50 is from IN
# 122.2.113.36 is from PH
# 73.19.237.89 is from US
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Reflective_programming&action=history
# 212.96.25.37 is from MZ
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Software_design&action=history
# 106.70.251.236 is from AU
# 92.107.190.169 is from CH
# 31.61.139.126 is from PL
# 2607:fb90:47:304:66f7:3c96:489d:dcc6 is from US
# 2601:d:7f82:2c20:b501:4a23:160c:3de8 is from US
# 2602:30a:c005:6140:811c:1f14:3cd6:33d6 is from US
# 31.199.173.26 is from IT
# 103.204.119.6 is from IN
# 122.177.225.160 is from IN
# 117.18.231.54 is from BD
# 112.204.234.62 is from PH
# 91.191.207.4 is from AZ
# 121.6.122.250 is from SG
# 37.231.183.161 is from KW
# 39.47.55.196 is from PK
# 142.55.48.19 is from CA
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Guido_van_Rossum&action=history
# 204.14.15.229 is from US
# 87.228.157.89 is from CY
# 117.196.232.127 is from IN
# 2602:306:c43c:8b20:1468:f8e:faca:84a5 is from US
# 67.171.73.105 is from US
# 112.135.69.224 is from LK
# 108.45.29.72 is from US
# 213.160.115.146 is from GB
# 2a02:c7d:9e2a:7800:85c3:9b5:7f8c:a731 is from GB
# 194.53.210.44 is from NL
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Software_developer&action=history
# 82.132.237.51 is from GB
# 123.108.246.165 is from BD
# 106.215.130.35 is from IN
# 212.34.23.18 is from JO
# 2001:56a:75c4:900:6535:d5de:a310:193c is from CA
# 49.201.52.16 is from IN
# 103.245.205.217 is from BD
# 145.102.141.25 is from NL
# 41.222.180.166 is from TZ
# 84.10.111.186 is from PL
# 2405:204:820c:25f8:bccf:65b5:76ca:d6c3 is from IN
# 5.41.243.155 is from SA
# 2602:30a:c029:ca70:9ae:f677:6124:b457 is from US
# 81.182.23.187 is from HU
# 45.127.246.14 is from BD
# 74.114.84.17 is from US
# 37.238.240.46 is from IQ
# 2601:154:8001:ff89:81cd:8994:a916:925c is from US
# 5.41.161.78 is from SA
# 82.229.30.79 is from FR
# 111.118.246.142 is from IN
# 14.195.225.221 is from IN
# 2601:18c:8602:19f0:8031:2d26:66f:c437 is from US
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Python_Software_Foundation&action=history
# 119.15.154.71 is from BD
# 70.198.36.48 is from US
# 194.83.198.199 is from GB
# 50.56.228.68 is from US
# 70.198.33.152 is from US
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Software_release_life_cycle&action=history
# 45.48.185.162 is from US
# 201.166.178.7 is from MX
# 173.35.3.46 is from CA
# 71.8.148.148 is from US
# 197.252.4.85 is from SD
# 50.116.32.213 is from US
# 12.69.60.128 is from US
# 109.166.136.138 is from RO
# 2607:fb90:42:946c:65ec:397a:98a:5608 is from US
# 1.39.38.191 is from IN
# 73.158.171.36 is from US
# 31.53.95.254 is from GB
# 190.9.193.97 is from CO
# 111.95.134.233 is from ID
# 192.100.72.2 is from US
# 2405:204:3003:f815:e142:e1a8:c7fe:f818 is from IN
# 131.111.27.50 is from GB
# 106.219.11.230 is from IN
# 170.163.100.203 is from US
# 2a02:c7d:bb84:a00:640b:9acf:1a76:bbe9 is from GB
# 72.201.249.127 is from US
# 62.255.48.34 is from GB
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Software_release_life_cycle&action=history
# 45.48.185.162 is from US
# 201.166.178.7 is from MX
# 173.35.3.46 is from CA
# 71.8.148.148 is from US
# 197.252.4.85 is from SD
# 50.116.32.213 is from US
# 12.69.60.128 is from US
# 109.166.136.138 is from RO
# 2607:fb90:42:946c:65ec:397a:98a:5608 is from US
# 1.39.38.191 is from IN
# 73.158.171.36 is from US
# 31.53.95.254 is from GB
# 190.9.193.97 is from CO
# 111.95.134.233 is from ID
# 192.100.72.2 is from US
# 2405:204:3003:f815:e142:e1a8:c7fe:f818 is from IN
# 131.111.27.50 is from GB
# 106.219.11.230 is from IN
# 170.163.100.203 is from US
# 2a02:c7d:bb84:a00:640b:9acf:1a76:bbe9 is from GB
# 72.201.249.127 is from US
# 62.255.48.34 is from GB
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Type_system&action=history
# 174.21.122.167 is from US
# 2601:647:4e00:44ac:e82e:385f:1a72:df27 is from US
# 70.247.167.70 is from US
# 115.114.69.98 is from IN
# 47.18.143.110 is from US
# 76.191.222.78 is from US
# 107.77.164.31 is from US
# 75.136.35.18 is from US
# 81.204.49.200 is from NL
# 122.174.117.206 is from IN
# 211.100.57.47 is from CN
# 85.237.234.45 is from SK
# 167.206.63.34 is from US
# 206.169.223.194 is from US
# 2001:630:212:220:ea40:f2ff:fee2:360e is from GB
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Duck_typing&action=history
# 2620:0:1079:50:1ec:6c40:1388:e2c8 is from DK
# 2001:4898:8010::343 is from US
# 104.63.252.164 is from US
# 167.220.148.135 is from US
# 59.10.72.130 is from KR
# 128.189.93.255 is from CA
# 108.48.188.159 is from US
# 2620:149:4:1c02:4424:4454:a038:4ac8 is from US
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Dynamic_typing&action=history
# 62.23.212.160 is from
# 24.217.36.41 is from US
# 131.111.8.99 is from GB
# 195.149.37.65 is from GB
# 192.102.214.6 is from NL
# 128.250.6.134 is from AU
# 172.194.101.14 is from AU
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Strong_typing&action=history
# 68.2.187.224 is from US
# 123.201.228.97 is from IN
# 98.234.249.218 is from US
# 59.167.127.158 is from AU
# 88.175.108.247 is from FR
# 75.152.190.38 is from CA
# 79.67.253.90 is from GB
# 46.14.245.69 is from CH
# 137.52.233.174 is from US
# 219.64.72.209 is from IN
# 219.64.70.220 is from IN
# 75.35.50.37 is from US
# 98.155.76.148 is from US
# 82.69.159.205 is from GB
# 71.61.178.1 is from US
# 83.254.128.245 is from SE
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Gradual_typing&action=history
# 129.59.105.69 is from US
# 166.170.42.168 is from US
# 2601:647:4902:5300:ec85:729e:df6d:8907 is from US
# 2620:c6:8000:200:4519:8595:5b08:42ee is from US
# 69.181.142.182 is from US
# 198.200.72.166 is from CA
# 2601:8:9600:be:3ded:d5a4:1893:109 is from US
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Operating_system&action=history
# 121.97.149.106 is from PH
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Cross-platform&action=history
# 71.89.253.238 is from US
# 106.213.252.233 is from IN
# 122.106.82.237 is from AU
# 122.180.187.250 is from IN
# 194.32.31.1 is from GB
# 209.36.4.2 is from US
# 183.82.110.221 is from IN
# 69.255.27.70 is from US
# 50.242.89.75 is from US
# 117.240.239.225 is from IN
# 165.124.145.1 is from US
# 81.146.6.93 is from GB
# 69.86.6.150 is from US
# 109.9.177.81 is from FR
# 14.0.174.109 is from HK
# 76.113.216.146 is from US
# 162.254.122.228 is from US
# 201.20.105.198 is from BR
# 42.118.13.66 is from VN
# 200.118.133.162 is from CO
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Software_license&action=history
# 2602:304:b10c:8f40:7170:10c0:2307:2ac1 is from US
# 108.24.93.201 is from US
# 108.54.60.239 is from US
# 71.246.230.59 is from US
# 94.193.76.224 is from GB
# 76.175.128.194 is from US
# 94.249.84.195 is from JO
# 121.241.127.12 is from IN
# 150.214.93.194 is from ES
# 50.153.148.151 is from US
# 121.208.13.154 is from AU
# 1.186.249.250 is from IN
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Python_Software_Foundation_License&action=history
# 71.110.212.116 is from US
# 69.154.10.203 is from US
# 129.10.9.77 is from US
# 221.134.160.242 is from IN
# 71.89.160.105 is from US
# 150.101.214.82 is from AU
# 74.56.110.127 is from CA
# 99.240.76.83 is from CA
# 90.215.243.133 is from GB
# 83.254.138.122 is from SE
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Filename_extension&action=history
# 220.158.156.29 is from IN
# 115.134.97.127 is from MY
# 2607:fb90:484e:e786:c5a4:86cf:cfed:3d1e is from US
# 168.235.201.226 is from US
# 197.253.221.148 is from MA
# 108.34.33.111 is from US
# 197.250.53.39 is from TZ
# 2001:e68:5426:1a0d:dd95:7d78:69b1:e16e is from MY
# 66.87.9.0 is from US
# 2a02:810a:8c40:2240:749e:b5ea:17a8:5e32 is from DE
# 2607:fb90:768:37c3:e5f3:6840:d6a1:bb48 is from US
# 109.77.15.112 is from IE
# 112.198.103.64 is from PH
# 113.210.185.206 is from MY
# 197.156.133.218 is from KE
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Programming_language_implementation&action=history
# 70.247.162.60 is from US
# 93.169.177.175 is from SA
# 220.227.8.230 is from IN
# 27.3.0.228 is from VN
# 2602:306:33e1:6a20:dd1b:bfab:c9bb:50a3 is from US
# 105.109.72.234 is from DZ
# 188.158.140.90 is from IR
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=CPython&action=history
# 2a02:6b8:0:40c:a952:4a93:a6f2:9317 is from RU
# 2601:243:301:5175:4d72:ae15:697f:6128 is from US
# 2.52.54.88 is from IL
# 15.211.201.87 is from US
# 2605:e000:1314:15a:c882:58d5:f0fa:c37c is from US
# 109.242.192.230 is from GR
# 70.198.33.152 is from US
# 77.56.53.183 is from CH
# 86.57.255.92 is from BY
# 24.1.209.218 is from US
# 38.129.227.156 is from US
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=IronPython&action=history
# 190.161.145.117 is from CL
# 130.235.32.53 is from SE
# 70.198.25.249 is from US
# 70.197.193.51 is from US
# 110.55.199.6 is from PH
# 50.53.15.51 is from US
# 70.151.74.66 is from US
# 193.173.35.5 is from NL
# 83.251.248.170 is from SE
# 128.206.40.209 is from US
# 70.198.7.85 is from US
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Jython&action=history
# 103.254.102.17 is from IN
# 157.127.124.151 is from US
# 95.210.220.183 is from FR
# 50.126.125.240 is from US
# 104.55.212.99 is from US
# 137.48.251.105 is from US
# 128.71.143.243 is from RU
# 71.237.143.157 is from US
# 65.125.12.222 is from US
# 119.225.34.242 is from AU
# 83.251.248.170 is from SE
# 95.172.74.62 is from GB
# 84.241.43.4 is from IR
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=MicroPython&action=history
# 64.238.129.36 is from US
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=PyPy&action=history
# 154.121.251.112 is from DZ
# 197.86.187.22 is from ZA
# 109.124.178.120 is from SE
# 195.145.106.234 is from DE
# 177.208.94.80 is from BR
# 137.48.251.105 is from US
# 96.241.70.123 is from US
# 188.30.114.144 is from GB
# 4.34.86.243 is from US
# 2003:7a:8503:c900:8d80:33cd:5219:2b3c is from DE
# 188.96.89.124 is from DE
# 216.252.198.54 is from US
# 82.41.255.254 is from GB
# 128.187.80.2 is from US
# 2605:6000:ef84:2f00:2821:769b:861:99ba is from US
# 112.166.75.192 is from KR
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Dialect_(computing)&action=history
# 89.163.66.103 is from RU
# 24.235.188.174 is from CA
# 189.82.188.108 is from BR
# 99.63.60.16 is from US
# 203.177.247.192 is from PH
# 118.210.197.145 is from AU
# 76.71.235.164 is from CA
# 83.100.187.50 is from GB
# 66.74.176.59 is from US
# 67.142.130.40 is from US
# 200.126.223.126 is from AR
# 124.124.52.164 is from IN
# 78.32.219.25 is from GB
# 172.206.111.187 is from GB
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Cython&action=history
# 86.128.190.208 is from GB
# 124.197.1.26 is from NZ
# 86.164.23.31 is from GB
# 86.186.136.196 is from GB
# 137.48.251.105 is from US
# 159.147.244.254 is from ES
# 67.170.72.127 is from US
# 128.229.4.2 is from US
# 87.112.174.210 is from GB
# 77.56.53.183 is from CH
# 142.231.110.50 is from CA
# 209.203.70.34 is from US
# 68.13.111.48 is from US
# 137.48.251.231 is from US
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=RPython&action=history
# 85.178.124.81 is from DE
# 85.178.179.11 is from DE
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Stackless_Python&action=history
# 85.118.231.227 is from RU
# 207.198.105.24 is from US
# 82.18.255.4 is from GB
# 50.53.15.51 is from US
# 137.48.251.105 is from US
# 73.222.188.140 is from US
# 86.190.223.79 is from GB
# 71.228.57.212 is from US
# 129.10.116.181 is from US
# 137.119.92.151 is from US
# 77.56.53.183 is from CH
# 95.79.208.212 is from RU
# 81.231.245.214 is from SE
# 212.185.168.66 is from DE
# 173.196.139.154 is from US
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=ABC_(programming_language)&action=history
# 24.106.95.243 is from US
# 178.187.57.17 is from RU
# 24.218.155.160 is from US
# 117.195.212.149 is from IN
# 131.211.113.2 is from NL
# 82.95.204.119 is from NL
# 113.162.145.67 is from VN
# 72.188.68.228 is from US
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=ALGOL_68&action=history
# 74.235.178.81 is from US
# 103.203.95.4 is from BD
# 165.189.255.34 is from US
# 63.230.188.98 is from US
# 1.47.234.70 is from TH
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=C_(programming_language)&action=history
# 45.252.54.2 is from BD
# 198.235.255.4 is from US
# 117.239.46.146 is from IN
# 216.46.210.245 is from US
# 182.74.157.249 is from IN
# 37.137.113.163 is from IR
# 84.198.108.151 is from BE
# 181.230.161.210 is from AR
# 45.120.214.53 is from IN
# 14.139.86.52 is from IN
# 122.173.227.178 is from IN
# 182.58.208.100 is from IN
# 139.5.199.234 is from IN
# 168.9.213.9 is from US
# 2601:2c3:8301:2510:25bb:ae57:5364:5862 is from US
# 94.118.222.35 is from GB
# 92.51.76.66 is from GE
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=C%2B%2B&action=history
# 189.100.44.173 is from BR
# 216.177.129.32 is from US
# 45.252.54.2 is from BD
# 202.125.156.94 is from PK
# 194.225.31.9 is from IR
# 183.87.21.246 is from IN
# 27.54.181.205 is from IN
# 174.61.228.93 is from US
# 164.52.227.130 is from US
# 5.250.50.254 is from IR
# 166.127.1.192 is from US
# 164.100.146.7 is from IN
# 24.13.202.137 is from US
# 38.104.192.74 is from CA
# 194.35.222.101 is from GB
# 146.196.34.231 is from IN
# 58.108.87.120 is from AU
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Dylan_(programming_language)&action=history
# 76.120.178.238 is from US
# 195.225.189.80 is from GB
# 70.231.229.51 is from US
# 2001:14bb:140:2896:2d4e:154c:5901:946f is from FI
# 216.38.129.126 is from US
# 168.31.88.115 is from US
# 79.164.171.49 is from RU
# 76.102.173.174 is from US
# 112.65.62.144 is from CN
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Haskell_(programming_language)&action=history
# 87.171.27.180 is from DE
# 193.52.24.15 is from FR
# 70.184.214.35 is from US
# 24.222.173.159 is from CA
# 8.37.227.158 is from US
# 2003:86:8d39:eb43:ad60:a860:254d:cdfd is from DE
# 203.181.243.17 is from JP
# 31.13.144.29 is from RU
# 65.222.202.204 is from US
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Icon_(programming_language)&action=history
# 82.29.185.61 is from GB
# 186.45.65.84 is from TT
# 172.56.12.248 is from US
# 188.244.41.216 is from RU
# 67.100.127.226 is from US
# 112.208.105.9 is from PH
# 93.181.213.199 is from RU
# 54.221.243.52 is from US
# 93.181.214.29 is from RU
# 121.45.201.112 is from AU
# 155.198.9.87 is from GB
# 177.92.39.38 is from BR
# 68.165.57.155 is from US
# 79.0.192.51 is from IT
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Java_(programming_language)&action=history
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Lisp_(programming_language)&action=history
# 76.21.61.202 is from US
# 70.184.214.35 is from US
# 96.27.107.130 is from US
# 109.202.131.98 is from DK
# 79.151.29.163 is from ES
# 1.123.1.235 is from AU
# 68.199.130.134 is from US
# 125.238.224.17 is from NZ
# 174.23.255.40 is from US
# 152.1.137.158 is from US
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Modula-3&action=history
# 68.222.54.61 is from US
# 68.222.22.46 is from US
# 125.236.56.215 is from NZ
# 88.183.246.121 is from FR
# 217.197.84.34 is from DE
# 216.31.219.19 is from US
# 166.177.249.185 is from US
# 67.35.254.109 is from US
# 190.67.201.127 is from CO
# 78.31.42.18 is from FR
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Perl&action=history
# 160.3.60.228 is from US
# 43.242.119.224 is from IN
# 199.22.57.2 is from CA
# 199.64.6.155 is from US
# 37.202.118.243 is from JO
# 143.199.125.10 is from US
# 99.236.6.160 is from CA
# 119.170.176.4 is from JP
# 208.73.81.66 is from US
# 210.195.71.86 is from MY
# 70.184.214.35 is from US
# 80.254.154.107 is from DK
# 2.99.198.170 is from GB
# 24.42.148.229 is from US
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Boo_(programming_language)&action=history
# 98.26.30.77 is from US
# 81.156.151.20 is from GB
# 14.139.190.101 is from IN
# 24.189.123.128 is from US
# 213.65.138.54 is from SE
# 173.183.144.105 is from CA
# 58.174.130.70 is from AU
# 86.24.195.220 is from GB
# 202.168.70.106 is from MY
# 12.36.214.74 is from US
# 122.252.227.228 is from IN
# 86.91.143.15 is from NL
# 24.114.77.91 is from CA
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Cobra_(programming_language)&action=history
# 194.66.32.10 is from GB
# 124.107.125.60 is from PH
# 75.36.159.151 is from US
# 216.40.129.218 is from US
# 213.246.131.69 is from GB
# 207.207.21.81 is from US
# 199.18.112.253 is from US
# 217.205.155.130 is from GB
# 76.174.233.82 is from US
# 46.175.99.212 is from RU
# 14.1.193.179 is from MY
# 195.19.32.201 is from RU
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=CoffeeScript&action=history
# 76.88.89.170 is from US
# 192.225.213.20 is from US
# 59.167.32.29 is from AU
# 84.59.106.7 is from DE
# 71.36.59.17 is from US
# 112.209.78.205 is from PH
# 195.234.136.77 is from DE
# 209.6.202.176 is from US
# 131.111.102.27 is from GB
# 74.138.97.18 is from US
# 70.162.153.220 is from US
# 144.32.240.104 is from GB
# 137.48.251.9 is from US
# 122.182.14.98 is from IN
# 85.64.32.8 is from IL
# 14.203.105.106 is from AU
# 188.195.82.199 is from DE
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=D_(programming_language)&action=history
# 185.13.106.91 is from GB
# 82.3.40.39 is from GB
# 186.158.138.229 is from AR
# 90.75.205.79 is from ES
# 2601:680:c700:c294:d5fd:5edd:9707:9b1a is from US
# 99.240.84.40 is from CA
# 86.127.128.170 is from RO
# 202.70.33.22 is from MN
# 213.205.252.47 is from GB
# 49.144.172.208 is from PH
# 115.248.248.242 is from IN
# 80.229.239.67 is from GB
# 105.103.85.87 is from DZ
# 89.217.100.117 is from CH
# 195.179.65.72 is from DE
# 2602:306:bcfd:c0c0:90b9:72b1:6340:ffd5 is from US
# 210.125.213.190 is from KR
# 175.142.181.65 is from MY
# 80.179.18.46 is from IL
# 96.33.204.253 is from US
# 93.214.224.231 is from DE
# 89.84.173.244 is from FR
# 80.229.36.157 is from GB
# 103.243.53.145 is from IN
# 2a01:e35:8bb7:2630:e3fa:8ec8:9482:1ec8 is from FR
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=F_Sharp_(programming_language)&action=history
# 91.23.165.8 is from DE
# 41.78.74.252 is from SO
# 213.207.90.158 is from NL
# 67.167.27.50 is from US
# 217.91.53.64 is from DE
# 202.159.151.37 is from AU
# 137.48.251.69 is from US
# 204.101.50.225 is from CA
# 2002:4350:5a37:1234:e95e:ad0d:1fc5:34d5 is from US
# 187.189.154.3 is from MX
# 137.48.251.192 is from US
# 100.2.87.52 is from US
# 93.176.76.139 is from DK
# 2.80.222.128 is from PT
# 2601:82:202:94b3:c994:be1f:9c4d:a2ea is from US
# 172.91.92.28 is from US
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Falcon_(programming_language)&action=history
# 86.30.150.32 is from GB
# 50.126.125.240 is from US
# 203.177.247.79 is from PH
# 205.168.23.154 is from US
# 107.181.20.148 is from US
# 93.36.1.48 is from IT
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Genie_(programming_language)&action=history
# 85.49.19.29 is from ES
# 202.164.35.98 is from IN
# 85.228.31.82 is from SE
# 137.48.251.106 is from US
# 83.254.138.122 is from SE
# 83.213.166.155 is from ES
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Go_(programming_language)&action=history
# 74.76.166.164 is from US
# 81.102.116.246 is from GB
# 165.225.80.124 is from GB
# 213.123.55.116 is from GB
# 108.46.195.138 is from US
# 50.53.1.33 is from US
# 96.238.44.95 is from US
# 156.211.247.69 is from EG
# 181.171.40.42 is from AR
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Groovy_(programming_language)&action=history
# 125.17.1.38 is from IN
# 82.28.153.207 is from GB
# 86.44.218.131 is from IE
# 58.165.156.2 is from AU
# 208.72.142.38 is from US
# 58.162.52.53 is from AU
# 124.123.87.169 is from IN
# 197.15.204.72 is from TN
# 2601:204:c002:7081:be5f:f4ff:fe35:1b41 is from US
# 95.118.155.195 is from DE
# 80.78.5.105 is from FR
# 146.140.210.15 is from DE
# 80.254.154.107 is from DK
# 89.157.62.109 is from FR
# 98.165.69.185 is from US
# 2001:4dd0:f940:0:9d4f:b03:c9f8:a99e is from DE
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=JavaScript&action=history
# 83.162.210.184 is from NL
# 86.131.122.84 is from GB
# 2601:541:4305:c70:5cdf:ecec:364:42ea is from US
# 58.68.125.18 is from IN
# 171.33.194.98 is from GB
# 122.160.12.51 is from IN
# 123.63.229.129 is from IN
# 87.188.203.220 is from DE
# 104.129.196.115 is from US
# 66.244.233.36 is from CA
# 111.88.123.43 is from PK
# 81.167.65.154 is from NO
# 176.42.249.108 is from TR
# 107.77.164.22 is from US
# 67.245.151.209 is from US
# 103.207.54.0 is from IN
# 101.167.20.185 is from AU
# 14.141.36.216 is from IN
# 86.10.78.130 is from GB
# 124.117.226.170 is from CN
# 96.80.32.1 is from US
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Julia_(programming_language)&action=history
# 108.244.57.133 is from US
# 188.100.247.250 is from DE
# 2602:306:cf43:9850:cc2:7b52:d97a:c470 is from US
# 172.4.242.120 is from US
# 31.13.144.22 is from RU
# 23.118.13.50 is from US
# 76.79.153.202 is from US
# 2600:1:e142:5c7e:f53f:1b6a:2f86:f94a is from US
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Nim_(programming_language)&action=history
# 79.164.169.89 is from RU
# 84.156.77.149 is from DE
# 77.3.241.53 is from DE
# 80.152.149.24 is from DE
# 82.47.79.174 is from GB
# 201.217.57.22 is from PY
# 185.95.206.91 is from IQ
# 80.221.159.67 is from FI
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Ruby_(programming_language)&action=history
# 89.138.110.173 is from IL
# 120.57.56.65 is from IN
# 216.73.64.51 is from CA
# 66.46.91.186 is from CA
# 60.52.98.52 is from MY
# 45.114.159.72 is from IN
# 87.12.214.164 is from IT
# 209.141.40.191 is from US
# 187.103.248.160 is from BR
# 49.126.255.79 is from NP
# 50.196.247.30 is from US
# 24.180.22.221 is from US
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Swift_(programming_language)&action=history
# 202.189.227.154 is from IN
# 79.70.159.148 is from GB
# 70.112.4.207 is from US
# 79.70.149.171 is from GB
# 180.151.193.250 is from IN
# 212.47.207.1 is from UA
# 43.251.85.146 is from IN
# 79.70.139.47 is from GB
# 122.162.201.162 is from IN
# 2602:306:308b:aea0:286b:1e33:c57e:a843 is from US
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=High-level_programming_language&action=history
# 83.110.226.122 is from AE
# 204.81.252.157 is from CA
# 112.209.25.21 is from PH
# 212.34.11.54 is from JO
# 38.140.59.74 is from US
# 188.247.78.209 is from JO
# 122.15.16.169 is from IN
# 197.211.57.51 is from NG
# 43.245.9.94 is from PK
# 2600:8800:1202:300:b101:66b5:2663:3876 is from US
# 188.247.77.21 is from JO
# 46.32.127.64 is from JO
# 14.139.189.40 is from IN
# 72.49.57.170 is from US
# 115.87.132.46 is from TH
# 62.255.100.11 is from GB
# 24.178.114.230 is from US
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=General-purpose_programming_language&action=history
# 122.52.102.84 is from PH
# 217.153.157.250 is from PL
# 213.103.204.226 is from LT
# 91.213.118.2 is from PL
# 77.56.4.74 is from CH
# 60.221.140.44 is from CN
# 92.245.5.18 is from SK
# 188.6.137.135 is from HU
# 122.179.62.195 is from IN
# 201.27.236.81 is from BR
# 70.60.76.34 is from US
# 207.162.101.2 is from CA
# 2a02:2f01:1026:30a4:7881:b0c1:dad0:c2f6 is from RO
# 173.167.116.225 is from US
# 79.227.4.123 is from DE
# 130.226.41.7 is from DK
# 84.211.83.254 is from NO
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Interpreter_(computing)&action=history
# 188.141.45.109 is from IE
# 112.133.245.13 is from IN
# 82.219.28.37 is from GB
# 83.51.158.23 is from ES
# 219.90.85.45 is from PH
# 117.221.138.171 is from IN
# 163.1.220.102 is from GB
# 212.230.172.61 is from ES
# 175.110.150.24 is from PK
# 192.88.146.1 is from US
# 15.203.233.84 is from US
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Dynamic_programming_language&action=history
# 198.54.211.2 is from US
# 174.92.108.120 is from CA
# 205.185.99.96 is from US
# 109.123.99.49 is from GB
# 117.211.27.53 is from IN
# 213.240.48.66 is from RS
# 68.134.37.76 is from US
# 199.106.103.53 is from US
# 94.245.25.101 is from SE
# 108.21.70.220 is from US
# 74.140.196.198 is from US
# 151.243.78.98 is from IR
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Readability&action=history
# 196.210.159.114 is from ZA
# 108.20.221.66 is from US
# 123.90.194.109 is from CN
# 108.221.18.208 is from US
# 66.192.33.51 is from US
# 134.96.90.27 is from DE
# 182.73.121.234 is from IN
# 65.185.61.104 is from US
# 24.39.147.75 is from US
# 207.237.81.81 is from US
# 2605:6000:ee4a:2900:907e:b8ad:f6e:9cca is from US
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Source_lines_of_code&action=history
# 103.19.255.74 is from BD
# 61.175.197.202 is from CN
# 132.3.45.83 is from US
# 39.42.73.66 is from PK
# 91.34.157.160 is from DE
# 81.198.114.49 is from LV
# 190.245.76.186 is from AR
# 91.34.140.145 is from DE
# 112.10.211.84 is from CN
# 128.237.28.16 is from US
# 87.167.95.56 is from DE
# 95.244.21.197 is from IT
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=C%2B%2B&action=history
# 189.100.44.173 is from BR
# 216.177.129.32 is from US
# 45.252.54.2 is from BD
# 202.125.156.94 is from PK
# 194.225.31.9 is from IR
# 183.87.21.246 is from IN
# 27.54.181.205 is from IN
# 174.61.228.93 is from US
# 164.52.227.130 is from US
# 5.250.50.254 is from IR
# 166.127.1.192 is from US
# 164.100.146.7 is from IN
# 24.13.202.137 is from US
# 38.104.192.74 is from CA
# 194.35.222.101 is from GB
# 146.196.34.231 is from IN
# 58.108.87.120 is from AU
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Java_(programming_language)&action=history
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Programming_in_the_large_and_programming_in_the_small&action=history
# 173.75.228.108 is from US
# 217.35.75.188 is from GB
# 182.178.71.27 is from PK
# 201.235.40.224 is from AR
# 125.114.148.122 is from CN
# 180.193.98.16 is from PH
# 75.2.139.127 is from US
# 83.139.197.18 is from IT
# 81.231.244.124 is from SE
# 192.174.37.50 is from US
# 89.118.19.75 is from IT
# 202.128.176.170 is from SG
# 129.237.28.201 is from US
# 88.218.157.241 is from ES
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Programming_paradigm&action=history
# 216.186.131.29 is from US
# 43.252.233.5 is from MY
# 2607:fb90:5223:c275:0:17:a6be:ca01 is from US
# 162.247.124.52 is from CA
# 68.8.169.121 is from US
# 213.30.118.68 is from PT
# 196.47.102.43 is from NG
# 97.32.131.205 is from US
# 66.87.64.75 is from US
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Object-oriented_programming&action=history
# 119.157.201.147 is from PK
# 124.217.188.219 is from HK
# 2602:306:ce95:6bb0:d5ce:67e8:51c6:49ef is from US
# 49.126.254.224 is from NP
# 41.136.96.19 is from MU
# 71.163.164.190 is from US
# 36.255.189.18 is from BD
# 176.104.51.69 is from UA
# 202.142.121.131 is from IN
# 94.124.165.9 is from RU
# 14.139.223.167 is from IN
# 107.1.229.152 is from US
# 74.202.112.4 is from US
# 157.139.21.1 is from US
# 117.211.110.69 is from IN
# 117.192.195.87 is from IN
# 182.190.96.145 is from PK
# 124.106.138.94 is from PH
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Imperative_programming&action=history
# 69.127.36.174 is from US
# 15.203.233.84 is from US
# 103.14.125.98 is from IN
# 2601:2:4d00:27b:7189:66f1:1135:7f00 is from US
# 2604:2000:b064:3300:6dd3:b07e:494d:c5cd is from US
# 5.199.208.23 is from RU
# 152.231.35.89 is from NI
# 114.79.32.242 is from ID
# 79.186.27.201 is from PL
# 94.118.222.35 is from GB
# 111.92.130.14 is from PK
# 80.175.63.138 is from GB
# 140.177.205.223 is from US
# 107.107.62.0 is from US
# 176.60.44.112 is from BY
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Functional_programming&action=history
# 2a00:1d40:146e:1:68d9:5c82:30f0:c7e4 is from GB
# 204.48.94.228 is from CA
# 217.91.53.64 is from DE
# 212.252.83.254 is from TR
# 86.61.7.10 is from SI
# 170.12.232.245 is from US
# 77.56.53.183 is from CH
# 99.246.86.48 is from CA
# 14.139.241.210 is from IN
# 104.162.245.137 is from US
# 118.200.185.145 is from SG
# 2602:306:ce6e:9420:9c11:f1e0:b219:bef0 is from US
# 208.71.62.32 is from US
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Procedural_programming&action=history
# 195.132.60.60 is from FR
# 107.1.229.152 is from US
# 198.233.104.154 is from US
# 212.132.0.22 is from GB
# 194.81.178.163 is from GB
# 37.211.33.26 is from QA
# 178.232.15.124 is from NO
# 62.253.69.42 is from GB
# 149.3.140.250 is from GB
# 90.222.80.124 is from GB
# 77.56.53.183 is from CH
# 86.152.129.204 is from GB
# 195.195.250.2 is from GB
# 14.139.234.50 is from IN
# 122.2.113.36 is from PH
# 73.19.237.89 is from US
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Dynamic_type&action=history
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Memory_management&action=history
# 114.4.78.203 is from ID
# 115.118.152.184 is from IN
# 2601:6c0:c001:a4b0:71fc:7a93:8e0b:d7ab is from US
# 122.61.32.185 is from NZ
# 2003:62:4428:c210:10da:b620:8142:af9c is from DE
# 151.52.56.37 is from IT
# 189.6.17.233 is from BR
# 115.188.27.154 is from NZ
# 115.118.152.182 is from IN
# 2605:e000:7d4b:600:109f:999d:ae0e:1a4c is from US
# 125.62.213.170 is from IN
# 106.208.206.192 is from IN
# 73.106.76.147 is from US
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Standard_library&action=history
# 202.63.186.19 is from CN
# 141.154.111.35 is from US
# 118.6.165.80 is from JP
# 69.176.131.57 is from US
# 193.124.208.80 is from SY
# 64.231.235.86 is from CA
# 73.166.146.160 is from US
# 193.196.8.103 is from DE
# 161.53.243.141 is from HR
# 68.200.191.240 is from US
# 24.4.198.207 is from US
# 189.72.121.146 is from BR
# 147.188.194.245 is from GB
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Operating_system&action=history
# 121.97.149.106 is from PH
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Third-party_software_component&action=history
# 124.105.61.44 is from PH
# 71.116.70.200 is from US
# 94.255.221.251 is from SE
# 202.164.46.82 is from IN
# 180.194.32.252 is from PH
# 116.68.125.239 is from IN
# 81.153.147.173 is from GB
# 117.228.55.39 is from IN
# 108.17.39.101 is from US
# 69.246.17.242 is from US
# 58.109.104.175 is from AU
# 66.76.66.114 is from US
# 117.193.39.180 is from IN
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Py2exe&action=history
# 114.76.98.247 is from AU
# 71.56.215.19 is from US
# 86.175.180.102 is from GB
# 173.73.44.108 is from US
# 85.193.250.223 is from PL
# 112.198.90.231 is from PH
# 91.192.15.76 is from DE
# 77.185.119.133 is from DE
# 2.103.74.138 is from GB
# 66.19.153.67 is from US
# 137.48.251.231 is from US
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=CPython&action=history
# 2a02:6b8:0:40c:a952:4a93:a6f2:9317 is from RU
# 2601:243:301:5175:4d72:ae15:697f:6128 is from US
# 2.52.54.88 is from IL
# 15.211.201.87 is from US
# 2605:e000:1314:15a:c882:58d5:f0fa:c37c is from US
# 109.242.192.230 is from GR
# 70.198.33.152 is from US
# 77.56.53.183 is from CH
# 86.57.255.92 is from BY
# 24.1.209.218 is from US
# 38.129.227.156 is from US
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Reference_implementation&action=history
# 75.61.140.175 is from US
# 89.163.66.103 is from RU
# 68.33.165.248 is from US
# 2602:306:c5a2:9160:221:97ff:fe13:6e3 is from US
# 71.166.48.124 is from US
# 146.178.95.1 is from AU
# 198.162.74.25 is from CA
# 76.66.200.95 is from CA
# 84.56.107.221 is from DE
# 210.212.241.233 is from IN
# 141.149.35.47 is from US
# 121.98.149.190 is from NZ
# 59.10.158.53 is from KR
# 199.46.200.230 is from US
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Free_and_open-source_software&action=history
# 103.17.158.152 is from IN
# 45.115.186.38 is from IN
# 41.77.15.30 is from MW
# 110.44.116.93 is from NP
# 103.59.206.227 is from IN
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Python_Software_Foundation&action=history
# 119.15.154.71 is from BD
# 70.198.36.48 is from US
# 194.83.198.199 is from GB
# 50.56.228.68 is from US
# 70.198.33.152 is from US
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Guido_van_Rossum&action=history
# 204.14.15.229 is from US
# 87.228.157.89 is from CY
# 117.196.232.127 is from IN
# 2602:306:c43c:8b20:1468:f8e:faca:84a5 is from US
# 67.171.73.105 is from US
# 112.135.69.224 is from LK
# 108.45.29.72 is from US
# 213.160.115.146 is from GB
# 2a02:c7d:9e2a:7800:85c3:9b5:7f8c:a731 is from GB
# 194.53.210.44 is from NL
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=History_of_Python&action=history
# 66.57.1.215 is from US
# 14.139.212.103 is from IN
# 108.27.68.139 is from US
# 103.245.101.246 is from IN
# 64.183.26.138 is from US
# 70.36.145.228 is from US
# 5.81.167.193 is from GB
# 97.117.102.251 is from US
# 117.203.237.236 is from IN
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Guido_van_Rossum&action=history
# 204.14.15.229 is from US
# 87.228.157.89 is from CY
# 117.196.232.127 is from IN
# 2602:306:c43c:8b20:1468:f8e:faca:84a5 is from US
# 67.171.73.105 is from US
# 112.135.69.224 is from LK
# 108.45.29.72 is from US
# 213.160.115.146 is from GB
# 2a02:c7d:9e2a:7800:85c3:9b5:7f8c:a731 is from GB
# 194.53.210.44 is from NL
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Centrum_Wiskunde_%26_Informatica&action=history
# 163.47.14.201 is from IN
# 14.161.3.158 is from VN
# 192.16.197.194 is from NL
# 77.250.188.40 is from NL
# 77.56.53.183 is from CH
# 131.180.220.124 is from NL
# 14.169.57.229 is from VN
# 192.87.39.42 is from NL
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Netherlands&action=history
# 217.105.68.88 is from NL
# 203.100.11.4 is from AU
# 81.132.213.18 is from GB
# 163.158.173.123 is from NL
# 212.83.70.136 is from NL
# 113.252.241.227 is from HK
# 2.31.20.184 is from GB
# 64.88.4.230 is from US
# 212.83.70.224 is from NL
# 2601:405:4001:2a0a:c050:b24a:9b7f:682e is from US
# 185.89.217.232 is from
# 31.149.197.22 is from NL
# 213.224.24.222 is from BE
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=ABC_(programming_language)&action=history
# 24.106.95.243 is from US
# 178.187.57.17 is from RU
# 24.218.155.160 is from US
# 117.195.212.149 is from IN
# 131.211.113.2 is from NL
# 82.95.204.119 is from NL
# 113.162.145.67 is from VN
# 72.188.68.228 is from US
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=SETL&action=history
# 141.31.111.1 is from DE
# 50.53.15.51 is from US
# 68.147.63.20 is from CA
# 75.70.113.157 is from US
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Exception_handling&action=history
# 2601:449:c202:2090:f99e:fbba:89a4:c3ea is from US
# 75.166.220.241 is from US
# 218.212.205.1 is from SG
# 106.79.207.76 is from IN
# 167.58.98.23 is from UY
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Amoeba_(operating_system)&action=history
# 27.33.140.165 is from AU
# 27.97.20.129 is from IN
# 93.88.189.236 is from RU
# 86.127.135.155 is from RO
# 14.169.56.195 is from VN
# 94.96.176.4 is from SA
# 31.50.197.208 is from GB
# 14.169.15.67 is from VN
# 217.128.37.173 is from FR
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Benevolent_dictator_for_life&action=history
# 78.109.184.105 is from GB
# 91.183.125.132 is from BE
# 143.167.5.171 is from GB
# 140.105.18.8 is from IT
# 2804:431:f710:67d:2349:4f3d:9c8b:5ee8 is from BR
# 82.150.96.2 is from GB
# 174.1.80.17 is from CA
# 205.135.136.10 is from US
# 39.37.140.232 is from PK
# 141.135.64.128 is from BE
# 178.3.239.252 is from DE
# 193.239.136.27 is from PL
# 199.67.131.156 is from US
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=ABC_(programming_language)&action=history
# 24.106.95.243 is from US
# 178.187.57.17 is from RU
# 24.218.155.160 is from US
# 117.195.212.149 is from IN
# 131.211.113.2 is from NL
# 82.95.204.119 is from NL
# 113.162.145.67 is from VN
# 72.188.68.228 is from US
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Unix&action=history
# 210.14.4.71 is from PH
# 203.129.242.82 is from IN
# 103.16.28.69 is from IN
# 111.90.172.100 is from IN
# 106.223.198.162 is from IN
# 180.151.195.74 is from IN
# 75.115.176.230 is from US
# 88.153.7.108 is from DE
# 97.65.130.169 is from US
# 87.88.76.232 is from FR
# 205.219.90.1 is from US
# 62.73.169.66 is from GB
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=C_(programming_language)&action=history
# 45.252.54.2 is from BD
# 198.235.255.4 is from US
# 117.239.46.146 is from IN
# 216.46.210.245 is from US
# 182.74.157.249 is from IN
# 37.137.113.163 is from IR
# 84.198.108.151 is from BE
# 181.230.161.210 is from AR
# 45.120.214.53 is from IN
# 14.139.86.52 is from IN
# 122.173.227.178 is from IN
# 182.58.208.100 is from IN
# 139.5.199.234 is from IN
# 168.9.213.9 is from US
# 2601:2c3:8301:2510:25bb:ae57:5364:5862 is from US
# 94.118.222.35 is from GB
# 92.51.76.66 is from GE
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Hacker_(programmer_subculture)&action=history
# 103.195.72.6 is from IN
# 24.5.215.230 is from US
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Monty_Python%27s_Flying_Circus&action=history
# 92.20.174.203 is from GB
# 12.233.147.42 is from US
# 125.18.177.99 is from IN
# 86.133.95.69 is from GB
# 130.88.99.219 is from GB
# 31.54.142.129 is from GB
# 67.234.122.52 is from US
# 47.219.175.118 is from US
# 72.82.172.37 is from US
# 92.239.2.154 is from GB
# 2605:6000:ee4a:2900:907e:b8ad:f6e:9cca is from US
# 2620:10d:c090:200::9:cf32 is from US
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Garbage_collection_(computer_science)&action=history
# 24.56.16.18 is from US
# 41.89.93.217 is from KE
# 141.165.213.173 is from US
# 2a02:908:e850:ecc0:d07a:98c6:702b:b6fc is from DE
# 179.24.254.92 is from UY
# 62.253.83.68 is from GB
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Unicode&action=history
# 49.145.202.227 is from PH
# 210.212.102.93 is from IN
# 23.119.202.20 is from US
# 69.58.42.90 is from US
# 203.81.71.69 is from MM
# 106.0.36.93 is from IN
# 173.58.44.171 is from US
# 193.96.224.19 is from DE
# 99.101.115.113 is from US
# 79.74.31.249 is from GB
# -------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Backporting&action=history
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-0565c2a02601> in <module>()
#      58         historyIPs = getHistoryIPs(link.attrs["href"])
#      59         for historyIP in historyIPs:
# ---> 60             country = getCountry(historyIP)
#      61             if country is not None:
#      62                 print(historyIP+" is from "+country)
#
# <ipython-input-4-0565c2a02601> in getCountry(ipAddress)
#      44 def getCountry(ipAddress):
#      45     try:
# ---> 46         response = urlopen("http://freegeoip.net/json/"+ipAddress).read().decode('utf-8')
#      47     except HTTPError:
#      48         return None
#
# /Users/adarshnair/graphlab/anaconda/lib/python2.7/urllib2.pyc in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     152     else:
#     153         opener = _opener
# --> 154     return opener.open(url, data, timeout)
#     155
#     156 def install_opener(opener):
#
# /Users/adarshnair/graphlab/anaconda/lib/python2.7/urllib2.pyc in open(self, fullurl, data, timeout)
#     427             req = meth(req)
#     428
# --> 429         response = self._open(req, data)
#     430
#     431         # post-process response
#
# /Users/adarshnair/graphlab/anaconda/lib/python2.7/urllib2.pyc in _open(self, req, data)
#     445         protocol = req.get_type()
#     446         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 447                                   '_open', req)
#     448         if result:
#     449             return result
#
# /Users/adarshnair/graphlab/anaconda/lib/python2.7/urllib2.pyc in _call_chain(self, chain, kind, meth_name, *args)
#     405             func = getattr(handler, meth_name)
#     406
# --> 407             result = func(*args)
#     408             if result is not None:
#     409                 return result
#
# /Users/adarshnair/graphlab/anaconda/lib/python2.7/urllib2.pyc in http_open(self, req)
#    1226
#    1227     def http_open(self, req):
# -> 1228         return self.do_open(httplib.HTTPConnection, req)
#    1229
#    1230     http_request = AbstractHTTPHandler.do_request_
#
# /Users/adarshnair/graphlab/anaconda/lib/python2.7/urllib2.pyc in do_open(self, http_class, req, **http_conn_args)
#    1199         else:
#    1200             try:
# -> 1201                 r = h.getresponse(buffering=True)
#    1202             except TypeError: # buffering kw not supported
#    1203                 r = h.getresponse()
#
# /Users/adarshnair/graphlab/anaconda/lib/python2.7/httplib.pyc in getresponse(self, buffering)
#    1134
#    1135         try:
# -> 1136             response.begin()
#    1137             assert response.will_close != _UNKNOWN
#    1138             self.__state = _CS_IDLE
#
# /Users/adarshnair/graphlab/anaconda/lib/python2.7/httplib.pyc in begin(self)
#     451         # read until we get a non-100 response
#     452         while True:
# --> 453             version, status, reason = self._read_status()
#     454             if status != CONTINUE:
#     455                 break
#
# /Users/adarshnair/graphlab/anaconda/lib/python2.7/httplib.pyc in _read_status(self)
#     407     def _read_status(self):
#     408         # Initialize with Simple-Response defaults
# --> 409         line = self.fp.readline(_MAXLINE + 1)
#     410         if len(line) > _MAXLINE:
#     411             raise LineTooLong("header line")
#
# /Users/adarshnair/graphlab/anaconda/lib/python2.7/socket.pyc in readline(self, size)
#     478             while True:
#     479                 try:
# --> 480                     data = self._sock.recv(self._rbufsize)
#     481                 except error, e:
#     482                     if e.args[0] == EINTR:
#
# KeyboardInterrupt:
