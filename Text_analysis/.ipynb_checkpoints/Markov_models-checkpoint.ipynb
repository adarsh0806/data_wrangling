# %% [markdown]
# # 1. Implementing Markov Model from scratch #

# %%
'''
This program will generate a Markov Model of the text found here http://pythonscraping.com/files/inaugurationSpeech.txt
'''
from urllib2 import urlopen
from random import randint

# Get total count of words in the text
def wordListSum(wordList):
    sum = 0
    for word, value in wordList.items():
        sum += value
    return sum

# Get random word from the list
def retrieveRandomWord(wordList):
    randIndex = randint(1, wordListSum(wordList))
    for word, value in wordList.items():
        randIndex -= value
        if randIndex <= 0:
            return word

'''
Build a dictionary of dictionaries of the form:
{
    word_a : { word_b : 2, word_c : 3, word_d : 1 },
    word_e : { word_b : 3, word_d : 2},
    ...
    ..
    .
}
Here, word_a was found 6 times, twice it was followed  by word_b, thrice it was followed by word_c and once by word_d.
word_e was found 5 times, it was followed by word_b three times and twice it was followed by word_d.
'''
def buildWordDict(text):
    # Remove newlines and quotes
    text = text.replace("\n", " ")
    text = text.replace("\"", "")

    # Make sure puncuation are treated as their own "word," so they will be included
    # in the Markov chain
    punctuation = [',','.',';',':']
    for symbol in punctuation:
        text = text.replace(symbol, " " + symbol + " ")

    words = text.split(" ")
    # Filter out empty words
    words = [word for word in words if word != ""]
    
    # Create dict of dict
    wordDict = {}
    for i in range(1, len(words)):
        if words[i-1] not in wordDict:
            # Create a new dictionary for this word
            wordDict[words[i-1]] = {}
        if words[i] not in wordDict[words[i-1]]:
            wordDict[words[i-1]][words[i]] = 0
        wordDict[words[i-1]][words[i]] += 1

    return wordDict

# , 'utf-8' removed from the text reading statement.
text = str(urlopen("http://pythonscraping.com/files/inaugurationSpeech.txt").read())

# Build dict of dict with the input text provided.
wordDict = buildWordDict(text)

#Generate a Markov chain of length 100
length = 100
chain = ""
currentWord = "I"

# Create Markov chain
for i in range(0, length):
    chain += currentWord + " "   
    '''
    Once the dictionary is built, it can be used as a lookup table to see where to go next. For example if we are on
    word_e, we pass the dictionary { word_b : 3, word_d : 2 } to the retrieveRandomWord fucntion, which retrieves
    a random word from the dictionary, weighted by number of times it occurs.
    '''
    print "** Current word: \n", currentWord    
    print "** Dictionary of words that follow the current word: \n", wordDict[currentWord]    
    print "\n"
    currentWord = retrieveRandomWord(wordDict[currentWord])

print(chain)
# Out:
# ** Current word:
# I
# ** Dictionary of words that follow the current word:
# {'consider': 2, 'give': 1, 'apprehend': 1, 'consent': 1, 'am': 1, 'sincerely': 1, 'see': 1, 'deem': 1, 'have': 5, 'fear': 1, 'trust': 1, 'now': 1, 'appear': 1, 'had': 1, 'should': 2, 'too': 1, 'must': 1, 'refer': 1, 'shall': 5, 'may': 1, 'propose': 1, 'know': 1, 'believe': 2, 'proceed': 2, 'wish': 1, 'conceive': 3, 'assure': 1, 'can': 3, 'possess': 1}
#
#
# ** Current word:
# have
# ** Dictionary of words that follow the current word:
# {'gone': 1, 'prepared': 1, 'spoken': 1, 'dreamed': 1, 'acted': 1, 'been': 16, 'enjoyed': 1, 'ultimately': 1, 'heretofore': 1, 'strictly': 1, 'adopted': 1, 'examples': 1, 'learned': 1, 'intrusted': 1, 'then': 1, 'given': 1, 'occurred': 2, 'reared': 1, 'fastened': 1, 'amply': 1, 'anticipated': 1, 'come': 1, 'entered': 1, 'arisen': 1, 'made': 2, 'improved': 1, 'this': 1, 'placed': 2, 'determined': 1, 'the': 3, 'granted': 1, 'left': 1}
#
#
# ** Current word:
# strictly
# ** Dictionary of words that follow the current word:
# {'proper': 1, 'observed': 1, 'forbidden': 1}
#
#
# ** Current word:
# observed
# ** Dictionary of words that follow the current word:
# {',': 2, '.': 1}
#
#
# ** Current word:
# .
# ** Dictionary of words that follow the current word:
# {'Even': 1, 'History': 1, "Jefferson's": 1, 'Men': 1, 'For': 1, 'No': 2, 'There': 7, 'When': 3, 'Long': 1, 'Content': 1, 'To': 7, 'Jefferson': 3, 'Mischievous': 1, 'Amongst': 1, 'You': 1, 'Until': 1, 'We': 4, 'Beyond': 1, 'Far': 1, 'Fellow-citizens': 1, 'Never': 2, 'Upon': 1, 'However': 3, 'But': 10, 'Something': 1, 'These': 1, 'Connected': 1, 'Although': 1, 'Always': 1, 'Nothing': 1, 'Such': 2, 'Now': 1, 'By': 3, 'Those': 1, 'He': 3, 'A': 3, 'On': 3, 'Like': 1, 'I': 12, 'Of': 3, 'This': 6, 'Madison': 1, 'Experience': 1, 'Without': 1, 'So': 1, 'They': 2, 'The': 33, 'Or': 1, 'Upward': 1, 'And': 3, 'Limited': 1, 'All': 2, 'Strong': 1, 'Caesar': 1, 'Their': 1, 'Being': 1, 'Some': 3, 'It': 28, 'Are': 2, 'As': 4, 'Unpleasant': 1, 'At': 1, 'In': 8, 'Notwithstanding': 1, 'Our': 3, 'Before': 1, 'Yet': 1, 'If': 11}
#
#
# ** Current word:
# On
# ** Dictionary of words that follow the current word:
# {'the': 2, 'an': 1}
#
#
# ** Current word:
# an
# ** Dictionary of words that follow the current word:
# {'amendment': 1, 'exclusive': 2, 'office': 1, 'incongruity': 1, 'argument': 1, 'armed': 1, 'undercurrent': 1, 'alleged': 1, 'examination': 1, 'intolerant': 1, 'extensive': 1, 'aristocracy': 1, 'assurance': 1, 'affectionate': 1, 'express': 2, 'impartial': 1, 'Administration': 1, 'object': 1, 'early': 1, 'American': 1, 'altogether': 1, 'equality': 1, 'Executive': 1, 'amount': 1, 'officer': 1}
#
#
# ** Current word:
# exclusive
# ** Dictionary of words that follow the current word:
# {'jurisdiction': 1, 'metallic': 2}
#
#
# ** Current word:
# metallic
# ** Dictionary of words that follow the current word:
# {'currency': 2, ',': 1}
#
#
# ** Current word:
# currency
# ** Dictionary of words that follow the current word:
# {',': 1, '.': 3}
#
#
# ** Current word:
# .
# ** Dictionary of words that follow the current word:
# {'Even': 1, 'History': 1, "Jefferson's": 1, 'Men': 1, 'For': 1, 'No': 2, 'There': 7, 'When': 3, 'Long': 1, 'Content': 1, 'To': 7, 'Jefferson': 3, 'Mischievous': 1, 'Amongst': 1, 'You': 1, 'Until': 1, 'We': 4, 'Beyond': 1, 'Far': 1, 'Fellow-citizens': 1, 'Never': 2, 'Upon': 1, 'However': 3, 'But': 10, 'Something': 1, 'These': 1, 'Connected': 1, 'Although': 1, 'Always': 1, 'Nothing': 1, 'Such': 2, 'Now': 1, 'By': 3, 'Those': 1, 'He': 3, 'A': 3, 'On': 3, 'Like': 1, 'I': 12, 'Of': 3, 'This': 6, 'Madison': 1, 'Experience': 1, 'Without': 1, 'So': 1, 'They': 2, 'The': 33, 'Or': 1, 'Upward': 1, 'And': 3, 'Limited': 1, 'All': 2, 'Strong': 1, 'Caesar': 1, 'Their': 1, 'Being': 1, 'Some': 3, 'It': 28, 'Are': 2, 'As': 4, 'Unpleasant': 1, 'At': 1, 'In': 8, 'Notwithstanding': 1, 'Our': 3, 'Before': 1, 'Yet': 1, 'If': 11}
#
#
# ** Current word:
# But
# ** Dictionary of words that follow the current word:
# {'the': 5, 'there': 1, 'with': 1, 'it': 1, 'if': 2}
#
#
# ** Current word:
# if
# ** Dictionary of words that follow the current word:
# {'concentrated': 1, 'we': 1, 'errors': 1, 'that': 1, 'this': 1, 'there': 2, 'it': 2, 'used': 1, 'not': 3, 'bills': 1, 'its': 1}
#
#
# ** Current word:
# we
# ** Dictionary of words that follow the current word:
# {'would': 2, 'shall': 1, 'may': 2, 'are': 1, 'want': 1, 'must': 1}
#
#
# ** Current word:
# want
# ** Dictionary of words that follow the current word:
# {'of': 3, ',': 1}
#
#
# ** Current word:
# of
# ** Dictionary of words that follow the current word:
# {'exclusive': 1, 'all': 9, 'gold': 1, 'discord': 2, 'being': 1, 'devising': 1, 'country': 1, 'course': 2, 'civilized': 1, 'Caesar': 1, 'religious': 1, 'its': 16, 'Independence': 1, 'perfect': 1, 'death': 1, 'Columbia': 2, 'justice': 1, ',': 1, 'Camillus': 1, 'removal': 2, 'arresting': 1, 'candidates': 1, 'policy': 1, 'pending': 1, 'division': 1, 'them': 5, 'his': 4, 'appointment': 1, 'finance': 1, 'government': 4, 'conduct': 1, 'unlimited': 1, 'republics': 1, 'every': 4, 'half': 1, 'combinations': 1, 'one': 6, 'shaping': 1, 'condition': 1, 'Representatives': 1, 'England': 1, 'ascertaining': 1, 'public': 1, 'these': 5, 'distrust': 1, 'each': 5, 'mine': 2, 'upward': 1, 'superintendent': 1, 'concord': 1, 'intelligence': 1, 'violated': 1, 'some': 2, 'principles': 1, 'our': 29, 'freedom': 1, 'business': 1, 'giving': 1, 'liberty': 10, 'worship': 1, 'disunion': 1, 'unalienable': 1, 'investigation': 1, 'designing': 1, 'all--or': 1, 'checks': 1, 'supporting': 1, 'power': 16, 'men': 1, 'free': 1, 'difficulty': 1, 'Scythia': 1, 'Mr': 1, 'both': 1, 'great': 3, 'her': 3, 'language': 1, 'conformity': 2, 'citizens': 2, 'minorities': 1, 'products': 1, 'mixed': 1, 'protector': 1, 'duty': 1, 'revenue': 1, 'civil': 2, 'political': 2, 'two': 2, 'faction--a': 1, 'another': 2, 'confidence': 2, 'wealth': 2, 'Congress': 4, 'union--cordial': 1, 'encroachments': 1, 'legislation': 1, 'alleged': 
': 2, 'expectations': 1, 'forms': 2, 'absence': 1, 'production': 1, 'origination': 1, 'nation': 2, 'effects': 3, 'hands': 4, 'day': 1, 'name': 2, 'instances': 1, 'servant': 1, 'safe-keeping': 1, 'magnitude': 1, 'mode': 2, 'quarter': 1, 'instrumentality': 1, 'principles': 4, 'Treasury': 4, 'operation': 1, 'restricted': 1, 'collisions': 1, 'amendatory': 1, 'independence': 1, 'veto': 5, 'free': 1, 'houses': 1, 'management': 3, 'advantages': 2, 'members': 1, 'enlightened': 1, 'care': 1, 'fiat': 1, 'allies': 1, 'service': 1, 'language': 2, 'days': 1, 'allied': 1, 'elective': 2, 'divorce': 2, 'neglect': 1, 'first': 1, 'preservation': 1, 'one': 2, 'embarrassed': 1, 'Territories': 1, 'defects': 1, 'pliant': 1, 'leaders': 1, 'legislative': 7, 'necessarily': 1, 'Congress': 1, 'leading': 2, 'system': 1, 'fiction': 1, 'master': 2, 'bitter': 1, 'aristocracy': 1, 'friend': 1, 'interests': 2, "'subjects'--in": 1, 'slaves--of': 1, 'part': 3, 'population': 1, 'framers': 3, 'second': 1, 'future': 1, 'contrary': 4, 'iron': 1, 'lover': 1, 'powers': 7, 'false': 2, 'lines': 1, 'modern': 1, 'mind': 1, 'defect': 1, 'appointing': 1, 'sincerity': 1, 'assurances': 1, 'people--a': 1, 'competency': 1, 'genuine': 2, 'latter': 4, 'officers': 1, 'majority': 3, 'subjects': 1, 'performance': 1, 'Legislature': 5, 'object': 1, 'most': 6, 'Chief': 1, 'immediate': 1, 'letter': 1, 'engagements': 1, 'intrinsic': 1, 'proud': 1, 'formation': 2, 'principle': 2, 'enterprise': 1, 'institutions': 2, 'fact': 2, 'laws': 1, 'obligations': 1, 'purely': 1, 'corner': 1, 'principal': 1, 'title': 1, 'ruin': 1, 'treasure': 1, 'only': 3, 'rich': 1, 'local': 1, 'excision': 1, 'dominant': 1, 'means': 3, 'conduct': 1, 'prohibition': 1, 'joint': 1, 'mistaken': 1, 'words': 1, 'antagonist': 1, 'banking': 1, 'common': 1, 'House': 1, 'abodes': 1, 'District': 3, 'national': 2, 'labors': 2, 'potent': 1, 'individual': 2, 'result': 2, 'best': 3, 'subject': 2, 'state': 1, 'various': 1, 'injustice': 1, 'progress': 1, 'terms': 1, 'parent': 1, 'importance': 1, 'sole': 1, 'opposition': 1, 'article': 1, 'declining': 1, 'last': 1, 'country': 5, 'whole': 9, 'duty': 3, 'statues': 1, 'extent': 3, 'period': 1, 'War': 1, 'custody': 1, 'forbearing': 1, 'source': 2, 'addition': 1, 'confident': 1, 'complicated': 1, 'motives': 1, 'employments': 1, ' ...
#
#
# ** Current word:
# power
# ** Dictionary of words that follow the current word:
# {'and': 1, 'limited': 1, 'withheld': 1, 'is': 2, 'in': 3, 'claimed': 1, 'precisely': 1, 'established': 1, 'given': 1, 'from': 1, 'also': 1, 'granted': 1, ',': 2, '.': 2, 'to': 11, 'which': 4, 'has': 1, 'not': 1, 'with': 1, 'on': 1, ':': 1, 'necessary': 1, 'of': 4, 'placed': 1, 'introduced': 1}
#
#
# ** Current word:
# which
# ** Dictionary of words that follow the current word:
# {'all': 1, 'appeared': 1, 'is': 2, 'arise': 1, 'it': 10, 'marked': 1, 'framed': 1, 'at': 1, 'have': 4, 'in': 2, 'operated': 1, 'our': 8, 'existed': 1, 'compose': 1, 'from': 1, 'violate': 1, 'for': 1, 'their': 2, 'States': 1, 'separate': 1, 'belong': 1, 'had': 3, ',': 2, 'I': 3, 'has': 5, 'was': 3, 'assumes': 1, 'He': 1, 'we': 1, 'that': 1, 'may': 4, 'formed': 1, 'they': 13, 'now': 1, 'those': 1, 'he': 2, 'treats': 1, 'might': 1, 'appertain': 1, 'flow': 1, 'thousands': 1, 'will': 1, 'can': 1, 'of': 1, 'the': 10, 'are': 3}
#
#
# ** Current word:
# it
# ** Dictionary of words that follow the current word:
# {'and': 1, 'features': 1, 'is': 15, 'leads': 1, 'as': 1, 'grants': 1, 'employs': 1, 'should': 1, 'any': 1, 'really': 1, 'by': 1, 'behooves': 1, 'agreeably': 1, 'would': 2, 'secured': 1, 'had': 2, ',': 1, 'exclusively': 1, '.': 2, 'to': 3, 'does': 1, 'brings': 1, 'if': 1, 'was': 4, 'gives': 1, 'shall': 1, 'may': 4, 'becomes': 2, 'continues': 1, 'certainly': 1, 'possible': 1, 'approaches': 1, 'regards': 1, 'immediately': 1, 'appears': 4, 'must': 1, 'has': 4, 'might': 1, 'depends': 1, 'will': 4, 'can': 1, 'the': 2, 'makes': 1, 'finds': 1}
#
#
# ** Current word:
# will
# ** Dictionary of words that follow the current word:
# {'and': 1, 'be': 3, 'scarcely': 1, 'detect': 1, 'confirm': 1, 'I': 1, 'of': 1, 'prove': 1, 'soon': 1, 'ensue': 1, '.': 2, 'fly': 1, 'without': 1, 'restore': 1, 'bear': 1, 'govern': 1, 'not': 2, 'the': 2, 'has': 1, 'ever': 2, 'than': 1}
#
#
# ** Current word:
# govern
# ** Dictionary of words that follow the current word:
# {'me': 1, 'and': 1, 'is': 1, ',': 1}
#
#
# ** Current word:
# ,
# ** Dictionary of words that follow the current word:
# {'all': 1, 'particularly': 1, 'vindictive': 1, 'discord': 1, 'being': 2, 'indeed': 6, 'executive': 1, 'domestic': 1, 'produced': 1, 'whilst': 3, 'still': 1, 'religious': 1, 'one': 2, 'had': 1, 'except': 1, 'supported': 1, 'to': 12, 'believing': 1, 'must': 2, 'then': 2, 'his': 1, 'they': 2, 'not': 10, 'quadrupled': 1, 'nor': 2, 'possess': 1, 'like': 2, 'calling': 1, 'these': 1, 'continue': 1, 'either': 1, 'each': 1, 'accompanied': 1, 'compensated': 1, 'often': 1, 'some': 1, 'State': 1, 'are': 3, 'inflict': 1, 'separating': 1, 'even': 1, 'living': 1, 'for': 5, 'since': 2, 'unalienable': 1, 'enough': 1, 'does': 1, 'assuming': 1, 'seeks': 1, 'be': 1, 'we': 2, 'bold': 1, 'never': 1, 'prescribe': 1, 'however': 12, 'disputes': 1, 'let': 1, 'although': 2, 'become': 1, 'unrestrained': 1, 'by': 3, 'change': 1, 'suggested': 1, 'on': 2, 'great': 1, 'impose': 1, 'many': 1, 'could': 1, 'citizens': 1, 'leaving': 1, 'became': 1, 'or': 4, 'duty': 1, 'within': 1, 'hitherto': 1, 'given': 1, 'ancient': 1, 'from': 3, 'would': 1, 'strictly': 1, 'there': 3, 'predictions': 1, 'fellow-citizens': 3, 'appears': 1, 'thirdly': 1, 'therefore': 3, 'was': 1, 'persevering': 1, 'too': 2, 'offer': 1, 'that': 16, 'protect': 1, 'but': 17, 'approving': 1, 'consolatory': 1, 'with': 2, 'than': 1, 'those': 2, 'he': 1, 'none': 1, 'this': 2, 'avoiding': 1, 'will': 2, 'placed': 1, 'can': 1, 'of': 7, 'and': 72, 'violence': 1, 'have': 2, 'is': 5, 'it': 17, 'as': 14, 'warning': 1, 'at': 1, 'fashioned': 1, 'in': 12, 'fraternal': 1, 'if': 5, 'selfish': 1, 'no': 7, 'whereas': 1, 'silenced': 1, 'how': 1, 'virtually': 1, 'which': 3, 'grows': 1, 'may': 1, 'I': 10, 'who': 3, 'confiding': 1, 'nothing': 2, 'a': 3, 'so': 3, 'alienation': 1, 'embracing': 1, 'the': 18, 'having': 1}
#
#
# ** Current word:
# discord
# ** Dictionary of words that follow the current word:
# {'.': 1, ',': 1, 'between': 1}
#
#
# ** Current word:
# between
# ** Dictionary of words that follow the current word:
# {'these': 1, 'them': 1, 'the': 4, 'free': 1, 'all': 1}
#
#
# ** Current word:
# all
# ** Dictionary of words that follow the current word:
# {'and': 1, 'such': 1, 'necessary': 2, 'that': 1, 'future': 1, ',': 1, 'its': 2, 'well-established': 1, 'parts': 1, 'mischievous': 1, 'are': 1, 'others': 1, 'our': 1, 'the': 13, '.': 1, 'true': 2, 'other': 1, 'those': 1, 'laws': 1}
#
#
# ** Current word:
# the
# ** Dictionary of words that follow the current word:
# {'limited': 1, 'partial': 1, 'bosoms': 2, 'existing': 1, 'scheming': 1, 'oaths': 1, 'devoted': 1, 'former': 5, 'Union': 4, 'sovereignty': 1, 'pledges': 1, 'virtuous': 1, 'very': 2, 'results': 2, 'liability': 1, 'worst': 1, 'gratification': 1, 'fullest': 1, 'governments': 1, 'entire': 1, 'unhallowed': 1, 'accumulation': 1, 'pledge': 2, 'State': 5, 'defender': 1, 'further': 1, 'General': 3, 'residue': 1, 'errors': 1, 'annals': 1, 'capital': 1, 'ground': 1, 'public': 8, 'exercise': 2, 'body': 1, 'Presidency': 1, 'eligibility': 1, 'desired': 1, 'objects': 1, 'others': 2, 'Commonwealth': 2, 'great': 8, 'forum': 1, 'unwillingness': 1, 'larger': 1, 'guilty': 1, 'experience': 1, 'amount': 2, 'opinion': 2, 'honor': 1, 'mutual': 1, 'beautiful': 1, 'love': 3, 'Constitution': 32, 'danger': 2, 'enactment': 1, 'defense': 2, 'patriots': 1, 'Utopian': 1, 'sanction': 1, 'Armies': 1, 'use': 1, 'sake': 2, 'positive': 1, 'predictions': 1, 'more': 2, '
 'result': 2, 'best': 3, 'subject': 2, 'state': 1, 'various': 1, 'injustice': 1, 'progress': 1, 'terms': 1, 'parent': 1, 'importance': 1, 'sole': 1, 'opposition': 1, 'article': 1, 'declining': 1, 'last': 1, 'country': 5, 'whole': 9, 'duty': 3, 'statues': 1, 'extent': 3, 'period': 1, 'War': 1, 'custody': 1, 'forbearing': 1, 'source': 2, 'addition': 1, 'confident': 1, 'complicated': 1, 'motives': 1, 'employments': 1, ' ...
#
#
# ** Current word:
# origination
# ** Dictionary of words that follow the current word:
# {'of': 1}
#
#
# ** Current word:
# of
# ** Dictionary of words that follow the current word:
# {'exclusive': 1, 'all': 9, 'gold': 1, 'discord': 2, 'being': 1, 'devising': 1, 'country': 1, 'course': 2, 'civilized': 1, 'Caesar': 1, 'religious': 1, 'its': 16, 'Independence': 1, 'perfect': 1, 'death': 1, 'Columbia': 2, 'justice': 1, ',': 1, 'Camillus': 1, 'removal': 2, 'arresting': 1, 'candidates': 1, 'policy': 1, 'pending': 1, 'division': 1, 'them': 5, 'his': 4, 'appointment': 1, 'finance': 1, 'government': 4, 'conduct': 1, 'unlimited': 1, 'republics': 1, 'every': 4, 'half': 1, 'combinations': 1, 'one': 6, 'shaping': 1, 'condition': 1, 'Representatives': 1, 'England': 1, 'ascertaining': 1, 'public': 1, 'these': 5, 'distrust': 1, 'each': 5, 'mine': 2, 'upward': 1, 'superintendent': 1, 'concord': 1, 'intelligence': 1, 'violated': 1, 'some': 2, 'principles': 1, 'our': 29, 'freedom': 1, 'business': 1, 'giving': 1, 'liberty': 10, 'worship': 1, 'disunion': 1, 'unalienable': 1, 'investigation': 1, 'designing': 1, 'all--or': 1, 'checks': 1, 'supporting': 1, 'power': 16, 'men': 1, 'free': 1, 'difficulty': 1, 'Scythia': 1, 'Mr': 1, 'both': 1, 'great': 3, 'her': 3, 'language': 1, 'conformity': 2, 'citizens': 2, 'minorities': 1, 'products': 1, 'mixed': 1, 'protector': 1, 'duty': 1, 'revenue': 1, 'civil': 2, 'political': 2, 'two': 2, 'faction--a': 1, 'another': 2, 'confidence': 2, 'wealth': 2, 'Congress': 4, 'union--cordial': 1, 'encroachments': 1, 'legislation': 1, 'alleged': 1, '.': 1, 'their': 18, 'much': 1, 'interest': 2, 'dangers': 1, 'aristocracy': 1, 'interests': 1, 'vigilance': 1, 'that': 18, "men's": 1, 'wisdom': 1, 'moderation': 1, 'two-thirds': 1, 'freemen': 1, 'those': 8, 'usury': 1, 'keeping': 2, 'Congress--that': 1, 'this': 6, 'limit': 1, 'theirs': 1, 'making': 1, 'feeling': 1, 'powers': 2, 'devotion': 1, 'and': 1, 'soil': 1, 'correction': 1, 'mind': 1, 'Athens': 2, 'an': 4, 'high': 1, 'despotism': 1, 'want': 2, 'my': 9, 'any': 9, 'Parliament': 1, 'democracy': 2, 'no': 5, 'sufferings': 1, 'things': 3, 'speculative': 1, 'Columbia?': 1, 'other': 2, 'which': 3, 'party': 2, 'you': 1, 'many': 3, 'measures': 1, 'British': 1, 'such': 4, 'law': 2, 'a': 22, 'hasty': 1, 'Executive': 2, 'constitutional': 1, 'propriety': 1, 'ultimate': 1, 'Greece': 1, 'the': 212}
#
#
# ** Current word:
# our
# ** Dictionary of words that follow the current word:
# {'duty': 1, 'own': 2, 'constant': 1, 'Constitution': 2, 'people': 2, 'fathers': 1, 'domestic': 1, 'souls': 1, 'countrymen': 1, 'relations': 1, 'forums': 1, 'best': 1, 'statesmen': 1, 'ancestors': 2, 'intercourse': 1, 'Government': 4, 'system': 6, 'fellow-citizens': 1, 'Confederacy': 1, 'beloved': 1, 'Declaration': 1, 'aboriginal': 1, 'sovereignty': 1, 'constitutions': 1, 'parent': 1, 'free': 1, 'most': 1, 'Chief': 1, 'republican': 1, 'extensive': 1, 'great': 1, 'actual': 1, 'Capitol': 1, 'country': 5, 'citizens': 2, 'constitutional': 1, 'American': 1, 'foreign': 1, 'States': 1, 'honor': 1, 'antifederal': 1, 'institutions': 3}
#
#
# ** Current word:
# ancestors
# ** Dictionary of words that follow the current word:
# {'so': 1, 'derived': 1}
#
#
# ** Current word:
# so
# ** Dictionary of words that follow the current word:
# {'powerful': 1, 'marked': 1, ',': 1, 'as': 1, 'zealously': 1, 'apparently': 1, 'constituted': 1, 'extensively': 1, 'long': 1, '.': 1, 'happily': 1, 'much': 2, 'under': 1, 'extensive': 1, 'has': 1, 'emphatically': 1, 'far': 2, 'important': 1, 'distinctly': 1, 'awful': 1, 'gloriously': 1, 'great': 1, 'short': 1, 'many': 1}
#
#
# ** Current word:
# long
# ** Dictionary of words that follow the current word:
# {'continuance': 1, 'will': 1, 'as': 2, 'exist': 1}
#
#
# ** Current word:
# exist
# ** Dictionary of words that follow the current word:
# {'to': 1, 'without': 1, '.': 1, 'in': 1}
#
#
# ** Current word:
# to
# ** Dictionary of words that follow the current word:
# {'all': 4, 'bring': 2, 'its': 4, 'whose': 1, 'varnish': 1, 'believe': 1, 'decay': 1, 'encourage': 1, 'realize': 1, 'arrest': 1, 'shout': 1, 'betray': 1, 'do': 1, 'them': 5, 'his': 5, 'return': 1, 'greater': 1, 'propose': 2, 'matters': 1, 'decide': 1, 'govern': 2, 'him': 1, 'remove': 1, 'leave': 1, 'continue': 1, 'contain': 1, 'become': 1, 'disparage': 1, 'prevent': 3, 'constitute': 2, 'see': 1, 'expect': 1, 'pass': 1, 'our': 5, 'accomplish': 1, 'for': 1, 'liberty': 3, 'propitiate': 1, 'increase': 2, 'state': 1, 'suppose': 1, 'public': 1, 'preserve': 2, 'be': 26, 'disfigure': 1, 'power': 1, 'monarchy': 1, 'communicate': 1, 'others': 2, 'both': 1, 'protect': 1, 'her': 1, 'receive': 1, 'keep': 3, 'union': 1, 'place': 1, 'commit': 2, 'secure': 1, 'revenue': 1, ',': 1, 'administer': 1, 'guard': 1, 'promise': 1, 'enumerate': 1, 'carry': 2, 'apply': 3, 'your': 1, 'use': 1, 'Congress': 4, 'whom': 3, 'stamp': 1, 'create': 2, 'their': 7, 'doubt': 
 1, 'forms': 2, 'absence': 1, 'production': 1, 'origination': 1, 'nation': 2, 'effects': 3, 'hands': 4, 'day': 1, 'name': 2, 'instances': 1, 'servant': 1, 'safe-keeping': 1, 'magnitude': 1, 'mode': 2, 'quarter': 1, 'instrumentality': 1, 'principles': 4, 'Treasury': 4, 'operation': 1, 'restricted': 1, 'collisions': 1, 'amendatory': 1, 'independence': 1, 'veto': 5, 'free': 1, 'houses': 1, 'management': 3, 'advantages': 2, 'members': 1, 'enlightened': 1, 'care': 1, 'fiat': 1, 'allies': 1, 'service': 1, 'language': 2, 'days': 1, 'allied': 1, 'elective': 2, 'divorce': 2, 'neglect': 1, 'first': 1, 'preservation': 1, 'one': 2, 'embarrassed': 1, 'Territories': 1, 'defects': 1, 'pliant': 1, 'leaders': 1, 'legislative': 7, 'necessarily': 1, 'Congress': 1, 'leading': 2, 'system': 1, 'fiction': 1, 'master': 2, 'bitter': 1, 'aristocracy': 1, 'friend': 1, 'interests': 2, "'subjects'--in": 1, 'slaves--of': 1, 'part': 3, 'population': 1, 'framers': 3, 'second': 1, 'future': 1, 'contrary': 4, 'iron': 1, 'lover': 1, 'powers': 7, 'false': 2, 'lines': 1, 'modern': 1, 'mind': 1, 'defect': 1, 'appointing': 1, 'sincerity': 1, 'assurances': 1, 'people--a': 1, 'competency': 1, 'genuine': 2, 'latter': 4, 'officers': 1, 'majority': 3, 'subjects': 1, 'performance': 1, 'Legislature': 5, 'object': 1, 'most': 6, 'Chief': 1, 'immediate': 1, 'letter': 1, 'engagements': 1, 'intrinsic': 1, 'proud': 1, 'formation': 2, 'principle': 2, 'enterprise': 1, 'institutions': 2, 'fact': 2, 'laws': 1, 'obligations': 1, 'purely': 1, 'corner': 1, 'principal': 1, 'title': 1, 'ruin': 1, 'treasure': 1, 'only': 3, 'rich': 1, 'local': 1, 'excision': 1, 'dominant': 1, 'means': 3, 'conduct': 1, 'prohibition': 1, 'joint': 1, 'mistaken': 1, 'words': 1, 'antagonist': 1, 'banking': 1, 'common': 1, 'House': 1, 'abodes': 1, 'District': 3, 'national': 2, 'labors': 2, 'potent': 1, 'individual': 2, 'result': 2, 'best': 3, 'subject': 2, 'state': 1, 'various': 1, 'injustice': 1, 'progress': 1, 'terms': 1, 'parent': 1, 'importance': 1, 'sole': 1, 'opposition': 1, 'article': 1, 'declining': 1, 'last': 1, 'country': 5, 'whole': 9, 'duty': 3, 'statues': 1, 'extent': 3, 'period': 1, 'War': 1, 'custody': 1, 'forbearing': 1, 'source': 2, 'addition': 1, 'confident': 1, 'complicated': 1, 'motives': 1, 'employments': 1, ' ...
#
#
# ** Current word:
# state
# ** Dictionary of words that follow the current word:
# {'of': 6, 'in': 1}
#
#
# ** Current word:
# of
# ** Dictionary of words that follow the current word:
ecism': 1, 'free': 3, 'vestige': 1, 'great': 3, 'country': 1, 'monarchical': 1, 'larger': 1, 'Roman': 2, 'settled': 1, 'duty': 1, 'simple': 1, 'usurpation': 1, 'period': 2, 'community': 1, 'one': 1, 'formidable': 1, 'vote': 1, 'petty': 1, 'reference': 1, 'strict': 1, 'union': 1, 'custom': 1, 'breath': 1, 'few': 2, 'too': 1, 'privilege': 1, 'calm': 1, 'fund': 1, 'part': 3, 'rigid': 1, 'magnanimous': 1, 'surrender': 1, 'spirit': 4, 'Secretary': 1, 'case': 1, 'dangerous': 1, 'bill': 1, 'matter': 1, 'supposed': 1, 'similar': 2, 'distinguished': 1, 'weaker': 1, 'century': 1, 'process': 2, 'discrepancy': 1, 'general': 2, 'single': 2, 'despotism': 1, 'manner': 1, 'variety': 1, 'thorough': 2, 'member': 1, 'majority': 1, 'republic': 2, 'President': 1, 'most': 2, 'moment': 1, 'delicate': 1, 'significant': 1, 'man': 1, 'thought': 1}
#
#
# ** Current word:
# consolidated
# ** Dictionary of words that follow the current word:
# {'power': 1}
#
#
# ** Current word:
# power
# ** Dictionary of words that follow the current word:
# {'and': 1, 'limited': 1, 'withheld': 1, 'is': 2, 'in': 3, 'claimed': 1, 'precisely': 1, 'established': 1, 'given': 1, 'from': 1, 'also': 1, 'granted': 1, ',': 2, '.': 2, 'to': 11, 'which': 4, 'has': 1, 'not': 1, 'with': 1, 'on': 1, ':': 1, 'necessary': 1, 'of': 4, 'placed': 1, 'introduced': 1}
#
#
# ** Current word:
# which
# ** Dictionary of words that follow the current word:
# {'all': 1, 'appeared': 1, 'is': 2, 'arise': 1, 'it': 10, 'marked': 1, 'framed': 1, 'at': 1, 'have': 4, 'in': 2, 'operated': 1, 'our': 8, 'existed': 1, 'compose': 1, 'from': 1, 'violate': 1, 'for': 1, 'their': 2, 'States': 1, 'separate': 1, 'belong': 1, 'had': 3, ',': 2, 'I': 3, 'has': 5, 'was': 3, 'assumes': 1, 'He': 1, 'we': 1, 'that': 1, 'may': 4, 'formed': 1, 'they': 13, 'now': 1, 'those': 1, 'he': 2, 'treats': 1, 'might': 1, 'appertain': 1, 'flow': 1, 'thousands': 1, 'will': 1, 'can': 1, 'of': 1, 'the': 10, 'are': 3}
#
#
# ** Current word:
# separate
# ** Dictionary of words that follow the current word:
# {'States': 1, 'their': 1, 'members': 1}
#
#
# ** Current word:
# their
# ** Dictionary of words that follow the current word:
# {'wishes': 1, 'own': 11, 'financial': 1, 'partiality': 1, 'being': 1, 'fears': 1, 'fellow-citizens?': 1, 'direction': 1, 'appropriate': 1, 'alliance': 1, 'agents': 1, 'usefulness': 1, 'best': 2, 'affairs': 3, 'respective': 2, 'rapid': 1, 'defective': 1, 'deliberate': 1, 'sufferings': 1, 'affections': 1, 'political': 2, 'ideas': 1, 'peculiar': 1, 'subjects': 1, 'systems': 1, 'commissions': 1, 'performance': 1, 'interference': 1, 'attention': 1, 'management': 1, 'decline': 1, 'credit': 1, 'share': 1, 'advice': 1, 'measures': 1, 'passions': 2, 'free': 1, 'hoards': 1, 'liberties': 1, 'persons': 1, 'American': 1, 'part': 2, 'flatterer': 1, 'engagements': 1, 'tendencies': 1, 'former': 2, "subjects'": 1, 'writings': 1, 'intercourse': 1, 'rights': 3, 'country': 2, 'industry': 1, 'Chief': 1, 'will': 1, 'union': 1, 'construction': 1, 'pockets': 1, 'countrymen': 1, 'powers': 1}
#
#
# ** Current word:
# subjects'
# ** Dictionary of words that follow the current word:
# {'in': 1}
#
#
# ** Current word:
# in
# ** Dictionary of words that follow the current word:
# {'conceiving': 1, 'all': 2, 'modern': 1, 'some': 1, 'it': 1, 'an': 1, 'direct': 1, 'as': 1, 'consummating': 1, 'relation': 5, 'recommending': 1, 'principle': 1, 'our': 4, 'its': 6, 'perfect': 1, 'different': 1, 'no': 1, 'acts': 1, 'legislation': 1, 'obedience': 1, 'virtual': 1, 'any': 1, 'their': 8, 'attributing': 1, 'distinguishing': 1, 'harmony': 1, 'which': 3, 'war': 1, 'exercising': 1, 'particular': 1, 'his': 4, 'expressing': 1, 'that': 2, 'domestic': 1, 'mine': 1, 'feelings': 1, 'Chief': 1, 'part': 2, 'every': 2, 'two': 1, 'fervently': 1, 'Mr': 1, 'such': 1, 'one': 3, 'a': 4, 'advance': 1, 'England': 1, 'contradistinction': 1, 'language': 1, 'accordance': 1, 'this': 2, 'many': 2, 'elections': 1, 'times': 1, 'amount': 1, 'Gaul': 1, 'excellence': 1, 'common': 1, 'controlling': 2, 'the': 62, 'my': 5, 'drawing': 1, 'periods': 1}
#
#
# ** Current word:
# the
# ** Dictionary of words that follow the current word:
# {'limited': 1, 'partial': 1, 'bosoms': 2, 'existing': 1, 'scheming': 1, 'oaths': 1, 'devoted': 1, 'former': 5, 'Union': 4, 'sovereignty': 1, 'pledges': 1, 'virtuous': 1, 'very': 2, 'results': 2, 'liability': 1, 'worst': 1, 'gratification': 1, 'fullest': 1, 'governments': 1, 'entire': 1, 'unhallowed': 1, 'accumulation': 1, 'pledge': 2, 'State': 5, 'defender': 1, 'further': 1, 'General': 3, 'residue': 1, 'errors': 1, 'annals': 1, 'capital': 1, 'ground': 1, 'public': 8, 'exercise': 2, 'body': 1, 'Presidency': 1, 'eligibility': 1, 'desired': 1, 'objects': 1, 'others': 2, 'Commonwealth': 2, 'great': 8, 'forum': 1, 'unwillingness': 1, 'larger': 1, 'guilty': 1, 'experience': 1, 'amount': 2, 'opinion': 2, 'honor': 1, 'mutual': 1, 'beautiful': 1, 'love': 3, 'Constitution': 32, 'danger': 2, 'enactment': 1, 'defense': 2, 'patriots': 1, 'Utopian': 1, 'sanction': 1, 'Armies': 1, 'use': 1, 'sake': 2, 'positive': 1, 'predictions': 1, 'more': 2, 'possession': 1, 'patronage': 1, 'spoils': 1, 'reign': 1, 'ambition': 1, 'American': 1, 'controlling': 1, 'pretense': 1, 'circumstances': 3, 'Scipios': 1, 'rights': 3, 'lapse': 2, 'friendly': 1, 'forbearance': 1, 'control': 4, "'recommendations'":
#
#
# ** Current word:
# officers
# ** Dictionary of words that follow the current word:
# {'I': 1, 'who': 1, 'can': 1}
#
#
# ** Current word:
# I
# ** Dictionary of words that follow the current word:
# {'consider': 2, 'give': 1, 'apprehend': 1, 'consent': 1, 'am': 1, 'sincerely': 1, 'see': 1, 'deem': 1, 'have': 5, 'fear': 1, 'trust': 1, 'now': 1, 'appear': 1, 'had': 1, 'should': 2, 'too': 1, 'must': 1, 'refer': 1, 'shall': 5, 'may': 1, 'propose': 1, 'know': 1, 'believe': 2, 'proceed': 2, 'wish': 1, 'conceive': 3, 'assure': 1, 'can': 3, 'possess': 1}
#
#
# ** Current word:
# conceive
# ** Dictionary of words that follow the current word:
# {'to': 1, 'of': 1, ',': 2, 'that': 1}
#
#
# ** Current word:
# ,
# ** Dictionary of words that follow the current word:
# {'all': 1, 'particularly': 1, 'vindictive': 1, 'discord': 1, 'being': 2, 'indeed': 6, 'executive': 1, 'domestic': 1, 'produced': 1, 'whilst': 3, 'still': 1, 'religious': 1, 'one': 2, 'had': 1, 'except': 1, 'supported': 1, 'to': 12, 'believing': 1, 'must': 2, 'then': 2, 'his': 1, 'they': 2, 'not': 10, 'quadrupled': 1, 'nor': 2, 'possess': 1, 'like': 2, 'calling': 1, 'these': 1, 'continue': 1, 'either': 1, 'each': 1, 'accompanied': 1, 'compensated': 1, 'often': 1, 'some': 1, 'State': 1, 'are': 3, 'inflict': 1, 'separating': 1, 'even': 1, 'living': 1, 'for': 5, 'since': 2, 'unalienable': 1, 'enough': 1, 'does': 1, 'assuming': 1, 'seeks': 1, 'be': 1, 'we': 2, 'bold': 1, 'never': 1, 'prescribe': 1, 'however': 12, 'disputes': 1, 'let': 1, 'although': 2, 'become': 1, 'unrestrained': 1, 'by': 3, 'change': 1, 'suggested': 1, 'on': 2, 'great': 1, 'impose': 1, 'many': 1, 'could': 1, 'citizens': 1, 'leaving': 1, 'became': 1, 'or': 4, 'duty': 1, 'within': 1, 'hitherto': 1, 'given': 1, 'ancient': 1, 'from': 3, 'would': 1, 'strictly': 1, 'there': 3, 'predictions': 1, 'fellow-citizens': 3, 'appears': 1, 'thirdly': 1, 'therefore': 3, 'was': 1, 'persevering': 1, 'too': 2, 'offer': 1, 'that': 16, 'protect': 1, 'but': 17, 'approving': 1, 'consolatory': 1, 'with': 2, 'than': 1, 'those': 2, 'he': 1, 'none': 1, 'this': 2, 'avoiding': 1, 'will': 2, 'placed': 1, 'can': 1, 'of': 7, 'and': 72, 'violence': 1, 'have': 2, 'is': 5, 'it': 17, 'as': 14, 'warning': 1, 'at': 1, 'fashioned': 1, 'in': 12, 'fraternal': 1, 'if': 5, 'selfish': 1, 'no': 7, 'whereas': 1, 'silenced': 1, 'how': 1, 'virtually': 1, 'which': 3, 'grows': 1, 'may': 1, 'I': 10, 'who': 3, 'confiding': 1, 'nothing': 2, 'a': 3, 'so': 3, 'alienation': 1, 'embracing': 1, 'the': 18, 'having': 1}
#
#
# ** Current word:
# for
# ** Dictionary of words that follow the current word:
# {'all': 1, 'schemes': 1, 'certain': 1, 'ages': 1, 'purposes': 1, 'one': 1, 'no': 2, 'their': 3, 'other': 1, 'which': 5, 'conferring': 1, 'so': 1, 'injury': 1, 'immutable': 1, 'his': 2, 'some': 1, 'misunderstanding': 1, 'every': 1, 'by': 1, 'a': 4, 'talent': 1, 'unhallowed': 1, 'annual': 1, 'generosity': 1, 'offices': 1, 'the': 16}
#
#
# ** Current word:
# so
# ** Dictionary of words that follow the current word:
# {'powerful': 1, 'marked': 1, ',': 1, 'as': 1, 'zealously': 1, 'apparently': 1, 'constituted': 1, 'extensively': 1, 'long': 1, '.': 1, 'happily': 1, 'much': 2, 'under': 1, 'extensive': 1, 'has': 1, 'emphatically': 1, 'far': 2, 'important': 1, 'distinctly': 1, 'awful': 1, 'gloriously': 1, 'great': 1, 'short': 1, 'many': 1}
#
#
# ** Current word:
# long
# ** Dictionary of words that follow the current word:
# {'continuance': 1, 'will': 1, 'as': 2, 'exist': 1}
#
#
# ** Current word:
# as
# ** Dictionary of words that follow the current word:
# {'all': 1, 'is': 1, 'it': 5, 'an': 1, 'are': 1, 'in': 3, 'any': 1, 'respects': 1, 'collisions': 2, 'long': 2, 'its': 1, 'to': 11, 'fatal': 1, 'power': 1, 'that': 1, 'I': 2, 'meaning': 1, 'regards': 1, 'they': 1, 'affording': 1, 'those': 1, 'a': 5, 'this': 1, 'of': 1, 'citizens': 1, 'well': 7, 'summary': 1, 'effectual': 1, 'far': 1, 'the': 10, 'settled': 1}
#
#
# ** Current word:
# to
# ** Dictionary of words that follow the current word:
# {'all': 4, 'bring': 2, 'its': 4, 'whose': 1, 'varnish': 1, 'believe': 1, 'decay': 1, 'encourage': 1, 'realize': 1, 'arrest': 1, 'shout': 1, 'betray': 1, 'do': 1, 'them': 5, 'his': 5, 'return': 1, 'greater': 1, 'propose': 2, 'matters': 1, 'decide': 1, 'govern': 2, 'him': 1, 'remove': 1, 'leave': 1, 'continue': 1, 'contain': 1, 'become': 1, 'disparage': 1, 'prevent': 3, 'constitute': 2, 'see': 1, 'expect': 1, 'pass': 1, 'our': 5, 'accomplish': 1, 'for': 1, 'liberty': 3, 'propitiate': 1, 'increase': 2, 'state': 1, 'suppose': 1, 'public': 1, 'preserve': 2, 'be': 26, 'disfigure': 1, 'power': 1, 'monarchy': 1, 'communicate': 1, 'others': 2, 'both': 1, 'protect': 1, 'her': 1, 'receive': 1, 'keep': 3, 'union': 1, 'place': 1, 'commit': 2, 'secure': 1, 'revenue': 1, ',': 1, 'administer': 1, 'guard': 1, 'promise': 1, 'enumerate': 1, 'carry': 2, 'apply': 3, 'your': 1, 'use': 1, 'Congress': 4, 'whom': 3, 'stamp': 1, 'create': 2, 'their': 7, 'doubt': 1, 'intrust': 1, 'recommend': 2, 'that': 6, 'afford': 1, 'serve': 1, 'yield': 1, 'favorable': 1, 'surrender': 1, 'present': 1, 'me': 5, 'none': 1, 'us': 1, 'cast': 1, 'limit': 1, 'those': 1, 'fulfill': 1, 'my': 4, 'declare': 1, 'result': 1, 'control': 3, 'gather': 1, 'give': 1, 'it': 2, 'deprive': 1, 'say': 3, 'exist': 1, 'have': 7, 'cultivate': 1, 'any': 2, 'condemn': 1, 'Parliament': 1, 'democracy': 1, 'grant': 2, 'perform': 2, 'make': 4, 'take': 1, 'which': 5, 'destroy': 1, 'you': 2, 'fill': 1, 'repeat': 1, 'upon': 1, "'despotism'": 1, 'reflect': 1, 'produce': 4, 'discharge': 1, 'manhood': 1, 'a': 8, 'discourage': 1, 'annul': 1, 'seize': 1, 'bind': 1, 'clear': 1, 'adopt': 2, 'provide': 1, 'allow': 1, 'the': 60, 'justify': 1, 'talk': 1, 'meet': 1}
#
#
# ** Current word:
# which
# ** Dictionary of words that follow the current word:
# {'all': 1, 'appeared': 1, 'is': 2, 'arise': 1, 'it': 10, 'marked': 1, 'framed': 1, 'at': 1, 'have': 4, 'in': 2, 'operated': 1, 'our': 8, 'existed': 1, 'compose': 1, 'from': 1, 'violate': 1, 'for': 1, 'their': 2, 'States': 1, 'separate': 1, 'belong': 1, 'had': 3, ',': 2, 'I': 3, 'has': 5, 'was': 3, 'assumes': 1, 'He': 1, 'we': 1, 'that': 1, 'may': 4, 'formed': 1, 'they': 13, 'now': 1, 'those': 1, 'he': 2, 'treats': 1, 'might': 1, 'appertain': 1, 'flow': 1, 'thousands': 1, 'will': 1, 'can': 1, 'of': 1, 'the': 10, 'are': 3}
#
#
# ** Current word:
# States
# ** Dictionary of words that follow the current word:
# {'and': 1, 'his': 1, 'form': 1, 'would': 1, 'may': 1, 'of': 1, 'is': 1, 'who': 1, ',': 4, 'accept': 1, '.': 4, 'to': 1, 'have': 1, 'the': 1, 'governments': 1, 'solely': 1, 'or': 1, 'first': 1}
#
#
# ** Current word:
# form
# ** Dictionary of words that follow the current word:
# {'a': 1, 'of': 1, 'in': 1}
#
#
# ** Current word:
# a
# ** Dictionary of words that follow the current word:
# ...
#
#
# ** Current word:
# be
# ** Dictionary of words that follow the current word:
# {'interpreted': 1, 'assigned': 1, 'effectually': 1, 'guaranteed': 1, ',': 2, 'destroyed': 1, 'to': 1, 'preserved': 1, 'overcome': 1, 'exchanged': 1, 'very': 1, 'denied': 1, 'not': 1, 'highly': 1, 'advanced': 1, 'sacrificed': 1, 'found': 5, 'exposed': 1, 'exerted': 1, 'some': 1, 'observed': 2, 'proper': 1, 'our': 1, 'said': 1, 'fraught': 1, 'content': 1, 'between': 1, 'overshadowed': 1, 'ascribed': 1, 'quite': 1, 'worthy': 1, 'permitted': 1, 'essentially': 1, 'deprecated': 1, 'attributed': 1, 'accomplished': 1, 'greatly': 1, 'introduced': 1, 'adapted': 1, 'one': 1, 'warped': 1, 'done': 1, 'your': 1, 'from': 1, 'strictly': 1, 'adopted': 1, 'cherished': 1, 'passed': 1, 'expected': 2, 'conformable': 1, 'more': 1, 'controlled': 1, 'that': 1, 'corrected': 1, 'applied': 1, 'made': 1, 'supposed': 1, 'of': 1, 'my': 1, 'called': 1, 'at': 1, 'an': 2, 'something': 1, 'in': 2, 'claimed': 1, 'effected': 3, 'thought': 2, 'productive': 1, 'no': 1, 'absorbed': 1, 'useless': 1, 'used': 4, 'exercised': 2, 'most': 1, 'a': 1, 'prescribed': 1, 'realized': 2, 'considered': 1, 'calculated': 1, 'interrupted': 1, 'looked': 1, 'ascertained': 1, 'so': 1, 'the': 4, 'true--and': 1, 'left': 1}
#
#
# ** Current word:
# found
# ** Dictionary of words that follow the current word:
# {'who': 1, 'powerful': 1, 'one': 1, 'to': 2, 'ineffectual': 1, 'in': 1}
#
#
# ** Current word:
# powerful
# ** Dictionary of words that follow the current word:
# {'fleet': 1, 'as': 1, 'nation': 1, 'in': 1}
#
#
# ** Current word:
# as
# ** Dictionary of words that follow the current word:
# {'all': 1, 'is': 1, 'it': 5, 'an': 1, 'are': 1, 'in': 3, 'any': 1, 'respects': 1, 'collisions': 2, 'long': 2, 'its': 1, 'to': 11, 'fatal': 1, 'power': 1, 'that': 1, 'I': 2, 'meaning': 1, 'regards': 1, 'they': 1, 'affording': 1, 'those': 1, 'a': 5, 'this': 1, 'of': 1, 'citizens': 1, 'well': 7, 'summary': 1, 'effectual': 1, 'far': 1, 'the': 10, 'settled': 1}
#
#
# ** Current word:
# is
# ** Dictionary of words that follow the current word:
# {'and': 1, 'full': 1, 'danger': 1, 'mainly': 1, 'an': 3, 'tendered': 1, 'mild': 1, 'owing': 1, 'at': 1, 'another': 1, 'in': 5, 'our': 1, 'still': 1, 'its': 1, 'intended': 1, 'one': 2, 'productive': 1, 'harsh': 1, 'for': 1, 'termed': 1, 'union': 1, 'with': 1, 'concerned': 1, ',': 5, 'also': 1, 'written': 1, 'unable': 1, 'complained': 1, 'suffered': 1, 'perfectly': 1, 'final': 1, 'more': 2, 'applied': 1, 'himself': 1, 'to': 2, 'that': 1, 'supposed': 1, 'not': 3, 'therefore': 1, 'preposterous': 1, 'true': 2, 'a': 6, 'anything': 1, 'no': 1, 'correct': 1, 'intangible': 1, 'obvious': 1, 'greatly': 1, 'the': 16, 'my': 1, 'called': 2, 'left': 1}
#
#
# ** Current word:
# a
# ** Dictionary of words that follow the current word:
# {'selection': 1, 'shield': 1, 'just': 2, 'sentence': 1, 'camp--that': 1, 'misconstruction': 2, 'tendency': 1, 'devoted': 1, 'retirement': 1, 'source': 1, 'consolidated': 1, 'sovereignty': 1, 'pleasing': 1, 'good': 1, 'dominant': 1, 'powerful': 1, 'party': 3, 'provision': 1, 'necessary': 1, 'profound': 1, 'summary': 1, 'bad': 1, 'common': 1, 'fair': 2, 'people': 2, 'motive': 1, 'second': 2, 'proper': 1, 'casual': 1, 'subject': 1, 'conservative': 1, 'state': 2, 'plural': 1, 'correct': 1, "citizen'": 1, 'full': 2, 'degree': 1, 'solecism': 1, 'free': 3, 'vestige': 1, 'great': 3, 'country': 1, 'monarchical': 1, 'larger': 1, 'Roman': 2, 'settled': 1, 'duty': 1, 'simple': 1, 'usurpation': 1, 'period': 2, 'community': 1, 'one': 1, 'formidable': 1, 'vote': 1, 'petty': 1, 'reference': 1, 'strict': 1, 'union': 1, 'custom': 1, 'breath': 1, 'few': 2, 'too': 1, 'privilege': 1, 'calm': 1, 'fund': 1, 'part': 3, 'rigid': 1, 'magnanimous': 1, 'surrender': 1, 'spirit': 4, 'Secretary': 1, 'case': 1, 'dangerous': 1, 'bill': 1, 'matter': 1, 'supposed': 1, 'similar': 2, 'distinguished': 1, 'weaker': 1, 'century': 1, 'process': 2, 'discrepancy': 1, 'general': 2, 'single': 2, 'despotism': 1, 'manner': 1, 'variety': 1, 'thorough': 2, 'member': 1, 'majority': 1, 'republic': 2, 'President': 1, 'most': 2, 'moment': 1, 'delicate': 1, 'significant': 1, 'man': 1, 'thought': 1}
#
#
# ** Current word:
# dominant
# ** Dictionary of words that follow the current word:
# {'passions': 1, 'passion': 1}
#
#
# ** Current word:
# passion
# ** Dictionary of words that follow the current word:
# {'of': 2, 'by': 1, 'once': 1}
#
#
# ** Current word:
# of
# ** Dictionary of words that follow the current word:
# {'exclusive': 1, 'all': 9, 'gold': 1, 'discord': 2, 'being': 1, 'devising': 1, 'country': 1, 'course': 2, 'civilized': 1, 'Caesar': 1, 'religious': 1, 'its': 16, 'Independence': 1, 'perfect': 1, 'death': 1, 'Columbia': 2, 'justice': 1, ',': 1, 'Camillus': 1, 'removal': 2, 'arresting': 1, 'candidates': 1, 'policy': 1, 'pending': 1, 'division': 1, 'them': 5, 'his': 4, 'appointment': 1, 'finance': 1, 'government': 4, 'conduct': 1, 'unlimited': 1, 'republics': 1, 'every': 4, 'half': 1, 'combinations': 1, 'one': 6, 'shaping': 1, 'condition': 1, 'Representatives': 1, 'England': 1, 'ascertaining': 1, 'public': 1, 'these': 5, 'distrust': 1, 'each': 5, 'mine': 2, 'upward': 1, 'superintendent': 1, 'concord': 1, 'intelligence': 1, 'violated': 1, 'some': 2, 'principles': 1, 'our': 29, 'freedom': 1, 'business': 1, 'giving': 1, 'liberty': 10, 'worship': 1, 'disunion': 1, 'unalienable': 1, 'investigation': 1, 'designing': 1, 'all--or': 1, 'checks': 1, 'supporting': 1, 'power': 16, 'men': 1, 'free': 1, 'difficulty': 1, 'Scythia': 1, 'Mr': 1, 'both': 1, 'great': 3, 'her': 3, 'language': 1, 'conformity': 2, 'citizens': 2, 'minorities': 1, 'products': 1, 'mixed': 1, 'protector': 1, 'duty': 1, 'revenue': 1, 'civil': 2, 'political': 2, 'two': 2, 'faction--a': 1, 'another': 2, 'confidence': 2, 'wealth': 2, 'Congress': 4, 'union--cordial': 1, 'encroachments': 1, 'legislation': 1, 'alleged': 1, '.': 1, 'their': 18, 'much': 1, 'interest': 2, 'dangers': 1, 'aristocracy': 1, 'interests': 1, 'vigilance': 1, 'that': 18, "men's": 1, 'wisdom': 1, 'moderation': 1, 'two-thirds': 1, 'freemen': 1, 'those': 8, 'usury': 1, 'keeping': 2, 'Congress--that': 1, 'this': 6, 'limit': 1, 'theirs': 1, 'making': 1, 'feeling': 1, 'powers': 2, 'devotion': 1, 'and': 1, 'soil': 1, 'correction': 1, 'mind': 1, 'Athens': 2, 'an': 4, 'high': 1, 'despotism': 1, 'want': 2, 'my': 9, 'any': 9, 'Parliament': 1, 'democracy': 2, 'no': 5, 'sufferings': 1, 'things': 3, 'speculative': 1, 'Columbia?': 1, 'other': 2, 'which': 3, 'party': 2, 'you': 1, 'many': 3, 'measures': 1, 'British': 1, 'such': 4, 'law': 2, 'a': 22, 'hasty': 1, 'Executive': 2, 'constitutional': 1, 'propriety': 1, 'ultimate': 1, 'Greece': 1, 'the': 212}
#
#
# ** Current word:
# their
# ** Dictionary of words that follow the current word:
# {'wishes': 1, 'own': 11, 'financial': 1, 'partiality': 1, 'being': 1, 'fears': 1, 'fellow-citizens?': 1, 'direction': 1, 'appropriate': 1, 'alliance': 1, 'agents': 1, 'usefulness': 1, 'best': 2, 'affairs': 3, 'respective': 2, 'rapid': 1, 'defective': 1, 'deliberate': 1, 'sufferings': 1, 'affections': 1, 'political': 2, 'ideas': 1, 'peculiar': 1, 'subjects': 1, 'systems': 1, 'commissions': 1, 'performance': 1, 'interference': 1, 'attention': 1, 'management': 1, 'decline': 1, 'credit': 1, 'share': 1, 'advice': 1, 'measures': 1, 'passions': 2, 'free': 1, 'hoards': 1, 'liberties': 1, 'persons': 1, 'American': 1, 'part': 2, 'flatterer': 1, 'engagements': 1, 'tendencies': 1, 'former': 2, "subjects'": 1, 'writings': 1, 'intercourse': 1, 'rights': 3, 'country': 2, 'industry': 1, 'Chief': 1, 'will': 1, 'union': 1, 'construction': 1, 'pockets': 1, 'countrymen': 1, 'powers': 1}
#
#
# ** Current word:
# Chief
# ** Dictionary of words that follow the current word:
# {'of': 1, 'Magistrate': 3}
#
#
# ** Current word:
# Magistrate
# ** Dictionary of words that follow the current word:
# {'of': 1, 'unworthy': 1, 'to': 1}
#
#
# ** Current word:
# unworthy
# ** Dictionary of words that follow the current word:
# {'of': 1}
#
#
# ** Current word:
# of
# ** Dictionary of words that follow the current word:
# {'exclusive': 1, 'all': 9, 'gold': 1, 'discord': 2, 'being': 1, 'devising': 1, 'country': 1, 'course': 2, 'civilized': 1, 'Caesar': 1, 'religious': 1, 'its': 16, 'Independence': 1, 'perfect': 1, 'death': 1, 'Columbia': 2, 'justice': 1, ',': 1, 'Camillus': 1, 'removal': 2, 'arresting': 1, 'candidates': 1, 'policy': 1, 'pending': 1, 'division': 1, 'them': 5, 'his': 4, 'appointment': 1, 'finance': 1, 'government': 4, 'conduct': 1, 'unlimited': 1, 'republics': 1, 'every': 4, 'half': 1, 'combinations': 1, 'one': 6, 'shaping': 1, 'condition': 1, 'Representatives': 1, 'England': 1, 'ascertaining': 1, 'public': 1, 'these': 5, 'distrust': 1, 'each': 5, 'mine': 2, 'upward': 1, 'superintendent': 1, 'concord': 1, 'intelligence': 1, 'violated': 1, 'some': 2, 'principles': 1, 'our': 29, 'freedom': 1, 'business': 1, 'giving': 1, 'liberty': 10, 'worship': 1, 'disunion': 1, 'unalienable': 1, 'investigation': 1, 'designing': 1, 'all--or': 1, 'checks': 1, 'supporting': 1, 'power': 16, 'men': 1, 'free': 1, 'difficulty': 1, 'Scythia': 1, 'Mr': 1, 'both': 1, 'great': 3, 'her': 3, 'language': 1, 'conformity': 2, 'citizens': 2, 'minorities': 1, 'products': 1, 'mixed': 1, 'protector': 1, 'duty': 1, 'revenue': 1, 'civil': 2, 'political': 2, 'two': 2, 'faction--a': 1, 'another': 2, 'confidence': 2, 'wealth': 2, 'Congress': 4, 'union--cordial': 1, 'encroachments': 1, 'legislation': 1, 'alleged': 1, '.': 1, 'their': 18, 'much': 1, 'interest': 2, 'dangers': 1, 'aristocracy': 1, 'interests': 1, 'vigilance': 1, 'that': 18, "men's": 1, 'wisdom': 1, 'moderation': 1, 'two-thirds': 1, 'freemen': 1, 'those': 8, 'usury': 1, 'keeping': 2, 'Congress--that': 1, 'this': 6, 'limit': 1, 'theirs': 1, 'making': 1, 'feeling': 1, 'powers': 2, 'devotion': 1, 'and': 1, 'soil': 1, 'correction': 1, 'mind': 1, 'Athens': 2, 'an': 4, 'high': 1, 'despotism': 1, 'want': 2, 'my': 9, 'any': 9, 'Parliament': 1, 'democracy': 2, 'no': 5, 'sufferings': 1, 'things': 3, 'speculative': 1, 'Columbia?': 1, 'other': 2, 'which': 3, 'party': 2, 'you': 1, 'many': 3, 'measures': 1, 'British': 1, 'such': 4, 'law': 2, 'a': 22, 'hasty': 1, 'Executive': 2, 'constitutional': 1, 'propriety': 1, 'ultimate': 1, 'Greece': 1, 'the': 212}
#
#
# ** Current word:
# the
# ** Dictionary of words that follow the current word:
# {'limited': 1, 'partial': 1, 'bosoms': 2, 'existing': 1, 'scheming': 1, 'oaths': 1, 'devoted': 1, 'former': 5, 'Union': 4, 'sovereignty': 1, 'pledges': 1, 'virtuous': 1, 'very': 2, 'results': 2, 'liability': 1, 'worst': 1, 'gratification': 1, 'fullest': 1, 'governments': 1, 'entire': 1, 'unhallowed': 1, 'accumulation': 1, 'pledge': 2, 'State': 5, 'defender': 1, 'further': 1, 'General': 3, 'residue': 1, 'errors': 1, 'annals': 1, 'capital': 1, 'ground': 1, 'public': 8, 'exercise': 2, 'body': 1, 'Presidency': 1, 'eligibility': 1, 'desired': 1, 'objects': 1, 'others': 2, 'Commonwealth': 2, 'great': 8, 'forum': 1, 'unwillingness': 1, 'larger': 1, 'guilty': 1, 'experience': 1, 'amount': 2, 'opinion': 2, 'honor': 1, 'mutual': 1, 'beautiful': 1, 'love': 3, 'Constitution': 32, 'danger': 2, 'enactment': 1, 'defense': 2, 'patriots': 1, 'Utopian': 1, 'sanction': 1, 'Armies': 1, 'use': 1, 'sake': 2, 'positive': 1, 'predictions': 1, 'more': 2, 'possession': 1, 'patronage': 1, 'sp
 2, 'state': 1, 'various': 1, 'injustice': 1, 'progress': 1, 'terms': 1, 'parent': 1, 'importance': 1, 'sole': 1, 'opposition': 1, 'article': 1, 'declining': 1, 'last': 1, 'country': 5, 'whole': 9, 'duty': 3, 'statues': 1, 'extent': 3, 'period': 1, 'War': 1, 'custody': 1, 'forbearing': 1, 'source': 2, 'addition': 1, 'confident': 1, 'complicated': 1, 'motives': 1, 'employments': 1, ' ...
#
#
# ** Current word:
# injustice
# ** Dictionary of words that follow the current word:
# {'and': 1}
#
#
# I have strictly observed . On an exclusive metallic currency . But if we want of the power which it will govern , discord between all the origination of our ancestors so long exist to the state of a consolidated power which separate their subjects' in the officers I conceive , for so long as to which States form a powerful as long as citizens . The cement which I shall be used with the joint councils of that the absence of you to be found powerful as is a dominant passion of their Chief Magistrate unworthy of the injustice

# %% [markdown]
# # 2. Implementing Markov Model for Wikipedia 6 degrees of seperation problem #

# %%
'''
This is an undirected graph problem. We will use the BFS approach.
'''
from urllib2 import urlopen
from bs4 import BeautifulSoup
import pymysql

# Connect to mysql
'''
Steps to connect to mysql:

1. sudo /usr/local/mysql/support-files/mysql.server restart
2. export PATH=$PATH:/usr/local/mysql/bin
3. $ echo $PATH
/Users/adarshnair/graphlab/anaconda/bin:
/Users/adarshnair/anaconda/bin:
/usr/local/bin:
/usr/bin:/bin:
/usr/sbin:
/sbin:
/usr/local/mysql/bin --> Make sure this is in your PATH.
4. mysql -u root -p 
5. Enter password: adarshpwd
'''
conn = pymysql.connect(host='127.0.0.1', 
                       port=3306, 
                       user='root', 
                       passwd='adarshpwd', 
                       db='mysql', 
                       charset='utf8')
cur = conn.cursor()
cur.execute("USE wikipedia")


'''
Retrieve URLs from the database, given the page id.
'''
def getUrl(pageId):
    cur.execute("SELECT url FROM pages WHERE id = %s", (int(pageId)))
    if cur.rowcount == 0:
        return None
    return cur.fetchone()[0]

def getLinks(fromPageId):
    cur.execute("SELECT toPageId FROM links WHERE fromPageId = %s", (int(fromPageId)))
    if cur.rowcount == 0:
        return None
    return [x[0] for x in cur.fetchall()]


'''
BFS: Recursively construct and search a tree of links.
'''
def searchBreadth(targetPageId, currentPageId, depth, nodes):
    if nodes is None or len(nodes) == 0:
        return None
    if depth <= 0:
        for node in nodes:
            if node == targetPageId:
                return [node]
        return None
    # depth is greater than 0 -- go deeper!
    '''
    Search all links that link directly to the starting page. If those links do not contain the target page, then 
    a second level of links(i.e. pages that are linked by a page that is linked by the starting page) is searched.
    This process continues until the depth limit(6) is reached or the target page is found.
    ''' 
    for node in nodes:
        # Recursive function call
        found = searchBreadth(targetPageId, node, depth-1, getLinks(node))
        if found is not None:
            return found.append(currentPageId)
    return None

# Get all outgoing page Ids
nodes = getLinks(1)

# Page Id we are looking to reach.
targetPageId = 123428

# Continue until we reach a depth of 5
for i in range(0,4):
    # 1 = current page id, i = current depth
    found = searchBreadth(targetPageId, 1, i, nodes)
    if found is not None:
        print(found)
        for node in found:
            print(getUrl(node))
        break
    else:
        print("No path found")
