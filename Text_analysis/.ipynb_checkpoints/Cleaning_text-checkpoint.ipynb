# %% [markdown]
# # Working with text data #

# %% [markdown]
# ## 1.0 n-gram in text data: A sequence of n words used in text ##

# %%
from urllib2 import urlopen
from bs4 import BeautifulSoup
import pprint
# get the sequence of n words
def getNgrams(input, n):
  input = input.split(' ')
  output = []
  # return words from the text in groups of n
  for i in range(len(input) - n+1):
    # 0:2, 1:3, 2:4...
    output.append(input[i : i+n])
  return output

html = urlopen("http://en.wikipedia.org/wiki/Python_(programming_language)")
bsObj = BeautifulSoup(html, "html.parser")

# Get the body of text without the HTML
content = bsObj.find("div", {"id":"mw-content-text"}).get_text()

# Split into 2 word groups
ngrams = getNgrams(content, 2)

pprint.pprint(ngrams)
print("2-grams count is: "+str(len(ngrams)))
# Out:
# [[u'This', u'article'],
#  [u'article', u'is'],
#  [u'is', u'about'],
#  [u'about', u'the'],
#  [u'the', u'programming'],
#  [u'programming', u'language.'],
#  [u'language.', u'For'],
#  [u'For', u'the'],
#  [u'the', u'snake'],
#  [u'snake', u'genus,'],
#  [u'genus,', u'see'],
#  [u'see', u'Python'],
#  [u'Python', u'(genus).'],
#  [u'(genus).', u'For'],
#  [u'For', u'other'],
#  [u'other', u'uses,'],
#  [u'uses,', u'see'],
#  [u'see', u'Python'],
#  [u'Python',
#   u'(disambiguation).\n\nPython\n\n\n\n\nParadigm\nmulti-paradigm:'],
#  [u'(disambiguation).\n\nPython\n\n\n\n\nParadigm\nmulti-paradigm:',
#   u'object-oriented,'],
#  [u'object-oriented,', u'imperative,'],
#  [u'imperative,', u'functional,'],
#  [u'functional,', u'procedural,'],
#  [u'procedural,', u'reflective\n\n\nDesigned\xa0by\nGuido'],
#  [u'reflective\n\n\nDesigned\xa0by\nGuido', u'van'],
#  [u'van', u'Rossum\n\n\nDeveloper\nPython'],
#  [u'Rossum\n\n\nDeveloper\nPython', u'Software'],
#  [u'Software', u'Foundation\n\n\nFirst\xa0appeared\n20\xa0February'],
#  [u'Foundation\n\n\nFirst\xa0appeared\n20\xa0February', u'1991;'],
#  [u'1991;', u'25'],
#  [u'25', u'years'],
#  [u'years', u'ago\xa0(1991-02-20)[1]\n\n\n\n\n\nStable'],
#  [u'ago\xa0(1991-02-20)[1]\n\n\n\n\n\nStable', u'release\n\n3.5.2'],
#  [u'release\n\n3.5.2', u'/'],
#  [u'/', u'27\xa0June'],
#  [u'27\xa0June', u'2016;'],
#  [u'2016;', u'3'],
#  [u'3', u'months'],
#  [u'months', u'ago\xa0(2016-06-27)[2]\n2.7.12'],
#  [u'ago\xa0(2016-06-27)[2]\n2.7.12', u'/'],
#  [u'/', u'28\xa0June'],
#  [u'28\xa0June', u'2016;'],
#  [u'2016;', u'3'],
#  [u'3', u'months'],
#  [u'months', u'ago\xa0(2016-06-28)[3]\n\n\n\nPreview'],
#  [u'ago\xa0(2016-06-28)[3]\n\n\n\nPreview', u'release\n\n3.6.0b1'],
#  [u'release\n\n3.6.0b1', u'/'],
#  [u'/', u'September\xa02016;'],
#  [u'September\xa02016;', u'1\xa0month'],
#  [u'1\xa0month', u'ago\xa0(2016-09)[4]\n\n\n\nTyping'],
#  [u'ago\xa0(2016-09)[4]\n\n\n\nTyping', u'discipline\nduck,'],
#  [u'discipline\nduck,', u'dynamic,'],
#  [u'dynamic,', u'strong,'],
#  [u'strong,', u'gradual'],
#  [u'gradual', u'(as'],
#  [u'(as', u'of'],
#  [u'of', u'Python'],
#  [u'Python', u'3.5)[5]\n\n\nOS\nCross-platform\n\n\nLicense\nPython'],
#  [u'3.5)[5]\n\n\nOS\nCross-platform\n\n\nLicense\nPython', u'Software'],
#  [u'Software', u'Foundation'],
#  [u'Foundation', u'License\n\n\nFilename'],
#  [u'License\n\n\nFilename', u'extensions\n.py,'],
#  [u'extensions\n.py,', u'.pyc,'],
#  [u'.pyc,', u'.pyd,'],
#  [u'.pyd,', u'.pyo,[6]'],
#  [u'.pyo,[6]', u'.pyw,'],
#  [u'.pyw,', u'.pyz[7]\n\n\nWebsite\nwww.python.org\n\n\nMajor'],
#  [u'.pyz[7]\n\n\nWebsite\nwww.python.org\n\n\nMajor',
#   u'implementations\n\n\nCPython,'],
#  [u'implementations\n\n\nCPython,', u'IronPython,'],
#  [u'IronPython,', u'Jython,'],
#  [u'Jython,', u'MicroPython,'],
#  [u'MicroPython,', u'PyPy\n\n\nDialects\n\n\nCython,'],
#  [u'PyPy\n\n\nDialects\n\n\nCython,', u'RPython,'],
#  [u'RPython,', u'Stackless'],
#  [u'Stackless', u'Python\n\n\nInfluenced'],
#  [u'Python\n\n\nInfluenced', u'by\n\n\nABC,[8]'],
#  [u'by\n\n\nABC,[8]', u'ALGOL'],
#  [u'ALGOL', u'68,[9]'],
#  [u'68,[9]', u'C,[10]'],
#  [u'C,[10]', u'C++,[11]'],
#  [u'C++,[11]', u'Dylan,[12]'],
#  [u'Dylan,[12]', u'Haskell,[13]'],
#  [u'Haskell,[13]', u'Icon,[14]'],
#  [u'Icon,[14]', u'Java,[15]'],
#  [u'Java,[15]', u'Lisp,[16]'],
#  [u'Lisp,[16]', u'Modula\u20113,[11]'],
#  [u'Modula\u20113,[11]', u'Perl\n\n\nInfluenced\n\n\nBoo,'],
#  [u'Perl\n\n\nInfluenced\n\n\nBoo,', u'Cobra,'],
#  [u'Cobra,', u'CoffeeScript,[17]'],
#  [u'CoffeeScript,[17]', u'D,'],
#  [u'D,', u'F#,'],
#  [u'F#,', u'Falcon,'],
#  [u'Falcon,', u'Genie,[18]'],
#  [u'Genie,[18]', u'Go,'],
#  [u'Go,', u'Groovy,'],
#  [u'Groovy,', u'JavaScript,[19][20]'],
#  [u'JavaScript,[19][20]', u'Julia,[21]'],
#  [u'Julia,[21]', u'Nim,'],
#  [u'Nim,', u'Ruby,[22]'],
#  [u'Ruby,[22]', u'Swift,[23]\n\n\n\n\n'],
#  [u'Swift,[23]\n\n\n\n\n', u'Python'],
#  [u'Python', u'Programming'],
#  [u'Programming', u'at'],
#  [u'at', u'Wikibooks\n\n\n\n\nPython'],
#  [u'Wikibooks\n\n\n\n\nPython', u'is'],
#  [u'is', u'a'],
#  [u'a', u'widely'],
#  [u'widely', u'used'],
#  [u'used', u'high-level,'],
#  [u'high-level,', u'general-purpose,'],
#  [u'general-purpose,', u'interpreted,'],
#  [u'interpreted,', u'dynamic'],
#  [u'dynamic', u'programming'],
#  [u'programming', u'language.[24][25]'],
#  [u'language.[24][25]', u'Its'],
#  [u'Its', u'design'],
#  [u'design', u'philosophy'],
#  [u'philosophy', u'emphasizes'],
#  [u'emphasizes', u'code'],
#  [u'code', u'readability,'],
#  [u'readability,', u'and'],
#  [u'and', u'its'],
#  [u'its', u'syntax'],
#  [u'syntax', u'allows'],
#  [u'allows', u'programmers'],
#  [u'programmers', u'to'],
#  [u'to', u'express'],
#  [u'express', u'concepts'],
#  [u'concepts', u'in'],
#  [u'in', u'fewer'],
#  [u'fewer', u'lines'],
#  [u'lines', u'of'],
#  [u'of', u'code'],
#  [u'code', u'than'],
#  [u'than', u'possible'],
#  [u'possible', u'in'],
#  [u'in', u'languages'],
#  [u'languages', u'such'],
#  [u'such', u'as'],
#  [u'as', u'C++'],
#  [u'C++', u'or'],
#  [u'or', u'Java.[26][27]'],
#  [u'Java.[26][27]', u'The'],
#  [u'The', u'language'],
#  [u'language', u'provides'],
#  [u'provides', u'constructs'],
#  [u'constructs', u'intended'],
#  [u'intended', u'to'],
#  [u'to', u'enable'],
#  [u'enable', u'writing'],
#  [u'writing', u'clear'],
#  [u'clear', u'programs'],
#  [u'programs', u'on'],
#  [u'on', u'both'],
#  [u'both', u'a'],
#  [u'a', u'small'],
#  [u'small', u'and'],
#  [u'and', u'large'],
#  [u'large', u'scale.[28]\nPython'],
#  [u'scale.[28]\nPython', u'supports'],
#  [u'supports', u'multiple'],
#  [u'multiple', u'programming'],
#  [u'programming', u'paradigms,'],
#  [u'paradigms,', u'including'],
#  [u'including', u'object-oriented,'],
#  [u'object-oriented,', u'imperative'],
#  [u'imperative', u'and'],
#  [u'and', u'functional'],
#  [u'functional', u'programming'],
#  [u'programming', u'or'],
#  [u'or', u'procedural'],
#  [u'procedural', u'styles.'],
#  [u'styles.', u'It'],
#  [u'It', u'features'],
#  [u'features', u'a'],
#  [u'a', u'dynamic'],
#  [u'dynamic', u'type'],
#  [u'type', u'system'],
#  [u'system', u'and'],
#  [u'and', u'automatic'],
#  [u'automatic', u'memory'],
#  [u'memory', u'management'],
#  [u'management', u'and'],
#  [u'and', u'has'],
#  [u'has', u'a'],
#  [u'a', u'large'],
#  [u'large', u'and'],
#  [u'and', u'comprehensive'],
#  [u'comprehensive', u'standard'],
#  [u'standard', u'library.[29]\nPython'],
#  [u'library.[29]\nPython', u'interpreters'],
#  [u'interpreters', u'are'],
#  [u'are', u'available'],
#  [u'available', u'for'],
#  [u'for', u'many'],
#  [u'many', u'operating'],
#  [u'operating', u'systems,'],
#  [u'systems,', u'allowing'],
#  [u'allowing', u'Python'],
#  [u'Python', u'code'],
#  [u'code', u'to'],
#  [u'to', u'run'],
#  [u'run', u'on'],
#  [u'on', u'a'],
#  [u'a', u'wide'],
#  [u'wide', u'variety'],
#  [u'variety', u'of'],
#  [u'of', u'systems.'],
#  [u'systems.', u'Using'],
#  [u'Using', u'third-party'],
#  [u'third-party', u'tools,'],
#  [u'tools,', u'such'],
#  [u'such', u'as'],
#  [u'as', u'Py2exe'],
#  [u'Py2exe', u'or'],
#  [u'or', u'Pyinstaller,[30]'],
#  [u'Pyinstaller,[30]', u'Python'],
#  [u'Python', u'code'],
#  [u'code', u'can'],
#  [u'can', u'be'],
#  [u'be', u'packaged'],
#  [u'packaged', u'into'],
#  [u'into', u'stand-alone'],
#  [u'stand-alone', u'executable'],
#  [u'executable', u'programs'],
#  [u'programs', u'for'],
#  [u'for', u'some'],
#  [u'some', u'of'],
#  [u'of', u'the'],
#  [u'the', u'most'],
#  [u'most', u'popular'],
#  [u'popular', u'operating'],
#  [u'operating', u'systems,'],
#  [u'systems,', u'so'],
#  [u'so', u'Python-based'],
#  [u'Python-based', u'software'],
#  [u'software', u'can'],
#  [u'can', u'be'],
#  [u'be', u'distributed'],
#  [u'distributed', u'to,'],
#  [u'to,', u'and'],
#  [u'and', u'used'],
#  [u'used', u'on,'],
#  [u'on,', u'those'],
#  [u'those', u'environments'],
#  [u'environments', u'with'],
#  [u'with', u'no'],
#  [u'no', u'need'],
#  [u'need', u'to'],
#  [u'to', u'install'],
#  [u'install', u'a'],
#  [u'a', u'Python'],
#  [u'Python', u'interpreter.\nCPython,'],
#  [u'interpreter.\nCPython,', u'the'],
#  [u'the', u'reference'],
#  [u'reference', u'implementation'],
#  [u'implementation', u'of'],
#  [u'of', u'Python,'],
#  [u'Python,', u'is'],
#  [u'is', u'free'],
#  [u'free', u'and'],
#  [u'and', u'open-source'],
#  [u'open-source', u'software'],
#  [u'software', u'and'],
#  [u'and', u'has'],
#  [u'has', u'a'],
#  [u'a', u'community-based'],
#  [u'community-based', u'development'],
#  [u'development', u'model,'],
#  [u'model,', u'as'],
#  [u'as', u'do'],
#  [u'do', u'nearly'],
#  [u'nearly', u'all'],
#  [u'all', u'of'],
#  [u'of', u'its'],
#  [u'its', u'variant'],
#  [u'variant', u'implementations.'],
#  [u'implementations.', u'CPython'],
#  [u'CPython', u'is'],
#  [u'is', u'managed'],
#  [u'managed', u'by'],
#  [u'by', u'the'],
#  [u'the', u'non-profit'],
#  [u'non-profit', u'Python'],
#  [u'Python', u'Software'],
#  [u'Software', u'Foundation.\n\n\n\nContents\n\n\n1'],
#  [u'Foundation.\n\n\n\nContents\n\n\n1', u'History\n2'],
#  [u'History\n2', u'Features'],
#  [u'Features', u'and'],
#  [u'and', u'philosophy\n3'],
#  [u'philosophy\n3', u'Syntax'],
#  [u'Syntax', u'and'],
#  [u'and', u'semantics\n\n3.1'],
#  [u'semantics\n\n3.1', u'Indentation\n3.2'],
#  [u'Indentation\n3.2', u'Statements'],
#  [u'Statements', u'and'],
#  [u'and', u'control'],
#  [u'control', u'flow\n3.3'],
#  [u'flow\n3.3', u'Expressions\n3.4'],
#  [u'Expressions\n3.4', u'Methods\n3.5'],
#  [u'Methods\n3.5', u'Typing\n3.6'],
#  [u'Typing\n3.6', u'Mathematics\n\n\n4'],
#  [u'Mathematics\n\n\n4', u'Libraries\n5'],
#  [u'Libraries\n5', u'Development'],
#  [u'Development', u'environments\n6'],
#  [u'environments\n6', u'Implementations\n7'],
#  [u'Implementations\n7', u'Development\n8'],
#  [u'Development\n8', u'Naming\n9'],
#  [u'Naming\n9', u'Uses\n10'],
#  [u'Uses\n10', u'Languages'],
#  [u'Languages', u'influenced'],
#  [u'influenced', u'by'],
#  [u'by', u'Python\n11'],
#  [u'Python\n11', u'See'],
#  [u'See', u'also\n12'],
#  [u'also\n12', u'References\n13'],
#  [u'References\n13', u'Further'],
#  [u'Further', u'reading\n14'],
#  [u'reading\n14', u'External'],
#  [u'External', u'links\n\n\n\nHistory[edit]\n\n\n\n\nGuido'],
#  [u'links\n\n\n\nHistory[edit]\n\n\n\n\nGuido', u'van'],
#  [u'van', u'Rossum,'],
#  [u'Rossum,', u'the'],
#  [u'the', u'creator'],
#  [u'creator', u'of'],
#  [u'of', u'Python\n\n\nMain'],
#  [u'Python\n\n\nMain', u'article:'],
#  [u'article:', u'History'],
#  [u'History', u'of'],
#  [u'of', u'Python\nPython'],
#  [u'Python\nPython', u'was'],
#  [u'was', u'conceived'],
#  [u'conceived', u'in'],
#  [u'in', u'the'],
#  [u'the', u'late'],
#  [u'late', u'1980s,[31]'],
#  [u'1980s,[31]', u'and'],
#  [u'and', u'its'],
#  [u'its', u'implementation'],
#  [u'implementation', u'began'],
#  [u'began', u'in'],
#  [u'in', u'December'],
#  [u'December', u'1989[32]'],
#  [u'1989[32]', u'by'],
#  [u'by', u'Guido'],
#  [u'Guido', u'van'],
#  [u'van', u'Rossum'],
#  [u'Rossum', u'at'],
#  [u'at', u'Centrum'],
#  [u'Centrum', u'Wiskunde'],
#  [u'Wiskunde', u'&'],
#  [u'&', u'Informatica'],
#  [u'Informatica', u'(CWI)'],
#  [u'(CWI)', u'in'],
#  [u'in', u'the'],
#  [u'the', u'Netherlands'],
#  [u'Netherlands', u'as'],
#  [u'as', u'a'],
#  [u'a', u'successor'],
#  [u'successor', u'to'],
#  [u'to', u'the'],
#  [u'the', u'ABC'],
#  [u'ABC', u'language'],
#  [u'language', u'(itself'],
#  [u'(itself', u'inspired'],
#  [u'inspired', u'by'],
#  [u'by', u'SETL)[33]'],
#  [u'SETL)[33]', u'capable'],
#  [u'capable', u'of'],
#  [u'of', u'exception'],
#  [u'exception', u'handling'],
#  [u'handling', u'and'],
#  [u'and', u'interfacing'],
#  [u'interfacing', u'with'],
#  [u'with', u'the'],
#  [u'the', u'operating'],
#  [u'operating', u'system'],
#  [u'system', u'Amoeba.[8]'],
#  [u'Amoeba.[8]', u'Van'],
#  [u'Van', u'Rossum'],
#  [u'Rossum', u'is'],
#  [u'is', u"Python's"],
#  [u"Python's", u'principal'],
#  [u'principal', u'author,'],
#  [u'author,', u'and'],
#  [u'and', u'his'],
#  [u'his', u'continuing'],
#  [u'continuing', u'central'],
#  [u'central', u'role'],
#  [u'role', u'in'],
#  [u'in', u'deciding'],
#  [u'deciding', u'the'],
#  [u'the', u'direction'],
#  [u'direction', u'of'],
#  [u'of', u'Python'],
#  [u'Python', u'is'],
#  [u'is', u'reflected'],
#  [u'reflected', u'in'],
#  [u'in', u'the'],
#  [u'the', u'title'],
#  [u'title', u'given'],
#  [u'given', u'to'],
#  [u'to', u'him'],
#  [u'him', u'by'],
#  [u'by', u'the'],
#  [u'the', u'Python'],
#  [u'Python', u'community,'],
#  [u'community,', u'benevolent'],
#  [u'benevolent', u'dictator'],
#  [u'dictator', u'for'],
#  [u'for', u'life'],
#  [u'life', u'(BDFL).\nAbout'],
#  [u'(BDFL).\nAbout', u'the'],
#  [u'the', u'origin'],
#  [u'origin', u'of'],
#  [u'of', u'Python,'],
#  [u'Python,', u'Van'],
#  [u'Van', u'Rossum'],
#  [u'Rossum', u'wrote'],
#  [u'wrote', u'in'],
#  [u'in', u'1996:[34]\n\nOver'],
#  [u'1996:[34]\n\nOver', u'six'],
#  [u'six', u'years'],
#  [u'years', u'ago,'],
#  [u'ago,', u'in'],
#  [u'in', u'December'],
#  [u'December', u'1989,'],
#  [u'1989,', u'I'],
#  [u'I', u'was'],
#  [u'was', u'looking'],
#  [u'looking', u'for'],
#  [u'for', u'a'],
#  [u'a', u'"hobby"'],
#  [u'"hobby"', u'programming'],
#  [u'programming', u'project'],
#  [u'project', u'that'],
#  [u'that', u'would'],
#  [u'would', u'keep'],
#  [u'keep', u'me'],
#  [u'me', u'occupied'],
#  [u'occupied', u'during'],
#  [u'during', u'the'],
#  [u'the', u'week'],
#  [u'week', u'around'],
#  [u'around', u'Christmas.'],
#  [u'Christmas.', u'My'],
#  [u'My', u'office'],
#  [u'office', u'...'],
#  [u'...', u'would'],
#  [u'would', u'be'],
#  [u'be', u'closed,'],
#  [u'closed,', u'but'],
#  [u'but', u'I'],
#  [u'I', u'had'],
#  [u'had', u'a'],
#  [u'a', u'home'],
#  [u'home', u'computer,'],
#  [u'computer,', u'and'],
#  [u'and', u'not'],
#  [u'not', u'much'],
#  [u'much', u'else'],
#  [u'else', u'on'],
#  [u'on', u'my'],
#  [u'my', u'hands.'],
#  [u'hands.', u'I'],
#  [u'I', u'decided'],
#  [u'decided', u'to'],
#  [u'to', u'write'],
#  [u'write', u'an'],
#  [u'an', u'interpreter'],
#  [u'interpreter', u'for'],
#  [u'for', u'the'],
#  [u'the', u'new'],
#  [u'new', u'scripting'],
#  [u'scripting', u'language'],
#  [u'language', u'I'],
#  [u'I', u'had'],
#  [u'had', u'been'],
#  [u'been', u'thinking'],
#  [u'thinking', u'about'],
#  [u'about', u'lately:'],
#  [u'lately:', u'a'],
#  [u'a', u'descendant'],
#  [u'descendant', u'of'],
#  [u'of', u'ABC'],
#  [u'ABC', u'that'],
#  [u'that', u'would'],
#  [u'would', u'appeal'],
#  [u'appeal', u'to'],
#  [u'to', u'Unix/C'],
#  [u'Unix/C', u'hackers.'],
#  [u'hackers.', u'I'],
#  [u'I', u'chose'],
#  [u'chose', u'Python'],
#  [u'Python', u'as'],
#  [u'as', u'a'],
#  [u'a', u'working'],
#  [u'working', u'title'],
#  [u'title', u'for'],
#  [u'for', u'the'],
#  [u'the', u'project,'],
#  [u'project,', u'being'],
#  [u'being', u'in'],
#  [u'in', u'a'],
#  [u'a', u'slightly'],
#  [u'slightly', u'irreverent'],
#  [u'irreverent', u'mood'],
#  [u'mood', u'(and'],
#  [u'(and', u'a'],
#  [u'a', u'big'],
#  [u'big', u'fan'],
#  [u'fan', u'of'],
#  [u'of', u'Monty'],
#  [u'Monty', u"Python's"],
#  [u"Python's", u'Flying'],
#  [u'Flying', u'Circus).\n\nPython'],
#  [u'Circus).\n\nPython', u'2.0'],
#  [u'2.0', u'was'],
#  [u'was', u'released'],
#  [u'released', u'on'],
#  [u'on', u'16'],
#  [u'16', u'October'],
#  [u'October', u'2000'],
#  [u'2000', u'and'],
#  [u'and', u'had'],
#  [u'had', u'many'],
#  [u'many', u'major'],
#  [u'major', u'new'],
#  [u'new', u'features,'],
#  [u'features,', u'including'],
#  [u'including', u'a'],
#  [u'a', u'cycle-detecting'],
#  [u'cycle-detecting', u'garbage'],
#  [u'garbage', u'collector'],
#  [u'collector', u'and'],
#  [u'and', u'support'],
#  [u'support', u'for'],
#  [u'for', u'Unicode.'],
#  [u'Unicode.', u'With'],
#  [u'With', u'this'],
#  [u'this', u'release'],
#  [u'release', u'the'],
#  [u'the', u'development'],
#  [u'development', u'process'],
#  [u'process', u'was'],
#  [u'was', u'changed'],
#  [u'changed', u'and'],
#  [u'and', u'became'],
#  [u'became', u'more'],
#  [u'more', u'transparent'],
#  [u'transparent', u'and'],
#  [u'and', u'community-backed.[35]\nPython'],
#  [u'community-backed.[35]\nPython', u'3.0'],
#  [u'3.0', u'(which'],
#  [u'(which', u'early'],
#  [u'early', u'in'],
#  [u'in', u'its'],
#  [u'its', u'development'],
#  [u'development', u'was'],
#  [u'was', u'commonly'],
#  [u'commonly', u'referred'],
#  [u'referred', u'to'],
#  [u'to', u'as'],
#  [u'as', u'Python'],
#  [u'Python', u'3000'],
#  [u'3000', u'or'],
#  [u'or', u'py3k),'],
#  [u'py3k),', u'a'],
#  [u'a', u'major,'],
#  [u'major,', u'backwards-incompatible'],
#  [u'backwards-incompatible', u'release,'],
#  [u'release,', u'was'],
#  [u'was', u'released'],
#  [u'released', u'on'],
#  [u'on', u'3'],
#  [u'3', u'December'],
#  [u'December', u'2008[36]'],
#  [u'2008[36]', u'after'],
#  [u'after', u'a'],
#  [u'a', u'long'],
#  [u'long', u'period'],
#  [u'period', u'of'],
#  [u'of', u'testing.'],
#  [u'testing.', u'Many'],
#  [u'Many', u'of'],
#  [u'of', u'its'],
#  [u'its', u'major'],
#  [u'major', u'features'],
#  [u'features', u'have'],
#  [u'have', u'been'],
#  [u'been', u'backported'],
#  [u'backported', u'to'],
#  [u'to', u'the'],
#  [u'the', u'backwards-compatible'],
#  [u'backwards-compatible', u'Python'],
#  [u'Python', u'2.6.x[37]'],
#  [u'2.6.x[37]', u'and'],
#  [u'and', u'2.7.x'],
#  [u'2.7.x', u'version'],
#  [u'version', u'series.\nFeatures'],
#  [u'series.\nFeatures', u'and'],
#  [u'and', u'philosophy[edit]\nPython'],
#  [u'philosophy[edit]\nPython', u'is'],
#  [u'is', u'a'],
#  [u'a', u'multi-paradigm'],
#  [u'multi-paradigm', u'programming'],
#  [u'programming', u'language:'],
#  [u'language:', u'object-oriented'],
#  [u'object-oriented', u'programming'],
#  [u'programming', u'and'],
#  [u'and', u'structured'],
#  [u'structured', u'programming'],
#  [u'programming', u'are'],
#  [u'are', u'fully'],
#  [u'fully', u'supported,'],
#  [u'supported,', u'and'],
#  [u'and', u'many'],
#  [u'many', u'language'],
#  [u'language', u'features'],
#  [u'features', u'support'],
#  [u'support', u'functional'],
#  [u'functional', u'programming'],
#  [u'programming', u'and'],
#  [u'and', u'aspect-oriented'],
#  [u'aspect-oriented', u'programming'],
#  [u'programming', u'(including'],
#  [u'(including', u'by'],
#  [u'by', u'metaprogramming[38]'],
#  [u'metaprogramming[38]', u'and'],
#  [u'and', u'metaobjects'],
#  [u'metaobjects', u'(magic'],
#  [u'(magic', u'methods)).[39]'],
#  [u'methods)).[39]', u'Many'],
#  [u'Many', u'other'],
#  [u'other', u'paradigms'],
#  [u'paradigms', u'are'],
#  [u'are', u'supported'],
#  [u'supported', u'via'],
#  [u'via', u'extensions,'],
#  [u'extensions,', u'including'],
#  [u'including', u'design'],
#  [u'design', u'by'],
#  [u'by', u'contract[40][41]'],
#  [u'contract[40][41]', u'and'],
#  [u'and', u'logic'],
#  [u'logic', u'programming.[42]\nPython'],
#  [u'programming.[42]\nPython', u'uses'],
#  [u'uses', u'dynamic'],
#  [u'dynamic', u'typing'],
#  [u'typing', u'and'],
#  [u'and', u'a'],
#  [u'a', u'mix'],
#  [u'mix', u'of'],
#  [u'of', u'reference'],
#  [u'reference', u'counting'],
#  [u'counting', u'and'],
#  [u'and', u'a'],
#  [u'a', u'cycle-detecting'],
#  [u'cycle-detecting', u'garbage'],
#  [u'garbage', u'collector'],
#  [u'collector', u'for'],
#  [u'for', u'memory'],
#  [u'memory', u'management.'],
#  [u'management.', u'An'],
#  [u'An', u'important'],
#  [u'important', u'feature'],
#  [u'feature', u'of'],
#  [u'of', u'Python'],
#  [u'Python', u'is'],
#  [u'is', u'dynamic'],
#  [u'dynamic', u'name'],
#  [u'name', u'resolution'],
#  [u'resolution', u'(late'],
#  [u'(late', u'binding),'],
#  [u'binding),', u'which'],
#  [u'which', u'binds'],
#  [u'binds', u'method'],
#  [u'method', u'and'],
#  [u'and', u'variable'],
#  [u'variable', u'names'],
#  [u'names', u'during'],
#  [u'during', u'program'],
#  [u'program', u'execution.\nThe'],
#  [u'execution.\nThe', u'design'],
#  [u'design', u'of'],
#  [u'of', u'Python'],
#  [u'Python', u'offers'],
#  [u'offers', u'some'],
#  [u'some', u'support'],
#  [u'support', u'for'],
#  [u'for', u'functional'],
#  [u'functional', u'programming'],
#  [u'programming', u'in'],
#  [u'in', u'the'],
#  [u'the', u'Lisp'],
#  [u'Lisp', u'tradition.'],
#  [u'tradition.', u'The'],
#  [u'The', u'language'],
#  [u'language', u'has'],
#  [u'has', u'map(),'],
#  [u'map(),', u'reduce()'],
#  [u'reduce()', u'and'],
#  [u'and', u'filter()'],
#  [u'filter()', u'functions;'],
#  [u'functions;', u'list'],
#  [u'list', u'comprehensions,'],
#  [u'comprehensions,', u'dictionaries,'],
#  [u'dictionaries,', u'and'],
#  [u'and', u'sets;'],
#  [u'sets;', u'and'],
#  [u'and', u'generator'],
#  [u'generator', u'expressions.[43]'],
#  [u'expressions.[43]', u'The'],
#  [u'The', u'standard'],
#  [u'standard', u'library'],
#  [u'library', u'has'],
#  [u'has', u'two'],
#  [u'two', u'modules'],
#  [u'modules', u'(itertools'],
#  [u'(itertools', u'and'],
#  [u'and', u'functools)'],
#  [u'functools)', u'that'],
#  [u'that', u'implement'],
#  [u'implement', u'functional'],
#  [u'functional', u'tools'],
#  [u'tools', u'borrowed'],
#  [u'borrowed', u'from'],
#  [u'from', u'Haskell'],
#  [u'Haskell', u'and'],
#  [u'and', u'Standard'],
#  [u'Standard', u'ML.[44]\nThe'],
#  [u'ML.[44]\nThe', u'core'],
#  [u'core', u'philosophy'],
#  [u'philosophy', u'of'],
#  [u'of', u'the'],
#  [u'the', u'language'],
#  [u'language', u'is'],
#  [u'is', u'summarized'],
#  [u'summarized', u'by'],
#  [u'by', u'the'],
#  [u'the', u'document'],
#  [u'document', u'The'],
#  [u'The', u'Zen'],
#  [u'Zen', u'of'],
#  [u'of', u'Python'],
#  [u'Python', u'(PEP'],
#  [u'(PEP', u'20),'],
#  [u'20),', u'which'],
#  [u'which', u'includes'],
#  [u'includes', u'aphorisms'],
#  [u'aphorisms', u'such'],
#  [u'such', u'as:[45]\n\nBeautiful'],
#  [u'as:[45]\n\nBeautiful', u'is'],
#  [u'is', u'better'],
#  [u'better', u'than'],
#  [u'than', u'ugly\nExplicit'],
#  [u'ugly\nExplicit', u'is'],
#  [u'is', u'better'],
#  [u'better', u'than'],
#  [u'than', u'implicit\nSimple'],
#  [u'implicit\nSimple', u'is'],
#  [u'is', u'better'],
#  [u'better', u'than'],
#  [u'than', u'complex\nComplex'],
#  [u'complex\nComplex', u'is'],
#  [u'is', u'better'],
#  [u'better', u'than'],
#  [u'than', u'complicated\nReadability'],
#  [u'complicated\nReadability', u'counts\n\nRather'],
#  [u'counts\n\nRather', u'than'],
#  [u'than', u'requiring'],
#  [u'requiring', u'all'],
#  [u'all', u'desired'],
#  [u'desired', u'functionality'],
#  [u'functionality', u'to'],
#  [u'to', u'be'],
#  [u'be', u'built'],
#  [u'built', u'into'],
#  [u'into', u'the'],
#  [u'the', u"language's"],
#  [u"language's", u'core,'],
#  [u'core,', u'Python'],
#  [u'Python', u'was'],
#  [u'was', u'designed'],
#  [u'designed', u'to'],
#  [u'to', u'be'],
#  [u'be', u'highly'],
#  [u'highly', u'extensible.'],
#  [u'extensible.', u'Python'],
#  [u'Python', u'can'],
#  [u'can', u'also'],
#  [u'also', u'be'],
#  [u'be', u'embedded'],
#  [u'embedded', u'in'],
#  [u'in', u'existing'],
#  [u'existing', u'applications'],
#  [u'applications', u'that'],
#  [u'that', u'need'],
#  [u'need', u'a'],
#  [u'a', u'programmable'],
#  [u'programmable', u'interface.'],
#  [u'interface.', u'This'],
#  [u'This', u'design'],
#  [u'design', u'of'],
#  [u'of', u'a'],
#  [u'a', u'small'],
#  [u'small', u'core'],
#  [u'core', u'language'],
#  [u'language', u'with'],
#  [u'with', u'a'],
#  [u'a', u'large'],
#  [u'large', u'standard'],
#  [u'standard', u'library'],
#  [u'library', u'and'],
#  [u'and', u'an'],
#  [u'an', u'easily'],
#  [u'easily', u'extensible'],
#  [u'extensible', u'interpreter'],
#  [u'interpreter', u'was'],
#  [u'was', u'intended'],
#  [u'intended', u'by'],
#  [u'by', u'Van'],
#  [u'Van', u'Rossum'],
#  [u'Rossum', u'from'],
#  [u'from', u'the'],
#  [u'the', u'start'],
#  [u'start', u'because'],
#  [u'because', u'of'],
#  [u'of', u'his'],
#  [u'his', u'frustrations'],
#  [u'frustrations', u'with'],
#  [u'with', u'ABC,'],
#  [u'ABC,', u'which'],
#  [u'which', u'espoused'],
#  [u'espoused', u'the'],
#  [u'the', u'opposite'],
#  [u'opposite', u'mindset.[31]\nWhile'],
#  [u'mindset.[31]\nWhile', u'offering'],
#  [u'offering', u'choice'],
#  [u'choice', u'in'],
#  [u'in', u'coding'],
#  [u'coding', u'methodology,'],
#  [u'methodology,', u'the'],
#  [u'the', u'Python'],
#  [u'Python', u'philosophy'],
#  [u'philosophy', u'rejects'],
#  [u'rejects', u'exuberant'],
#  [u'exuberant', u'syntax,'],
#  [u'syntax,', u'such'],
#  [u'such', u'as'],
#  [u'as', u'in'],
#  [u'in', u'Perl,'],
#  [u'Perl,', u'in'],
#  [u'in', u'favor'],
#  [u'favor', u'of'],
#  [u'of', u'a'],
#  [u'a', u'sparser,'],
#  [u'sparser,', u'less-cluttered'],
#  [u'less-cluttered', u'grammar.'],
#  [u'grammar.', u'As'],
#  [u'As', u'Alex'],
#  [u'Alex', u'Martelli'],
#  [u'Martelli', u'put'],
#  [u'put', u'it:'],
#  [u'it:', u'"To'],
#  [u'"To', u'describe'],
#  [u'describe', u'something'],
#  [u'something', u'as'],
#  [u'as', u'clever'],
#  [u'clever', u'is'],
#  [u'is', u'not'],
#  [u'not', u'considered'],
#  [u'considered', u'a'],
#  [u'a', u'compliment'],
#  [u'compliment', u'in'],
#  [u'in', u'the'],
#  [u'the', u'Python'],
#  [u'Python', u'culture."[46]'],
#  [u'culture."[46]', u"Python's"],
#  [u"Python's", u'philosophy'],
#  [u'philosophy', u'rejects'],
#  [u'rejects', u'the'],
#  [u'the', u'Perl'],
#  [u'Perl', u'"there'],
#  [u'"there', u'is'],
#  [u'is', u'more'],
#  [u'more', u'than'],
#  [u'than', u'one'],
#  [u'one', u'way'],
#  [u'way', u'to'],
#  [u'to', u'do'],
#  [u'do', u'it"'],
#  [u'it"', u'approach'],
#  [u'approach', u'to'],
#  [u'to', u'language'],
#  [u'language', u'design'],
#  [u'design', u'in'],
#  [u'in', u'favor'],
#  [u'favor', u'of'],
#  [u'of', u'"there'],
#  [u'"there', u'should'],
#  [u'should', u'be'],
#  [u'be', u'one\u2014and'],
#  [u'one\u2014and', u'preferably'],
#  [u'preferably', u'only'],
#  [u'only', u'one\u2014obvious'],
#  [u'one\u2014obvious', u'way'],
#  [u'way', u'to'],
#  [u'to', u'do'],
#  [u'do', u'it".[45]\nPython\'s'],
#  [u'it".[45]\nPython\'s', u'developers'],
#  [u'developers', u'strive'],
#  [u'strive', u'to'],
#  [u'to', u'avoid'],
#  [u'avoid', u'premature'],
#  [u'premature', u'optimization,'],
#  [u'optimization,', u'and'],
#  [u'and', u'moreover,'],
#  [u'moreover,', u'reject'],
#  [u'reject', u'patches'],
#  [u'patches', u'to'],
#  [u'to', u'non-critical'],
#  [u'non-critical', u'parts'],
#  [u'parts', u'of'],
#  [u'of', u'CPython'],
#  [u'CPython', u'that'],
#  [u'that', u'would'],
#  [u'would', u'offer'],
#  [u'offer', u'a'],
#  [u'a', u'marginal'],
#  [u'marginal', u'increase'],
#  [u'increase', u'in'],
#  [u'in', u'speed'],
#  [u'speed', u'at'],
#  [u'at', u'the'],
#  [u'the', u'cost'],
#  [u'cost', u'of'],
#  [u'of', u'clarity.[47]'],
#  [u'clarity.[47]', u'When'],
#  [u'When', u'speed'],
#  [u'speed', u'is'],
#  [u'is', u'important,'],
#  [u'important,', u'a'],
#  [u'a', u'Python'],
#  [u'Python', u'programmer'],
#  [u'programmer', u'can'],
#  [u'can', u'move'],
#  [u'move', u'time-critical'],
#  [u'time-critical', u'functions'],
#  [u'functions', u'to'],
#  [u'to', u'extension'],
#  [u'extension', u'modules'],
#  [u'modules', u'written'],
#  [u'written', u'in'],
#  [u'in', u'languages'],
#  [u'languages', u'such'],
#  [u'such', u'as'],
#  [u'as', u'C,'],
#  [u'C,', u'or'],
#  [u'or', u'try'],
#  [u'try', u'using'],
#  [u'using', u'PyPy,'],
#  [u'PyPy,', u'a'],
#  [u'a', u'just-in-time'],
#  [u'just-in-time', u'compiler.'],
#  [u'compiler.', u'Cython'],
#  [u'Cython', u'is'],
#  [u'is', u'also'],
#  [u'also', u'available,'],
#  [u'available,', u'which'],
#  [u'which', u'translates'],
#  [u'translates', u'a'],
#  [u'a', u'Python'],
#  [u'Python', u'script'],
#  [u'script', u'into'],
#  [u'into', u'C'],
#  [u'C', u'and'],
#  [u'and', u'makes'],
#  [u'makes', u'direct'],
#  [u'direct', u'C-level'],
#  [u'C-level', u'API'],
#  [u'API', u'calls'],
#  [u'calls', u'into'],
#  [u'into', u'the'],
#  [u'the', u'Python'],
#  [u'Python', u'interpreter.\nAn'],
#  [u'interpreter.\nAn', u'important'],
#  [u'important', u'goal'],
#  [u'goal', u'of'],
#  [u'of', u"Python's"],
#  [u"Python's", u'developers'],
#  [u'developers', u'is'],
#  [u'is', u'making'],
#  [u'making', u'it'],
#  [u'it', u'fun'],
#  [u'fun', u'to'],
#  [u'to', u'use.'],
#  [u'use.', u'This'],
#  [u'This', u'is'],
#  [u'is', u'reflected'],
#  [u'reflected', u'in'],
#  [u'in', u'the'],
#  [u'the', u'origin'],
#  [u'origin', u'of'],
#  [u'of', u'the'],
#  [u'the', u'name,'],
#  [u'name,', u'which'],
#  [u'which', u'comes'],
#  [u'comes', u'from'],
#  [u'from', u'Monty'],
#  [u'Monty', u'Python,[48]'],
#  [u'Python,[48]', u'and'],
#  [u'and', u'in'],
#  [u'in', u'an'],
#  [u'an', u'occasionally'],
#  [u'occasionally', u'playful'],
#  [u'playful', u'approach'],
#  [u'approach', u'to'],
#  [u'to', u'tutorials'],
#  [u'tutorials', u'and'],
#  [u'and', u'reference'],
#  [u'reference', u'materials,'],
#  [u'materials,', u'such'],
#  [u'such', u'as'],
#  [u'as', u'using'],
#  [u'using', u'examples'],
#  [u'examples', u'that'],
#  [u'that', u'refer'],
#  [u'refer', u'to'],
#  [u'to', u'spam'],
#  [u'spam', u'and'],
#  [u'and', u'eggs'],
#  [u'eggs', u'instead'],
#  [u'instead', u'of'],
#  [u'of', u'the'],
#  [u'the', u'standard'],
#  [u'standard', u'foo'],
#  [u'foo', u'and'],
#  [u'and', u'bar.[49][50]\nA'],
#  [u'bar.[49][50]\nA', u'common'],
#  [u'common', u'neologism'],
#  [u'neologism', u'in'],
#  [u'in', u'the'],
#  [u'the', u'Python'],
#  [u'Python', u'community'],
#  [u'community', u'is'],
#  [u'is', u'pythonic,'],
#  [u'pythonic,', u'which'],
#  [u'which', u'can'],
#  [u'can', u'have'],
#  [u'have', u'a'],
#  [u'a', u'wide'],
#  [u'wide', u'range'],
#  [u'range', u'of'],
#  [u'of', u'meanings'],
#  [u'meanings', u'related'],
#  [u'related', u'to'],
#  [u'to', u'program'],
#  [u'program', u'style.'],
#  [u'style.', u'To'],
#  [u'To', u'say'],
#  [u'say', u'that'],
#  [u'that', u'code'],
#  [u'code', u'is'],
#  [u'is', u'pythonic'],
#  [u'pythonic', u'is'],
#  [u'is', u'to'],
#  [u'to', u'say'],
#  [u'say', u'that'],
#  [u'that', u'it'],
#  [u'it', u'uses'],
#  [u'uses', u'Python'],
#  [u'Python', u'idioms'],
#  [u'idioms', u'well,'],
#  [u'well,', u'that'],
#  [u'that', u'it'],
#  [u'it', u'is'],
#  [u'is', u'natural'],
#  [u'natural', u'or'],
#  [u'or', u'shows'],
#  [u'shows', u'fluency'],
#  [u'fluency', u'in'],
#  [u'in', u'the'],
#  [u'the', u'language,'],
#  [u'language,', u'that'],
#  [u'that', u'it'],
#  [u'it', u'conforms'],
#  [u'conforms', u'with'],
#  [u'with', u"Python's"],
#  [u"Python's", u'minimalist'],
#  [u'minimalist', u'philosophy'],
#  [u'philosophy', u'and'],
#  [u'and', u'emphasis'],
#  [u'emphasis', u'on'],
#  [u'on', u'readability.'],
#  [u'readability.', u'In'],
#  [u'In', u'contrast,'],
#  [u'contrast,', u'code'],
#  [u'code', u'that'],
#  [u'that', u'is'],
#  [u'is', u'difficult'],
#  [u'difficult', u'to'],
#  [u'to', u'understand'],
#  [u'understand', u'or'],
#  [u'or', u'reads'],
#  [u'reads', u'like'],
#  [u'like', u'a'],
#  [u'a', u'rough'],
#  [u'rough', u'transcription'],
#  [u'transcription', u'from'],
#  [u'from', u'another'],
#  [u'another', u'programming'],
#  [u'programming', u'language'],
#  [u'language', u'is'],
#  [u'is', u'called'],
#  [u'called', u'unpythonic.\nUsers'],
#  [u'unpythonic.\nUsers', u'and'],
#  [u'and', u'admirers'],
#  [u'admirers', u'of'],
#  [u'of', u'Python,'],
#  [u'Python,', u'especially'],
#  [u'especially', u'those'],
#  [u'those', u'considered'],
#  [u'considered', u'knowledgeable'],
#  [u'knowledgeable', u'or'],
#  [u'or', u'experienced,'],
#  [u'experienced,', u'are'],
#  [u'are', u'often'],
#  [u'often', u'referred'],
#  [u'referred', u'to'],
#  [u'to', u'as'],
#  [u'as', u'Pythonists,'],
#  [u'Pythonists,', u'Pythonistas,'],
#  [u'Pythonistas,', u'and'],
#  [u'and', u'Pythoneers.[51][52]\nSyntax'],
#  [u'Pythoneers.[51][52]\nSyntax', u'and'],
#  [u'and', u'semantics[edit]\nMain'],
#  [u'semantics[edit]\nMain', u'article:'],
#  [u'article:', u'Python'],
#  [u'Python', u'syntax'],
#  [u'syntax', u'and'],
#  [u'and', u'semantics\nPython'],
#  [u'semantics\nPython', u'is'],
#  [u'is', u'intended'],
#  [u'intended', u'to'],
#  [u'to', u'be'],
#  [u'be', u'a'],
#  [u'a', u'highly'],
#  [u'highly', u'readable'],
#  [u'readable', u'language.'],
#  [u'language.', u'It'],
#  [u'It', u'is'],
#  [u'is', u'designed'],
#  [u'designed', u'to'],
#  [u'to', u'have'],
#  [u'have', u'an'],
#  [u'an', u'uncluttered'],
#  [u'uncluttered', u'visual'],
#  [u'visual', u'layout,'],
#  [u'layout,', u'often'],
#  [u'often', u'using'],
#  [u'using', u'English'],
#  [u'English', u'keywords'],
#  [u'keywords', u'where'],
#  [u'where', u'other'],
#  [u'other', u'languages'],
#  [u'languages', u'use'],
#  [u'use', u'punctuation.'],
#  [u'punctuation.', u'Further,'],
#  [u'Further,', u'Python'],
#  [u'Python', u'has'],
#  [u'has', u'fewer'],
#  [u'fewer', u'syntactic'],
#  [u'syntactic', u'exceptions'],
#  [u'exceptions', u'and'],
#  [u'and', u'special'],
#  [u'special', u'cases'],
#  [u'cases', u'than'],
#  [u'than', u'C'],
#  [u'C', u'or'],
#  [u'or', u'Pascal.[53]\nIndentation[edit]\nMain'],
#  [u'Pascal.[53]\nIndentation[edit]\nMain', u'article:'],
#  [u'article:', u'Python'],
#  [u'Python', u'syntax'],
#  [u'syntax', u'and'],
#  [u'and', u'semantics'],
#  [u'semantics', u'\xa7\xa0Indentation\nPython'],
#  [u'\xa7\xa0Indentation\nPython', u'uses'],
#  [u'uses', u'whitespace'],
#  [u'whitespace', u'indentation'],
#  [u'indentation', u'to'],
#  [u'to', u'delimit'],
#  [u'delimit', u'blocks'],
#  [u'blocks', u'-'],
#  [u'-', u'rather'],
#  [u'rather', u'than'],
#  [u'than', u'curly'],
#  [u'curly', u'braces'],
#  [u'braces', u'or'],
#  [u'or', u'keywords.'],
#  [u'keywords.', u'An'],
#  [u'An', u'increase'],
#  [u'increase', u'in'],
#  [u'in', u'indentation'],
#  [u'indentation', u'comes'],
#  [u'comes', u'after'],
#  [u'after', u'certain'],
#  [u'certain', u'statements;'],
#  [u'statements;', u'a'],
#  [u'a', u'decrease'],
#  [u'decrease', u'in'],
#  [u'in', u'indentation'],
#  [u'indentation', u'signifies'],
#  [u'signifies', u'the'],
#  [u'the', u'end'],
#  [u'end', u'of'],
#  [u'of', u'the'],
#  [u'the', u'current'],
#  [u'current', u'block.[54]'],
#  [u'block.[54]', u'This'],
#  [u'This', u'feature'],
#  [u'feature', u'is'],
#  [u'is', u'also'],
#  [u'also', u'sometimes'],
#  [u'sometimes', u'termed'],
#  [u'termed', u'the'],
#  [u'the', u'off-side'],
#  [u'off-side', u'rule.\nStatements'],
#  [u'rule.\nStatements', u'and'],
#  [u'and', u'control'],
#  [u'control', u"flow[edit]\nPython's"],
#  [u"flow[edit]\nPython's", u'statements'],
#  [u'statements', u'include'],
#  [u'include', u'(among'],
#  [u'(among', u'others):\n\nThe'],
#  [u'others):\n\nThe', u'assignment'],
#  [u'assignment', u'statement'],
#  [u'statement', u'(token'],
#  [u'(token', u"'=',"],
#  [u"'=',", u'the'],
#  [u'the', u'equals'],
#  [u'equals', u'sign).'],
#  [u'sign).', u'This'],
#  [u'This', u'operates'],
#  [u'operates', u'differently'],
#  [u'differently', u'than'],
#  [u'than', u'in'],
#  [u'in', u'traditional'],
#  [u'traditional', u'imperative'],
#  [u'imperative', u'programming'],
#  [u'programming', u'languages,'],
#  [u'languages,', u'and'],
#  [u'and', u'this'],
#  [u'this', u'fundamental'],
#  [u'fundamental', u'mechanism'],
#  [u'mechanism', u'(including'],
#  [u'(including', u'the'],
#  [u'the', u'nature'],
#  [u'nature', u'of'],
#  [u'of', u"Python's"],
#  [u"Python's", u'version'],
#  [u'version', u'of'],
#  [u'of', u'variables)'],
#  [u'variables)', u'illuminates'],
#  [u'illuminates', u'many'],
#  [u'many', u'other'],
#  [u'other', u'features'],
#  [u'features', u'of'],
#  [u'of', u'the'],
#  [u'the', u'language.'],
#  [u'language.', u'Assignment'],
#  [u'Assignment', u'in'],
#  [u'in', u'C,'],
#  [u'C,', u'e.g.,'],
#  [u'e.g.,', u'x'],
#  [u'x', u'='],
#  [u'=', u'2,'],
#  [u'2,', u'translates'],
#  [u'translates', u'to'],
#  [u'to', u'"typed'],
#  [u'"typed', u'variable'],
#  [u'variable', u'name'],
#  [u'name', u'x'],
#  [u'x', u'receives'],
#  [u'receives', u'a'],
#  [u'a', u'copy'],
#  [u'copy', u'of'],
#  [u'of', u'numeric'],
#  [u'numeric', u'value'],
#  [u'value', u'2".'],
#  [u'2".', u'The'],
#  [u'The', u'(right-hand)'],
#  [u'(right-hand)', u'value'],
#  [u'value', u'is'],
#  [u'is', u'copied'],
#  [u'copied', u'into'],
#  [u'into', u'an'],
#  [u'an', u'allocated'],
#  [u'allocated', u'storage'],
#  [u'storage', u'location'],
#  [u'location', u'for'],
#  [u'for', u'which'],
#  [u'which', u'the'],
#  [u'the', u'(left-hand)'],
#  [u'(left-hand)', u'variable'],
#  [u'variable', u'name'],
#  [u'name', u'is'],
#  [u'is', u'the'],
#  [u'the', u'symbolic'],
#  [u'symbolic', u'address.'],
#  [u'address.', u'The'],
#  [u'The', u'memory'],
#  [u'memory', u'allocated'],
#  [u'allocated', u'to'],
#  [u'to', u'the'],
#  [u'the', u'variable'],
#  [u'variable', u'is'],
#  [u'is', u'large'],
#  [u'large', u'enough'],
#  [u'enough', u'(potentially'],
#  [u'(potentially', u'quite'],
#  [u'quite', u'large)'],
#  [u'large)', u'for'],
#  [u'for', u'the'],
#  [u'the', u'declared'],
#  [u'declared', u'type.'],
#  [u'type.', u'In'],
#  [u'In', u'the'],
#  [u'the', u'simplest'],
#  [u'simplest', u'case'],
#  [u'case', u'of'],
#  [u'of', u'Python'],
#  [u'Python', u'assignment,'],
#  [u'assignment,', u'using'],
#  [u'using', u'the'],
#  [u'the', u'same'],
#  [u'same', u'example,'],
#  [u'example,', u'x'],
#  [u'x', u'='],
#  [u'=', u'2,'],
#  [u'2,', u'translates'],
#  [u'translates', u'to'],
#  [u'to', u'"(generic)'],
#  [u'"(generic)', u'name'],
#  [u'name', u'x'],
#  [u'x', u'receives'],
#  [u'receives', u'a'],
#  [u'a', u'reference'],
#  [u'reference', u'to'],
#  [u'to', u'a'],
#  [u'a', u'separate,'],
#  [u'separate,', u'dynamically'],
#  [u'dynamically', u'allocated'],
#  [u'allocated', u'object'],
#  [u'object', u'of'],
#  [u'of', u'numeric'],
#  [u'numeric', u'(int)'],
#  [u'(int)', u'type'],
#  [u'type', u'of'],
#  [u'of', u'value'],
#  [u'value', u'2."'],
#  [u'2."', u'This'],
#  [u'This', u'is'],
#  [u'is', u'termed'],
#  [u'termed', u'binding'],
#  [u'binding', u'the'],
#  [u'the', u'name'],
#  [u'name', u'to'],
#  [u'to', u'the'],
#  [u'the', u'object.'],
#  [u'object.', u'Since'],
#  [u'Since', u'the'],
#  [u'the', u"name's"],
#  [u"name's", u'storage'],
#  [u'storage', u'location'],
#  [u'location', u"doesn't"],
#  [u"doesn't", u'contain'],
#  [u'contain', u'the'],
#  [u'the', u'indicated'],
#  [u'indicated', u'value,'],
#  [u'value,', u'it'],
#  [u'it', u'is'],
#  [u'is', u'improper'],
#  [u'improper', u'to'],
#  [u'to', u'call'],
#  [u'call', u'it'],
#  [u'it', u'a'],
#  [u'a', u'variable.'],
#  [u'variable.', u'Names'],
#  [u'Names', u'may'],
#  [u'may', u'be'],
#  [u'be', u'subsequently'],
#  [u'subsequently', u'rebound'],
#  [u'rebound', u'at'],
#  [u'at', u'any'],
#  [u'any', u'time'],
#  [u'time', u'to'],
#  [u'to', u'objects'],
#  [u'objects', u'of'],
#  [u'of', u'greatly'],
#  [u'greatly', u'varying'],
#  [u'varying', u'types,'],
#  [u'types,', u'including'],
#  [u'including', u'strings,'],
#  [u'strings,', u'procedures,'],
#  [u'procedures,', u'complex'],
#  [u'complex', u'objects'],
#  [u'objects', u'with'],
#  [u'with', u'data'],
#  [u'data', u'and'],
#  [u'and', u'methods,'],
#  [u'methods,', u'etc.'],
#  [u'etc.', u'Successive'],
#  [u'Successive', u'assignments'],
#  [u'assignments', u'of'],
#  [u'of', u'a'],
#  [u'a', u'common'],
#  [u'common', u'value'],
#  [u'value', u'to'],
#  [u'to', u'multiple'],
#  [u'multiple', u'names,'],
#  [u'names,', u'e.g.,'],
#  [u'e.g.,', u'x'],
#  [u'x', u'='],
#  [u'=', u'2;'],
#  [u'2;', u'y'],
#  [u'y', u'='],
#  [u'=', u'2;'],
#  [u'2;', u'z'],
#  [u'z', u'='],
#  [u'=', u'2'],
#  [u'2', u'result'],
#  [u'result', u'in'],
#  [u'in', u'allocating'],
#  [u'allocating', u'storage'],
#  [u'storage', u'to'],
#  [u'to', u'(at'],
#  [u'(at', u'most)'],
#  [u'most)', u'three'],
#  [u'three', u'names'],
#  [u'names', u'and'],
#  [u'and', u'one'],
#  [u'one', u'numeric'],
#  [u'numeric', u'object,'],
#  [u'object,', u'to'],
#  [u'to', u'which'],
#  [u'which', u'all'],
#  [u'all', u'three'],
#  [u'three', u'names'],
#  [u'names', u'are'],
#  [u'are', u'bound.'],
#  [u'bound.', u'Since'],
#  [u'Since', u'a'],
#  [u'a', u'name'],
#  [u'name', u'is'],
#  [u'is', u'a'],
#  [u'a', u'generic'],
#  [u'generic', u'reference'],
#  [u'reference', u'holder'],
#  [u'holder', u'it'],
#  [u'it', u'is'],
#  [u'is', u'unreasonable'],
#  [u'unreasonable', u'to'],
#  [u'to', u'associate'],
#  [u'associate', u'a'],
#  [u'a', u'fixed'],
#  [u'fixed', u'data'],
#  [u'data', u'type'],
#  [u'type', u'with'],
#  [u'with', u'it.'],
#  [u'it.', u'However'],
#  [u'However', u'at'],
#  [u'at', u'a'],
#  [u'a', u'given'],
#  [u'given', u'time'],
#  [u'time', u'a'],
#  [u'a', u'name'],
#  [u'name', u'will'],
#  [u'will', u'be'],
#  [u'be', u'bound'],
#  [u'bound', u'to'],
#  [u'to', u'some'],
#  [u'some', u'object,'],
#  [u'object,', u'which'],
#  [u'which', u'will'],
#  [u'will', u'have'],
#  [u'have', u'a'],
#  [u'a', u'type;'],
#  [u'type;', u'thus'],
#  [u'thus', u'there'],
#  [u'there', u'is'],
#  [u'is', u'dynamic'],
#  [u'dynamic', u'typing.\nThe'],
#  [u'typing.\nThe', u'if'],
#  [u'if', u'statement,'],
#  [u'statement,', u'which'],
#  [u'which', u'conditionally'],
#  [u'conditionally', u'executes'],
#  [u'executes', u'a'],
#  [u'a', u'block'],
#  [u'block', u'of'],
#  [u'of', u'code,'],
#  [u'code,', u'along'],
#  [u'along', u'with'],
#  [u'with', u'else'],
#  [u'else', u'and'],
#  [u'and', u'elif'],
#  [u'elif', u'(a'],
#  [u'(a', u'contraction'],
#  [u'contraction', u'of'],
#  [u'of', u'else-if).\nThe'],
#  [u'else-if).\nThe', u'for'],
#  [u'for', u'statement,'],
#  [u'statement,', u'which'],
#  [u'which', u'iterates'],
#  [u'iterates', u'over'],
#  [u'over', u'an'],
#  [u'an', u'iterable'],
#  [u'iterable', u'object,'],
#  [u'object,', u'capturing'],
#  [u'capturing', u'each'],
#  [u'each', u'element'],
#  [u'element', u'to'],
#  [u'to', u'a'],
#  [u'a', u'local'],
#  [u'local', u'variable'],
#  [u'variable', u'for'],
#  [u'for', u'use'],
#  [u'use', u'by'],
#  [u'by', u'the'],
#  [u'the', u'attached'],
#  [u'attached', u'block.\nThe'],
#  [u'block.\nThe', u'while'],
#  [u'while', u'statement,'],
#  [u'statement,', u'which'],
#  [u'which', u'executes'],
#  [u'executes', u'a'],
#  [u'a', u'block'],
#  [u'block', u'of'],
#  [u'of', u'code'],
#  [u'code', u'as'],
#  [u'as', u'long'],
#  [u'long', u'as'],
#  [u'as', u'its'],
#  [u'its', u'condition'],
#  [u'condition', u'is'],
#  [u'is', u'true.\nThe'],
#  [u'true.\nThe', u'try'],
#  [u'try', u'statement,'],
#  [u'statement,', u'which'],
#  [u'which', u'allows'],
#  [u'allows', u'exceptions'],
#  [u'exceptions', u'raised'],
#  [u'raised', u'in'],
#  [u'in', u'its'],
#  [u'its', u'attached'],
#  [u'attached', u'code'],
#  [u'code', u'block'],
#  [u'block', u'to'],
#  [u'to', u'be'],
#  [u'be', u'caught'],
#  [u'caught', u'and'],
#  [u'and', u'handled'],
#  [u'handled', u'by'],
#  [u'by', u'except'],
#  [u'except', u'clauses;'],
#  [u'clauses;', u'it'],
#  [u'it', u'also'],
#  [u'also', u'ensures'],
#  [u'ensures', u'that'],
#  [u'that', u'clean-up'],
#  [u'clean-up', u'code'],
#  [u'code', u'in'],
#  [u'in', u'a'],
#  [u'a', u'finally'],
#  [u'finally', u'block'],
#  [u'block', u'will'],
#  [u'will', u'always'],
#  [u'always', u'be'],
#  [u'be', u'run'],
#  [u'run', u'regardless'],
#  [u'regardless', u'of'],
#  [u'of', u'how'],
#  [u'how', u'the'],
#  [u'the', u'block'],
#  [u'block', u'exits.\nThe'],
#  [u'exits.\nThe', u'class'],
#  [u'class', u'statement,'],
#  [u'statement,', u'which'],
#  [u'which', u'executes'],
#  [u'executes', u'a'],
#  [u'a', u'block'],
#  [u'block', u'of'],
#  [u'of', u'code'],
#  [u'code', u'and'],
#  [u'and', u'attaches'],
#  [u'attaches', u'its'],
#  [u'its', u'local'],
#  [u'local', u'namespace'],
#  [u'namespace', u'to'],
#  [u'to', u'a'],
#  [u'a', u'class,'],
#  [u'class,', u'for'],
#  [u'for', u'use'],
#  [u'use', u'in'],
#  [u'in', u'object-oriented'],
#  [u'object-oriented', u'programming.\nThe'],
#  [u'programming.\nThe', u'def'],
#  [u'def', u'statement,'],
#  [u'statement,', u'which'],
#  [u'which', u'defines'],
#  [u'defines', u'a'],
#  [u'a', u'function'],
#  [u'function', u'or'],
#  [u'or', u'method.\nThe'],
#  [u'method.\nThe', u'with'],
#  [u'with', u'statement'],
#  [u'statement', u'(from'],
#  [u'(from', u'Python'],
#  [u'Python', u'2.5),'],
#  [u'2.5),', u'which'],
#  [u'which', u'encloses'],
#  [u'encloses', u'a'],
#  [u'a', u'code'],
#  [u'code', u'block'],
#  [u'block', u'within'],
#  [u'within', u'a'],
#  [u'a', u'context'],
#  [u'context', u'manager'],
#  [u'manager', u'(for'],
#  [u'(for', u'example,'],
#  [u'example,', u'acquiring'],
#  [u'acquiring', u'a'],
#  [u'a', u'lock'],
#  [u'lock', u'before'],
#  [u'before', u'the'],
#  [u'the', u'block'],
#  [u'block', u'of'],
#  [u'of', u'code'],
#  [u'code', u'is'],
#  [u'is', u'run'],
#  [u'run', u'and'],
#  [u'and', u'releasing'],
#  [u'releasing', u'the'],
#  [u'the', u'lock'],
#  [u'lock', u'afterwards,'],
#  [u'afterwards,', u'or'],
#  [u'or', u'opening'],
#  [u'opening', u'a'],
#  [u'a', u'file'],
#  [u'file', u'and'],
#  [u'and', u'then'],
#  [u'then', u'closing'],
#  [u'closing', u'it),'],
#  [u'it),', u'allowing'],
#  [u'allowing', u'Resource'],
#  [u'Resource', u'Acquisition'],
#  [u'Acquisition', u'Is'],
#  [u'Is', u'Initialization'],
#  [u'Initialization', u'(RAII)-like'],
#  [u'(RAII)-like', u'behavior.\nThe'],
#  [u'behavior.\nThe', u'pass'],
#  [u'pass', u'statement,'],
#  [u'statement,', u'which'],
#  [u'which', u'serves'],
#  [u'serves', u'as'],
#  [u'as', u'a'],
#  [u'a', u'NOP.'],
#  [u'NOP.', u'It'],
#  [u'It', u'is'],
#  [u'is', u'syntactically'],
#  [u'syntactically', u'needed'],
#  [u'needed', u'to'],
#  [u'to', u'create'],
#  [u'create', u'an'],
#  [u'an', u'empty'],
#  [u'empty', u'code'],
#  [u'code', u'block.\nThe'],
#  [u'block.\nThe', u'assert'],
#  [u'assert', u'statement,'],
#  [u'statement,', u'used'],
#  [u'used', u'during'],
#  [u'during', u'debugging'],
#  [u'debugging', u'to'],
#  [u'to', u'check'],
#  [u'check', u'for'],
#  [u'for', u'conditions'],
#  [u'conditions', u'that'],
#  [u'that', u'ought'],
#  [u'ought', u'to'],
#  [u'to', u'apply.\nThe'],
#  [u'apply.\nThe', u'yield'],
#  [u'yield', u'statement,'],
#  [u'statement,', u'which'],
#  [u'which', u'returns'],
#  [u'returns', u'a'],
#  [u'a', u'value'],
#  [u'value', u'from'],
#  [u'from', u'a'],
#  [u'a', u'generator'],
#  [u'generator', u'function.'],
#  [u'function.', u'From'],
#  [u'From', u'Python'],
#  [u'Python', u'2.5,'],
#  [u'2.5,', u'yield'],
#  [u'yield', u'is'],
#  [u'is', u'also'],
#  [u'also', u'an'],
#  [u'an', u'operator.'],
#  [u'operator.', u'This'],
#  [u'This', u'form'],
#  [u'form', u'is'],
#  [u'is', u'used'],
#  [u'used', u'to'],
#  [u'to', u'implement'],
#  [u'implement', u'coroutines.\nThe'],
#  [u'coroutines.\nThe', u'import'],
#  [u'import', u'statement,'],
#  [u'statement,', u'which'],
#  [u'which', u'is'],
#  [u'is', u'used'],
#  [u'used', u'to'],
#  [u'to', u'import'],
#  [u'import', u'modules'],
#  [u'modules', u'whose'],
#  [u'whose', u'functions'],
#  [u'functions', u'or'],
#  [u'or', u'variables'],
#  [u'variables', u'can'],
#  [u'can', u'be'],
#  [u'be', u'used'],
#  [u'used', u'in'],
#  [u'in', u'the'],
#  [u'the', u'current'],
#  [u'current', u'program.\nThe'],
#  [u'program.\nThe', u'print'],
#  [u'print', u'statement'],
#  [u'statement', u'was'],
#  [u'was', u'changed'],
#  [u'changed', u'to'],
#  [u'to', u'the'],
#  [u'the', u'print()'],
#  [u'print()', u'function'],
#  [u'function', u'in'],
#  [u'in', u'Python'],
#  [u'Python', u'3.[55]\n\nPython'],
#  [u'3.[55]\n\nPython', u'does'],
#  [u'does', u'not'],
#  [u'not', u'support'],
#  [u'support', u'tail'],
#  [u'tail', u'call'],
#  [u'call', u'optimization'],
#  [u'optimization', u'or'],
#  [u'or', u'first-class'],
#  [u'first-class', u'continuations,'],
#  [u'continuations,', u'and,'],
#  [u'and,', u'according'],
#  [u'according', u'to'],
#  [u'to', u'Guido'],
#  [u'Guido', u'van'],
#  [u'van', u'Rossum,'],
#  [u'Rossum,', u'it'],
#  [u'it', u'never'],
#  [u'never', u'will.[56][57]'],
#  [u'will.[56][57]', u'However,'],
#  [u'However,', u'better'],
#  [u'better', u'support'],
#  [u'support', u'for'],
#  [u'for', u'coroutine-like'],
#  [u'coroutine-like', u'functionality'],
#  [u'functionality', u'is'],
#  [u'is', u'provided'],
#  [u'provided', u'in'],
#  [u'in', u'2.5,'],
#  [u'2.5,', u'by'],
#  [u'by', u'extending'],
#  [u'extending', u"Python's"],
#  [u"Python's", u'generators.[58]'],
#  [u'generators.[58]', u'Before'],
#  [u'Before', u'2.5,'],
#  [u'2.5,', u'generators'],
#  [u'generators', u'were'],
#  [u'were', u'lazy'],
#  [u'lazy', u'iterators;'],
#  [u'iterators;', u'information'],
#  [u'information', u'was'],
#  [u'was', u'passed'],
#  [u'passed', u'unidirectionally'],
#  [u'unidirectionally', u'out'],
#  [u'out', u'of'],
#  [u'of', u'the'],
#  [u'the', u'generator.'],
#  [u'generator.', u'As'],
#  [u'As', u'of'],
#  [u'of', u'Python'],
#  [u'Python', u'2.5,'],
#  [u'2.5,', u'it'],
#  [u'it', u'is'],
#  [u'is', u'possible'],
#  [u'possible', u'to'],
#  [u'to', u'pass'],
#  [u'pass', u'information'],
#  [u'information', u'back'],
#  [u'back', u'into'],
#  [u'into', u'a'],
#  [u'a', u'generator'],
#  [u'generator', u'function,'],
#  [u'function,', u'and'],
#  [u'and', u'as'],
#  [u'as', u'of'],
#  [u'of', u'Python'],
#  [u'Python', u'3.3,'],
#  [u'3.3,', u'the'],
#  [u'the', u'information'],
#  [u'information', u'can'],
#  [u'can', u'be'],
#  [u'be', u'passed'],
#  [u'passed', u'through'],
#  [u'through', u'multiple'],
#  [u'multiple', u'stack'],
#  [u'stack', u'levels.[59]\nExpressions[edit]\nSome'],
#  [u'levels.[59]\nExpressions[edit]\nSome', u'Python'],
#  [u'Python', u'expressions'],
#  [u'expressions', u'are'],
#  [u'are', u'similar'],
#  [u'similar', u'to'],
#  [u'to', u'languages'],
#  [u'languages', u'such'],
#  [u'such', u'as'],
#  [u'as', u'C'],
#  [u'C', u'and'],
#  [u'and', u'Java,'],
#  [u'Java,', u'while'],
#  [u'while', u'some'],
#  [u'some', u'are'],
#  [u'are', u'not:\n\nAddition,'],
#  [u'not:\n\nAddition,', u'subtraction,'],
#  [u'subtraction,', u'and'],
#  [u'and', u'multiplication'],
#  [u'multiplication', u'are'],
#  [u'are', u'the'],
#  [u'the', u'same,'],
#  [u'same,', u'but'],
#  [u'but', u'the'],
#  [u'the', u'behavior'],
#  [u'behavior', u'of'],
#  [u'of', u'division'],
#  [u'division', u'differs'],
#  [u'differs', u'(see'],
#  [u'(see', u'Mathematics'],
#  [u'Mathematics', u'for'],
#  [u'for', u'details).'],
#  [u'details).', u'Python'],
#  [u'Python', u'also'],
#  [u'also', u'added'],
#  [u'added', u'the'],
#  [u'the', u'**'],
#  [u'**', u'operator'],
#  [u'operator', u'for'],
#  [u'for', u'exponentiation.\nAs'],
#  [u'exponentiation.\nAs', u'of'],
#  [u'of', u'Python'],
#  [u'Python', u'3.5,'],
#  [u'3.5,', u'it'],
#  [u'it', u'supports'],
#  [u'supports', u'matrix'],
#  [u'matrix', u'multiplication'],
#  [u'multiplication', u'directly'],
#  [u'directly', u'with'],
#  [u'with', u'the'],
#  [u'the', u'@'],
#  [u'@', u'operator,'],
#  [u'operator,', u'versus'],
#  [u'versus', u'C'],
#  [u'C', u'and'],
#  [u'and', u'Java,'],
#  [u'Java,', u'which'],
#  [u'which', u'implement'],
#  [u'implement', u'these'],
#  [u'these', u'as'],
#  [u'as', u'library'],
#  [u'library', u'functions.'],
#  [u'functions.', u'Earlier'],
#  [u'Earlier', u'versions'],
#  [u'versions', u'of'],
#  [u'of', u'Python'],
#  [u'Python', u'also'],
#  [u'also', u'used'],
#  [u'used', u'methods'],
#  [u'methods', u'instead'],
#  [u'instead', u'of'],
#  [u'of', u'an'],
#  [u'an', u'infix'],
#  [u'infix', u'operator.[60][61]\nIn'],
# ...
#  [u'Interview', u'with'],
#  [u'with', u'the'],
#  [u'the', u'Creator'],
#  [u'Creator', u'of'],
#  [u'of', u'Ruby".'],
#  [u'Ruby".', u'Linuxdevcenter.com.'],
#  [u'Linuxdevcenter.com.', u'Retrieved'],
#  [u'Retrieved', u'3'],
#  [u'3', u'December'],
#  [u'December', u'2012.\xa0\n^'],
#  [u'2012.\xa0\n^', u'Lattner,'],
#  [u'Lattner,', u'Chris'],
#  [u'Chris', u'(3'],
#  [u'(3', u'June'],
#  [u'June', u'2014).'],
#  [u'2014).', u'"Chris'],
#  [u'"Chris', u"Lattner's"],
#  [u"Lattner's", u'Homepage".'],
#  [u'Homepage".', u'Chris'],
#  [u'Chris', u'Lattner.'],
#  [u'Lattner.', u'Retrieved'],
#  [u'Retrieved', u'3'],
#  [u'3', u'June'],
#  [u'June', u'2014.'],
#  [u'2014.', u'I'],
#  [u'I', u'started'],
#  [u'started', u'work'],
#  [u'work', u'on'],
#  [u'on', u'the'],
#  [u'the', u'Swift'],
#  [u'Swift', u'Programming'],
#  [u'Programming', u'Language'],
#  [u'Language', u'in'],
#  [u'in', u'July'],
#  [u'July', u'of'],
#  [u'of', u'2010.'],
#  [u'2010.', u'I'],
#  [u'I', u'implemented'],
#  [u'implemented', u'much'],
#  [u'much', u'of'],
#  [u'of', u'the'],
#  [u'the', u'basic'],
#  [u'basic', u'language'],
#  [u'language', u'structure,'],
#  [u'structure,', u'with'],
#  [u'with', u'only'],
#  [u'only', u'a'],
#  [u'a', u'few'],
#  [u'few', u'people'],
#  [u'people', u'knowing'],
#  [u'knowing', u'of'],
#  [u'of', u'its'],
#  [u'its', u'existence.'],
#  [u'existence.', u'A'],
#  [u'A', u'few'],
#  [u'few', u'other'],
#  [u'other', u'(amazing)'],
#  [u'(amazing)', u'people'],
#  [u'people', u'started'],
#  [u'started', u'contributing'],
#  [u'contributing', u'in'],
#  [u'in', u'earnest'],
#  [u'earnest', u'late'],
#  [u'late', u'in'],
#  [u'in', u'2011,'],
#  [u'2011,', u'and'],
#  [u'and', u'it'],
#  [u'it', u'became'],
#  [u'became', u'a'],
#  [u'a', u'major'],
#  [u'major', u'focus'],
#  [u'focus', u'for'],
#  [u'for', u'the'],
#  [u'the', u'Apple'],
#  [u'Apple', u'Developer'],
#  [u'Developer', u'Tools'],
#  [u'Tools', u'group'],
#  [u'group', u'in'],
#  [u'in', u'July'],
#  [u'July', u'2013'],
#  [u'2013', u'[...]'],
#  [u'[...]', u'drawing'],
#  [u'drawing', u'ideas'],
#  [u'ideas', u'from'],
#  [u'from', u'Objective-C,'],
#  [u'Objective-C,', u'Rust,'],
#  [u'Rust,', u'Haskell,'],
#  [u'Haskell,', u'Ruby,'],
#  [u'Ruby,', u'Python,'],
#  [u'Python,', u'C#,'],
#  [u'C#,', u'CLU,'],
#  [u'CLU,', u'and'],
#  [u'and', u'far'],
#  [u'far', u'too'],
#  [u'too', u'many'],
#  [u'many', u'others'],
#  [u'others', u'to'],
#  [u'to', u'list.\xa0\n^'],
#  [u'list.\xa0\n^', u'Kupries,'],
#  [u'Kupries,', u'Andreas;'],
#  [u'Andreas;', u'Fellows,'],
#  [u'Fellows,', u'Donal'],
#  [u'Donal', u'K.'],
#  [u'K.', u'(14'],
#  [u'(14', u'September'],
#  [u'September', u'2000).'],
#  [u'2000).', u'"TIP'],
#  [u'"TIP', u'#3:'],
#  [u'#3:', u'TIP'],
#  [u'TIP', u'Format".'],
#  [u'Format".', u'tcl.tk.'],
#  [u'tcl.tk.', u'Tcl'],
#  [u'Tcl', u'Developer'],
#  [u'Developer', u'Xchange.'],
#  [u'Xchange.', u'Retrieved'],
#  [u'Retrieved', u'24'],
#  [u'24', u'November'],
#  [u'November', u'2008.\xa0\n^'],
#  [u'2008.\xa0\n^', u'Gustafsson,'],
#  [u'Gustafsson,', u'Per;'],
#  [u'Per;', u'Niskanen,'],
#  [u'Niskanen,', u'Raimo'],
#  [u'Raimo', u'(29'],
#  [u'(29', u'January'],
#  [u'January', u'2007).'],
#  [u'2007).', u'"EEP'],
#  [u'"EEP', u'1:'],
#  [u'1:', u'EEP'],
#  [u'EEP', u'Purpose'],
#  [u'Purpose', u'and'],
#  [u'and', u'Guidelines".'],
#  [u'Guidelines".', u'erlang.org.'],
#  [u'erlang.org.', u'Retrieved'],
#  [u'Retrieved', u'19'],
#  [u'19', u'April'],
#  [u'April', u'2011.\xa0\n^'],
#  [u'2011.\xa0\n^', u'"TIOBE'],
#  [u'"TIOBE', u'Programming'],
#  [u'Programming', u'Community'],
#  [u'Community', u'Index'],
#  [u'Index', u'for'],
#  [u'for', u'March'],
#  [u'March', u'2012".'],
#  [u'2012".', u'TIOBE'],
#  [u'TIOBE', u'Software.'],
#  [u'Software.', u'March'],
#  [u'March', u'2012.'],
#  [u'2012.', u'Retrieved'],
#  [u'Retrieved', u'25'],
#  [u'25', u'March'],
#  [u'March', u'2012.\xa0\n\n\nFurther'],
#  [u'2012.\xa0\n\n\nFurther', u'reading[edit]\n\nDowney,'],
#  [u'reading[edit]\n\nDowney,', u'Allen'],
#  [u'Allen', u'B'],
#  [u'B', u'(May'],
#  [u'(May', u'2012).'],
#  [u'2012).', u'Think'],
#  [u'Think', u'Python:'],
#  [u'Python:', u'How'],
#  [u'How', u'to'],
#  [u'to', u'Think'],
#  [u'Think', u'Like'],
#  [u'Like', u'a'],
#  [u'a', u'Computer'],
#  [u'Computer', u'Scientist'],
#  [u'Scientist', u'(Version'],
#  [u'(Version', u'1.6.6'],
#  [u'1.6.6', u'ed.).'],
#  [u'ed.).', u'ISBN\xa0978-0-521-72596-5.\xa0\nHamilton,'],
#  [u'ISBN\xa0978-0-521-72596-5.\xa0\nHamilton,', u'Naomi'],
#  [u'Naomi', u'(5'],
#  [u'(5', u'August'],
#  [u'August', u'2008).'],
#  [u'2008).', u'"The'],
#  [u'"The', u'A-Z'],
#  [u'A-Z', u'of'],
#  [u'of', u'Programming'],
#  [u'Programming', u'Languages:'],
#  [u'Languages:', u'Python".'],
#  [u'Python".', u'Computerworld.'],
#  [u'Computerworld.', u'Retrieved'],
#  [u'Retrieved', u'31'],
#  [u'31', u'March'],
#  [u'March', u'2010.\xa0\nLutz,'],
#  [u'2010.\xa0\nLutz,', u'Mark'],
#  [u'Mark', u'(2013).'],
#  [u'(2013).', u'Learning'],
#  [u'Learning', u'Python'],
#  [u'Python', u'(5th'],
#  [u'(5th', u'ed.).'],
#  [u'ed.).', u"O'Reilly"],
#  [u"O'Reilly", u'Media.'],
#  [u'Media.', u'ISBN\xa0978-0-596-15806-4.\xa0\nPilgrim,'],
#  [u'ISBN\xa0978-0-596-15806-4.\xa0\nPilgrim,', u'Mark'],
#  [u'Mark', u'(2004).'],
#  [u'(2004).', u'Dive'],
#  [u'Dive', u'Into'],
#  [u'Into', u'Python.'],
#  [u'Python.', u'Apress.'],
#  [u'Apress.', u'ISBN\xa0978-1-59059-356-1.\xa0\nPilgrim,'],
#  [u'ISBN\xa0978-1-59059-356-1.\xa0\nPilgrim,', u'Mark'],
#  [u'Mark', u'(2009).'],
#  [u'(2009).', u'Dive'],
#  [u'Dive', u'Into'],
#  [u'Into', u'Python'],
#  [u'Python', u'3.'],
#  [u'3.', u'Apress.'],
#  [u'Apress.', u'ISBN\xa0978-1-4302-2415-0.\xa0\nSummerfield,'],
#  [u'ISBN\xa0978-1-4302-2415-0.\xa0\nSummerfield,', u'Mark'],
#  [u'Mark', u'(2009).'],
#  [u'(2009).', u'Programming'],
#  [u'Programming', u'in'],
#  [u'in', u'Python'],
#  [u'Python', u'3'],
#  [u'3', u'(2nd'],
#  [u'(2nd', u'ed.).'],
#  [u'ed.).', u'Addison-Wesley'],
#  [u'Addison-Wesley', u'Professional.'],
#  [u'Professional.', u'ISBN\xa0978-0-321-68056-3.\xa0\n\nExternal'],
#  [u'ISBN\xa0978-0-321-68056-3.\xa0\n\nExternal', u'links[edit]\n\n\n\nFind'],
#  [u'links[edit]\n\n\n\nFind', u'more'],
#  [u'more', u'about\nPython'],
#  [u'about\nPython', u'(programming'],
#  [u'(programming', u'language)\nat'],
#  [u'language)\nat', u"Wikipedia's"],
#  [u"Wikipedia's", u'sister'],
#  [u'sister', u'projects\n\n\n\n\nMedia'],
#  [u'projects\n\n\n\n\nMedia', u'from'],
#  [u'from', u'Commons\n\n\n\nQuotations'],
#  [u'Commons\n\n\n\nQuotations', u'from'],
#  [u'from', u'Wikiquote\n\n\n\nTextbooks'],
#  [u'Wikiquote\n\n\n\nTextbooks', u'from'],
#  [u'from', u'Wikibooks\n\n\n\nLearning'],
#  [u'Wikibooks\n\n\n\nLearning', u'resources'],
#  [u'resources', u'from'],
#  [u'from', u'Wikiversity\n\n\n\nOfficial'],
#  [u'Wikiversity\n\n\n\nOfficial', u'website\nPython'],
#  [u'website\nPython', u'(programming'],
#  [u'(programming', u'language)'],
#  [u'language)', u'newsgroup'],
#  [u'newsgroup', u'on'],
#  [u'on', u'Usenet'],
#  [u'Usenet', u'(alternative'],
#  [u'(alternative', u'free'],
#  [u'free', u'web'],
#  [u'web', u'access'],
#  [u'access', u'using'],
#  [u'using', u'Google'],
#  [u'Google', u'Groups)\nThe'],
#  [u'Groups)\nThe', u'History'],
#  [u'History', u'of'],
#  [u'of', u'Python'],
#  [u'Python', u'(blog'],
#  [u'(blog', u'by'],
#  [u'by', u'Guido'],
#  [u'Guido', u'van'],
#  [u'van', u'Rossum)\nPython'],
#  [u'Rossum)\nPython', u'development'],
#  [u'development', u'list\nPython'],
#  [u'list\nPython', u'at'],
#  [u'at', u'DMOZ\n\n\n\n\n\n\n\nv\nt\ne\n\n\nProgramming'],
#  [u'DMOZ\n\n\n\n\n\n\n\nv\nt\ne\n\n\nProgramming',
#   u'languages\n\n\n\n\n\n\n\n\n\nComparison\nTimeline\nHistory\n\n\n\n\n\n\n\n\n\n\n\nAssembly\nBASIC\nC\nC++\nC#\nCOBOL\nFortran\nGo\nHaskell\nJava\nJavaScript'],
#  [u'languages\n\n\n\n\n\n\n\n\n\nComparison\nTimeline\nHistory\n\n\n\n\n\n\n\n\n\n\n\nAssembly\nBASIC\nC\nC++\nC#\nCOBOL\nFortran\nGo\nHaskell\nJava\nJavaScript',
#   u'(JS)\nLisp\nLua\nObjective-C\nPascal\nPerl\nPHP\nPython\nRuby\nShell\nSmalltalk\nSwift\nVisual'],
#  [u'(JS)\nLisp\nLua\nObjective-C\nPascal\nPerl\nPHP\nPython\nRuby\nShell\nSmalltalk\nSwift\nVisual',
#   u'Basic'],
#  [u'Basic', u'.NET'],
#  [u'.NET', u'(VB.NET)\nmore...\n\n\n\n\n\n\n\n\n\n\n\n'],
#  [u'(VB.NET)\nmore...\n\n\n\n\n\n\n\n\n\n\n\n', u'Category\n'],
#  [u'Category\n', u'Comparison\n'],
#  [u'Comparison\n',
#   u'Lists\n\nAlphabetical\nCategorical\nGenerational\nNon-English-based\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nv\nt\ne\n\n\nPython\n\n\n\n\n\n\nImplementations\n\n\n\nCLPython\nCPython\nCython\nIronPython\nJython\nPsyco\nPyPy\nPython'],
#  [u'Lists\n\nAlphabetical\nCategorical\nGenerational\nNon-English-based\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nv\nt\ne\n\n\nPython\n\n\n\n\n\n\nImplementations\n\n\n\nCLPython\nCPython\nCython\nIronPython\nJython\nPsyco\nPyPy\nPython',
#   u'for'],
#  [u'for', u'S60\nStackless'],
#  [u'S60\nStackless', u'Python\nUnladen'],
#  [u'Python\nUnladen', u'Swallow\n\n\n\n\n\n\n\n\n\n\n\nIDE\n\n\n\nBoa\nEric'],
#  [u'Swallow\n\n\n\n\n\n\n\n\n\n\n\nIDE\n\n\n\nBoa\nEric', u'Python'],
#  [u'Python',
#   u'IDE\nIDLE\nPyDev\nSPE\nNinja-IDE\nmore...\n\n\n\n\n\n\n\n\nTopics\n\n\n\nWSGI\n\n\n\n\n\n\n\n\n\n\n\nsoftware'],
#  [u'IDE\nIDLE\nPyDev\nSPE\nNinja-IDE\nmore...\n\n\n\n\n\n\n\n\nTopics\n\n\n\nWSGI\n\n\n\n\n\n\n\n\n\n\n\nsoftware',
#   u'(list)\nPython'],
#  [u'(list)\nPython', u'Software'],
#  [u'Software',
#   u'Foundation\nPyCon\n\n\n\n\n\n\n\n\n\n\n\n\nv\nt\ne\n\n\nPython'],
#  [u'Foundation\nPyCon\n\n\n\n\n\n\n\n\n\n\n\n\nv\nt\ne\n\n\nPython', u'web'],
#  [u'web',
#   u'frameworks\n\n\n\n\n\n\n\n\n\nBlueBream\nCherryPy\nDjango\nFlask\nGrok\nNagare\nNevow\nPyjamas\nPylons\nPyramid\nQuixote\nSpyce\nTACTIC\nTornado\nTurboGears\nTwistedWeb\nWebware\nweb2py\nZope'],
#  [u'frameworks\n\n\n\n\n\n\n\n\n\nBlueBream\nCherryPy\nDjango\nFlask\nGrok\nNagare\nNevow\nPyjamas\nPylons\nPyramid\nQuixote\nSpyce\nTACTIC\nTornado\nTurboGears\nTwistedWeb\nWebware\nweb2py\nZope',
#   u'2\nmore...\n\n\n\n\n\n\n\n\n\n\n\n\nv\nt\ne\n\n\nFree'],
#  [u'2\nmore...\n\n\n\n\n\n\n\n\n\n\n\n\nv\nt\ne\n\n\nFree', u'and'],
#  [u'and', u'open-source'],
#  [u'open-source', u'software\n\n\n\n\n\n\nGeneral\n\n\n\nAlternative'],
#  [u'software\n\n\n\n\n\n\nGeneral\n\n\n\nAlternative', u'terms'],
#  [u'terms', u'for'],
#  [u'for', u'free'],
#  [u'free', u'software\nComparison'],
#  [u'software\nComparison', u'of'],
#  [u'of', u'open-source'],
#  [u'open-source', u'and'],
#  [u'and', u'closed-source'],
#  [u'closed-source', u'software\nComparison'],
#  [u'software\nComparison', u'of'],
#  [u'of', u'source'],
#  [u'source', u'code'],
#  [u'code', u'hosting'],
#  [u'hosting', u'facilities\nFree'],
#  [u'facilities\nFree', u'software\nFree'],
#  [u'software\nFree', u'software'],
#  [u'software', u'project'],
#  [u'project', u'directories\nGratis'],
#  [u'directories\nGratis', u'versus'],
#  [u'versus', u'libre\nLong-term'],
#  [u'libre\nLong-term', u'support\nOpen-source'],
#  [u'support\nOpen-source', u'software\nOpen-source'],
#  [u'software\nOpen-source', u'software'],
#  [u'software',
#   u'development\nOutline\n\n\n\n\n\n\n\n\nSoftware\npackages\n\n\n\nAudio\nBioinformatics\nCodecs\nCollaboration\nConfiguration'],
#  [u'development\nOutline\n\n\n\n\n\n\n\n\nSoftware\npackages\n\n\n\nAudio\nBioinformatics\nCodecs\nCollaboration\nConfiguration',
#   u'management\nDevice'],
#  [u'management\nDevice',
#   u'drivers\n\nGraphics\nWireless\n\n\nGeophysics\nHealth\nMathematics\nOperating'],
#  [u'drivers\n\nGraphics\nWireless\n\n\nGeophysics\nHealth\nMathematics\nOperating',
#   u'systems\nProgramming'],
#  [u'systems\nProgramming',
#   u'languages\nRouting\nStatistics\nTelevision\nVideo'],
#  [u'languages\nRouting\nStatistics\nTelevision\nVideo', u'games\nWeb'],
#  [u'games\nWeb', u'applications\n\nContent'],
#  [u'applications\n\nContent', u'management'],
#  [u'management', u'systems\nE-commerce\n\n\nWord'],
#  [u'systems\nE-commerce\n\n\nWord', u'processors\nAndroid'],
#  [u'processors\nAndroid', u'apps\niOS'],
#  [u'apps\niOS', u'apps\nCommercial\nTrademarked\nFormerly'],
#  [u'apps\nCommercial\nTrademarked\nFormerly',
#   u'proprietary\n\n\n\n\n\n\n\n\nCommunity\n\n\n\nFree'],
#  [u'proprietary\n\n\n\n\n\n\n\n\nCommunity\n\n\n\nFree', u'software'],
#  [u'software', u'movement\nHistory\nOpen-source'],
#  [u'movement\nHistory\nOpen-source',
#   u'movement\nOrganizations\nEvents\n\n\n\n\n\n\n\n\nLicenses\n\n\n\nApache\nAPSL\nArtistic\nBeerware\nBoost\nBSD\nCC0\nCDDL\nEPL\nGNU'],
#  [u'movement\nOrganizations\nEvents\n\n\n\n\n\n\n\n\nLicenses\n\n\n\nApache\nAPSL\nArtistic\nBeerware\nBoost\nBSD\nCC0\nCDDL\nEPL\nGNU',
#   u'GPL\nGNU'],
#  [u'GPL\nGNU',
#   u'LGPL\nISC\nMIT\nMPL\nMs-PL/RL\nWTFPL\nzlib\n\n\n\n\n\n\n\n\nLicense'],
#  [u'LGPL\nISC\nMIT\nMPL\nMs-PL/RL\nWTFPL\nzlib\n\n\n\n\n\n\n\n\nLicense',
#   u'types\nand'],
#  [u'types\nand', u'standards\n\n\n\nComparison'],
#  [u'standards\n\n\n\nComparison', u'of'],
#  [u'of', u'free'],
#  [u'free', u'and'],
#  [u'and', u'open-source'],
#  [u'open-source', u'software'],
#  [u'software', u'licenses\nContributor'],
#  [u'licenses\nContributor', u'License'],
#  [u'License', u'Agreement\nCopyfree\nCopyleft\nDebian'],
#  [u'Agreement\nCopyfree\nCopyleft\nDebian', u'Free'],
#  [u'Free', u'Software'],
#  [u'Software', u'Guidelines\nDefinition'],
#  [u'Guidelines\nDefinition', u'of'],
#  [u'of', u'Free'],
#  [u'Free', u'Cultural'],
#  [u'Cultural', u'Works\nFree'],
#  [u'Works\nFree', u'license\nThe'],
#  [u'license\nThe', u'Free'],
#  [u'Free', u'Software'],
#  [u'Software', u'Definition\nThe'],
#  [u'Definition\nThe', u'Open'],
#  [u'Open', u'Source'],
#  [u'Source', u'Definition\nOpen-source'],
#  [u'Definition\nOpen-source', u'license\nPermissive'],
#  [u'license\nPermissive', u'free'],
#  [u'free', u'software'],
#  [u'software', u'licence\nPublic'],
#  [u'licence\nPublic', u'domain\nViral'],
#  [u'domain\nViral', u'license\n\n\n\n\n\n\n\n\nChallenges\n\n\n\nBinary'],
#  [u'license\n\n\n\n\n\n\n\n\nChallenges\n\n\n\nBinary', u'blob\nDigital'],
#  [u'blob\nDigital', u'rights'],
#  [u'rights', u'management\nHardware'],
#  [u'management\nHardware', u'restrictions\nLicense'],
#  [u'restrictions\nLicense', u'proliferation\nMozilla'],
#  [u'proliferation\nMozilla', u'software'],
#  [u'software', u'rebranding\nProprietary'],
#  [u'rebranding\nProprietary', u'software\nSCO/Linux'],
#  [u'software\nSCO/Linux', u'controversies\nSecure'],
#  [u'controversies\nSecure', u'boot\nSoftware'],
#  [u'boot\nSoftware', u'patents\nSoftware'],
#  [u'patents\nSoftware', u'security\nTrusted'],
#  [u'security\nTrusted', u'Computing\n\n\n\n\n\n\n\n\nRelated'],
#  [u'Computing\n\n\n\n\n\n\n\n\nRelated', u'topics\n\n\n\nThe'],
#  [u'topics\n\n\n\nThe', u'Cathedral'],
#  [u'Cathedral', u'and'],
#  [u'and', u'the'],
#  [u'the', u'Bazaar\nForking\nMicrosoft'],
#  [u'Bazaar\nForking\nMicrosoft', u'Open'],
#  [u'Open', u'Specification'],
#  [u'Specification', u'Promise\nRevolution'],
#  [u'Promise\nRevolution', u'OS\n\n\n\n\n\n\n\n\n\n\n\n'],
#  [u'OS\n\n\n\n\n\n\n\n\n\n\n\n', u'Book\n'],
#  [u'Book\n', u'Category\n'],
#  [u'Category\n', u'Commons\n'],
#  [u'Commons\n', u'Portal\n\n\n\n\n\n\n\n\n\nAuthority'],
#  [u'Portal\n\n\n\n\n\n\n\n\n\nAuthority', u'control\n\n\n\nLCCN:'],
#  [u'control\n\n\n\nLCCN:', u'sh96008834\nGND:'],
#  [u'sh96008834\nGND:',
#   u'4434275-5\n\n\n\n\n\n\n\n(window.RLQ=window.RLQ||[]).push(function(){mw.log.warn("Gadget'],
#  [u'4434275-5\n\n\n\n\n\n\n\n(window.RLQ=window.RLQ||[]).push(function(){mw.log.warn("Gadget',
#   u'\\"teahouse\\"'],
#  [u'\\"teahouse\\"', u'styles'],
#  [u'styles', u'loaded'],
#  [u'loaded', u'twice.'],
#  [u'twice.', u'Migrate'],
#  [u'Migrate', u'to'],
#  [u'to', u'type=general.'],
#  [u'type=general.', u'See'],
#  [u'See',
#   u'\\u003Chttps://phabricator.wikimedia.org/T42284\\u003E.");mw.log.warn("Gadget'],
#  [u'\\u003Chttps://phabricator.wikimedia.org/T42284\\u003E.");mw.log.warn("Gadget',
#   u'\\"ReferenceTooltips\\"'],
#  [u'\\"ReferenceTooltips\\"', u'styles'],
#  [u'styles', u'loaded'],
#  [u'loaded', u'twice.'],
#  [u'twice.', u'Migrate'],
#  [u'Migrate', u'to'],
#  [u'to', u'type=general.'],
#  [u'type=general.', u'See'],
#  [u'See',
#   u'\\u003Chttps://phabricator.wikimedia.org/T42284\\u003E.");mw.log.warn("Gadget'],
#  [u'\\u003Chttps://phabricator.wikimedia.org/T42284\\u003E.");mw.log.warn("Gadget',
#   u'\\"featured-articles-links\\"'],
#  [u'\\"featured-articles-links\\"', u'styles'],
#  [u'styles', u'loaded'],
#  [u'loaded', u'twice.'],
#  [u'twice.', u'Migrate'],
#  [u'Migrate', u'to'],
#  [u'to', u'type=general.'],
#  [u'type=general.', u'See'],
#  [u'See', u'\\u003Chttps://phabricator.wikimedia.org/T42284\\u003E.");});']]
# 2-grams count is: 8253

# %% [markdown]
# ## 1.1 Clean the data ##

# %%
from urllib2 import urlopen
from bs4 import BeautifulSoup
import re
import string
from collections import OrderedDict
import pprint

# Clean the data
def cleanInput(input):
    # Replace all newline characters with a space
    input = re.sub('\n+', " ", input)
    
    # Remove wikipedia citation marks which are of the form [24]
    input = re.sub('\[[0-9]*\]', "", input)
    
    # replace all instances of multiple spaces with single space
    input = re.sub(' +', " ", input)
    
    # Eleminate escape characters by encoding the content with UTF-8
    input = input.encode('utf-8')
    input = input.decode("ascii", "ignore")
    
    cleanInput = []
    input = input.split(' ')
    
    # remove all punctuation marks
    for item in input:
        item = item.strip(string.punctuation)
        # Remove all single character words except 'i' and 'a'
        if len(item) > 1 or (item.lower() == 'a' or item.lower() == 'i'):
            cleanInput.append(item)
    return cleanInput

# Same as in 1.1
def getNgrams(input, n):
    input = cleanInput(input)
    output = dict()
    for i in range(len(input)-n+1):
        newNGram = " ".join(input[i:i+n])
        if newNGram in output:
            output[newNGram] += 1
        else:
            output[newNGram] = 1
    return output

html = urlopen("http://en.wikipedia.org/wiki/Python_(programming_language)")
bsObj = BeautifulSoup(html, "html.parser")

# Get the textual data without the HTML
content = bsObj.find("div", {"id":"mw-content-text"}).get_text()

# 2-gram
ngrams = getNgrams(content, 2)

# Order the output in the form of a dictionary sorted in descending order in terms of value
ngrams = OrderedDict(sorted(ngrams.items(), 
                            key = lambda t: t[1], 
                            reverse=True))
pprint.pprint(ngrams)
# Out:
# OrderedDict([(u'Software Foundation', 37), (u'Python Software', 37), (u'of Python', 36), (u'of the', 34), (u'Foundation Retrieved', 32), (u'in the', 21), (u'such as', 20), (u'in Python', 19), (u'van Rossum', 19), (u'Retrieved 24', 18), (u'is a', 18), (u'February 2012', 17), (u'Python Enhancement', 15), (u'from the', 15), (u'to the', 15), (u'Python is', 14), (u'the Python', 14), (u'Enhancement Proposals', 14), (u'Proposals Python', 14), (u'Python has', 13), (u'can be', 12), (u'standard library', 12), (u'as a', 12), (u'Rossum Guido', 12), (u'be used', 11), (u'for the', 10), (u'Python and', 10), (u'of a', 10), (u'by the', 10), (u'programming language', 10), (u'statement which', 9), (u'Python Python', 9), (u'and a', 9), (u'to be', 9), (u'November 2008', 9), (u'December 2012', 9), (u'The Python', 9), (u'with the', 9), (u'24 November', 9), (u'used to', 8), (u'it is', 8), (u'for Python', 8), (u'August 2016', 8), (u'Retrieved December', 8), (u'Retrieved 19', 8), (u'11 February', 7), (u'Python for', 7), (u'programming languages', 7), (u'written in', 7), (u'Retrieved 20', 7), (u'Retrieved 27', 7), (u'is the', 7), (u'a Python', 7), (u'June 2009', 7), (u'for example', 7), (u'Retrieved 11', 7), (u'in a', 7), (u'the language', 7), (u'used in', 7), (u'Guido van', 7), (u'has been', 6), (u'on the', 6), (u'to Python', 6), (u'Python as', 6), (u'and is', 6), (u'Comparison of', 6), (u'and Python', 6), (u'is also', 6), (u'part of', 6), (u'scripting language', 6), (u'Archived from', 6), (u'September 2011', 6), (u'24 September', 6), (u'has a', 6), (u'languages such', 6), (u'27 June', 6), (u'In Python', 6), (u'the original', 6), (u'Programming Language', 6), (u'June 2014', 5), (u'2001 PEP', 5), (u'code is', 5), (u'better than', 5), (u'contain mixed', 5), (u'original on', 5), (u'July 2013', 5), (u'arbitrary precision', 5), (u'March 2012', 5), (u'the standard', 5), (u'Python code', 5), (u'2012 Retrieved', 5), (u'to run', 5), (u'run on', 5), (u'is not', 5), (u'to a', 5), (u'of code', 5), (u'use the', 5), (u'Python uses', 5), (u'Retrieved 12', 5), (u'Python 3.0', 5), (u'March 2007', 5), (u'use of', 5), (u'is used', 5), (u'other languages', 5), (u'as the', 5), (u'mixed types', 5), (u'It is', 5), (u'used as', 5), (u'Stackless Python', 5), (u'and has', 5), (u'Free software', 4), (u'are not', 4), (u'FAQ Python', 4), (u'and Java', 4), (u'a similar', 4), (u'kinds of', 4), (u'support for', 4), (u'a is', 4), (u'operator for', 4), (u'from Python', 4), (u'is better', 4), (u'Python FAQ', 4), (u'object-oriented programming', 4), (u'block of', 4), (u"of Python's", 4), (u'are also', 4), (u'General Python', 4), (u'typing and', 4), (u'new features', 4), (u'version number', 4), (u'Main article', 4), (u'may be', 4), (u'on Python', 4), (u'Perl and', 4), (u'For example', 4), (u'Van Rossum', 4), (u'means that', 4), (u'Python programming', 4), (u'that the', 4), (u'August 2010', 4), (u'a large', 4), (u'can contain', 4), (u'number is', 4), (u'on a', 4), (u'the version', 4), (u'there is', 4), (u'Python interpreter', 4), (u'most popular', 4), (u'19 February', 4), (u'is incremented', 4), (u'As of', 4), (u'syntax and', 4), (u'quote marks', 4), (u'History of', 4), (u'Python 2.5', 4), (u'19 April', 4), (u'with a', 4), (u'with Python', 4), (u'April 2011', 4), (u'TIOBE Programming', 4), (u'string True', 4), (u'a scripting', 4), (u'styles loaded', 3), (u'and Oracle', 3), (u'design of', 3), (u'as Python', 3), (u'2009 Python', 3), (u'Python a', 3), (u'as of', 3), (u'Features and', 3), (u'rather than', 3), (u'Python in', 3), (u'be a', 3), (u'Web Server', 3), (u'of classes', 3), (u'Retrieved 28', 3), (u'Retrieved 22', 3), (u'Retrieved 25', 3), (u'language for', 3), (u'compiles Python', 3), (u'must be', 3), (u'the operator', 3), (u'using the', 3), (u'28 August', 3), (u'of its', 3), (u'the class', 3), (u'matrix multiplication', 3), (u'language with', 3), (u'to use', 3), (u'used for', 3), (u'to type=general', 3), (u'Migrate to', 3), (u'Python Retrieved', 3), (u'in Science', 3), (u'of an', 3), ( ...

# %% [markdown]
# ## 2: Using OpenRefine ##

# %%
# http://openrefine.org/download.html

# %% [markdown]
# ## 3. Summarizing data using n-gram(2nd example) ##

# %%
'''
The data we are summarzing in the inaugration speach of the 9th president of the USA.
'''
from urllib2 import urlopen
from bs4 import BeautifulSoup
import re
import string
import operator
import pprint

def cleanInput(input):
    # Similar to clean function in 1.1
    input = re.sub('\n+', " ", input).lower()
    input = re.sub('\[[0-9]*\]', "", input)
    input = re.sub(' +', " ", input)
    input = input.encode('utf-8')
    input = input.decode("ascii", "ignore")
    cleanInput = []
    input = input.split(' ')
    for item in input:
        item = item.strip(string.punctuation)
        if len(item) > 1 or (item.lower() == 'a' or item.lower() == 'i'):
            cleanInput.append(item)
    return cleanInput

def getNgrams(input, n):
    input = cleanInput(input)
    output = {}
    for i in range(len(input)-n+1):
        ngramTemp = " ".join(input[i:i+n])
        if ngramTemp not in output:
            output[ngramTemp] = 0
        output[ngramTemp] += 1
    return output

content = str(urlopen("http://pythonscraping.com/files/inaugurationSpeech.txt").read())
ngrams = getNgrams(content, 2)
sortedNGrams = sorted(ngrams.items(), 
                      key = operator.itemgetter(1), 
                      reverse=True)
pprint.pprint(sortedNGrams)
# Out:
# [(u'of the', 213),
#  (u'in the', 65),
#  (u'to the', 61),
#  (u'by the', 41),
#  (u'the constitution', 34),
#  (u'of our', 29),
#  (u'to be', 26),
#  (u'the people', 24),
#  (u'from the', 24),
#  (u'that the', 23),
#  (u'it is', 23),
#  (u'and the', 23),
#  (u'of a', 22),
#  (u'of their', 19),
#  (u'the executive', 19),
#  (u'may be', 19),
#  (u'of that', 18),
#  (u'for the', 16),
#  (u'is the', 16),
#  (u'have been', 16),
#  (u'of its', 16),
#  (u'of power', 16),
#  (u'all the', 15),
#  (u'with the', 15),
#  (u'the government', 15),
#  (u'which they', 13),
#  (u'has been', 13),
#  (u'there is', 13),
#  (u'power to', 12),
#  (u'the same', 11),
#  (u'as to', 11),
#  (u'the power', 11),
#  (u'spirit of', 11),
#  (u'that of', 11),
#  (u'their own', 11),
#  (u'can be', 10),
#  (u'which the', 10),
#  (u'the character', 10),
#  (u'the united', 10),
#  (u'of all', 10),
#  (u'part of', 10),
#  (u'which it', 10),
#  (u'but the', 10),
#  (u'upon the', 10),
#  (u'united states', 10),
#  (u'as the', 10),
#  (u'of liberty', 10),
#  (u'the president', 9),
#  (u'the great', 9),
#  (u'on the', 9),
#  (u'of any', 9),
#  (u'of my', 9),
#  (u'to a', 9),
#  (u'it was', 9),
#  (u'the whole', 9),
#  (u'of those', 8),
#  (u'and of', 8),
#  (u'in their', 8),
#  (u'should be', 8),
#  (u'the states', 8),
#  (u'the public', 8),
#  (u'would be', 8),
#  (u'which our', 8),
#  (u'it may', 8),
#  (u'by a', 8),
#  (u'character of', 8),
#  (u'the legislative', 8),
#  (u'and that', 8),
#  (u'to have', 7),
#  (u'to their', 7),
#  (u'as well', 7),
#  (u'the powers', 7),
#  (u'the general', 7),
#  (u'at the', 7),
#  (u'citizens of', 7),
#  (u'acts of', 7),
#  (u'any other', 7),
#  (u'the spirit', 6),
#  (u'and in', 6),
#  (u'to that', 6),
#  (u'under the', 6),
#  (u'the influence', 6),
#  (u'upon their', 6),
#  (u'some of', 6),
#  (u'the most', 6),
#  (u'it would', 6),
#  (u'the state', 6),
#  (u'our system', 6),
#  (u'in its', 6),
#  (u'state of', 6),
#  (u'those of', 6),
#  (u'of one', 6),
#  (u'them to', 6),
#  (u'one of', 6),
#  (u'government and', 6),
#  (u'is a', 6),
#  (u'that they', 6),
#  (u'to me', 6),
#  (u'of this', 6),
#  (u'relation to', 6),
#  (u'the former', 5),
#  (u'that instrument', 5),
#  (u'for which', 5),
#  (u'is in', 5),
#  (u'the other', 5),
#  (u'or the', 5),
#  (u'power which', 5),
#  (u'by which', 5),
#  (u'to his', 5),
#  (u'of these', 5),
#  (u'the veto', 5),
#  (u'in relation', 5),
#  (u'our country', 5),
#  (u'the citizens', 5),
#  (u'the legislature', 5),
#  (u'well as', 5),
#  (u'to them', 5),
#  (u'people to', 5),
#  (u'which has', 5),
#  (u'by any', 5),
#  (u'to which', 5),
#  (u'the country', 5),
#  (u'in my', 5),
#  (u'the citizen', 5),
#  (u'in our', 5),
#  (u'the acts', 5),
#  (u'of each', 5),
#  (u'to our', 5),
#  (u'shall be', 5),
#  (u'be found', 5),
#  (u'of them', 5),
#  (u'far as', 5),
#  (u'he is', 5),
#  (u'exercise of', 5),
#  (u'as a', 5),
#  (u'i have', 5),
#  (u'the latter', 5),
#  (u'it has', 5),
#  (u'not only', 5),
#  (u'not to', 5),
#  (u'was the', 5),
#  (u'i shall', 5),
#  (u'of no', 5),
#  (u'as it', 5),
#  (u'the judiciary', 5),
#  (u'might be', 5),
#  (u'if this', 4),
#  (u'a spirit', 4),
#  (u'at least', 4),
#  (u'that i', 4),
#  (u'that a', 4),
#  (u'it will', 4),
#  (u'country in', 4),
#  (u'but that', 4),
#  (u'influence of', 4),
#  (u'be the', 4),
#  (u'if there', 4),
#  (u'such a', 4),
#  (u'had been', 4),
#  (u'of his', 4),
#  (u'it appears', 4),
#  (u'by their', 4),
#  (u'of an', 4),
#  (u'the treasury', 4),
#  (u'the convention', 4),
#  (u'general government', 4),
#  (u'the respective', 4),
#  (u'with which', 4),
#  (u'and i', 4),
#  (u'people of', 4),
#  (u'may have', 4),
#  (u'intended to', 4),
#  (u'control of', 4),
#  (u'that which', 4),
#  (u'between the', 4),
#  (u'of congress', 4),
#  (u'the senate', 4),
#  (u'to produce', 4),
#  (u'hands of', 4),
#  (u'be used', 4),
#  (u'to its', 4),
#  (u'citizen of', 4),
#  (u'the control', 4),
#  (u'departments of', 4),
#  (u'control the', 4),
#  (u'given to', 4),
#  (u'for a', 4),
#  (u'that it', 4),
#  (u'duty of', 4),
#  (u'of every', 4),
#  (u'the contrary', 4),
#  (u'necessary to', 4),
#  (u'members of', 4),
#  (u'in a', 4),
#  (u'danger to', 4),
#  (u'than the', 4),
#  (u'grant of', 4),
#  (u'the union', 4),
#  (u'of government', 4),
#  (u'been the', 4),
#  (u'rights of', 4),
#  (u'our government', 4),
#  (u'which may', 4),
#  (u'the hands', 4),
#  (u'was to', 4),
#  (u'they have', 4),
#  (u'does not', 4),
#  (u'to make', 4),
#  (u'executive department', 4),
#  (u'it to', 4),
#  (u'continuance of', 4),
#  (u'mode of', 4),
#  (u'not the', 4),
#  (u'to my', 4),
#  (u'power of', 4),
#  (u'of such', 4),
#  (u'been granted', 4),
#  (u'to congress', 4),
#  (u'possessed by', 4),
#  (u'must be', 4),
#  (u'the principles', 4),
#  (u'any of', 4),
#  (u'me to', 4),
#  (u'assigned to', 4),
#  (u'to all', 4),
#  (u'examination of', 4),
#  (u'the majority', 4),
#  (u'interests of', 4),
#  (u'this is', 4),
#  (u'which have', 4),
#  (u'government but', 4),
#  (u'powers which', 4),
#  (u'in his', 4),
#  (u'difficulty in', 4),
#  (u'privilege of', 3),
#  (u'to prevent', 3),
#  (u'member of', 3),
#  (u'country for', 3),
#  (u'the federal', 3),
#  (u'not be', 3),
#  (u'likely to', 3),
#  (u'houses of', 3),
#  (u'either of', 3),
#  (u'the best', 3),
#  (u'which was', 3),
#  (u'than any', 3),
#  (u'same causes', 3),
#  (u'the departments', 3),
#  (u'mass of', 3),
#  (u'union of', 3),
#  (u'of many', 3),
#  (u'instances of', 3),
#  (u'management of', 3),
#  (u'the principle', 3),
#  (u'i can', 3),
#  (u'whilst the', 3),
#  (u'want of', 3),
#  (u'adoption of', 3),
#  (u'to say', 3),
#  (u'become the', 3),
#  (u'of things', 3),
#  (u'constitution the', 3),
#  (u'opinion of', 3),
#  (u'liberty is', 3),
#  (u'chief magistrate', 3),
#  (u'is an', 3),
#  (u'duty to', 3),
#  (u'constitution has', 3),
#  (u'at this', 3),
#  (u'granted to', 3),
#  (u'freedom of', 3),
#  (u'never be', 3),
#  (u'government of', 3),
#  (u'mr jefferson', 3),
#  (u'institutions of', 3),
#  (u'which he', 3),
#  (u'i conceive', 3),
#  (u'will be', 3),
#  (u'in one', 3),
#  (u'could not', 3),
#  (u'people and', 3),
#  (u'and it', 3),
#  (u'legislative body', 3),
#  (u'to whom', 3),
#  (u'effected by', 3),
#  (u'to keep', 3),
#  (u'the effects', 3),
#  (u'government which', 3),
#  (u'placed in', 3),
#  (u'which had', 3),
#  (u'they might', 3),
#  (u'those who', 3),
#  (u'the greatest', 3),
#  (u'and a', 3),
#  (u'the district', 3),
#  (u'in which', 3),
#  (u'from a', 3),
#  (u'it can', 3),
#  (u'if not', 3),
#  (u'whole country', 3),
#  (u'connected with', 3),
#  (u'have the', 3),
#  (u'injury to', 3),
#  (u'the management', 3),
#  (u'but by', 3),
#  (u'my countrymen', 3),
#  (u'the duty', 3),
#  (u'can only', 3),
#  (u'from our', 3),
#  (u'the rights', 3),
#  (u'this time', 3),
#  (u'the legislation', 3),
#  (u'of which', 3),
#  (u'to liberty', 3),
#  (u'and yet', 3),
#  (u'their rights', 3),
#  (u'extent of', 3),
#  (u'forms of', 3),
#  (u'can not', 3),
#  (u'to control', 3),
#  (u'right to', 3),
#  (u'character and', 3),
#  (u'in all', 3),
#  (u'powers of', 3),
#  (u'the reserved', 3),
#  (u'by an', 3),
#  (u'the framers', 3),
#  (u'sense of', 3),
#  (u'the part', 3),
#  (u'the roman', 3),
#  (u'which i', 3),
#  (u'congress the', 3),
#  (u'when the', 3),
#  (u'our institutions', 3),
#  (u'called upon', 3),
#  (u'the several', 3),
#  (u'indeed that', 3),
#  (u'the only', 3),
#  (u'my hands', 3),
#  (u'that in', 3),
#  (u'framers of', 3),
#  (u'destruction of', 3),
#  (u'government the', 3),
#  (u'the adoption', 3),
#  (u'the freedom', 3),
#  (u'those which', 3),
#  (u'the danger', 3),
#  (u'the extent', 3),
#  (u'upon which', 3),
#  (u'district of', 3),
#  (u'appear to', 3),
#  (u'effects of', 3),
#  (u'the right', 3),
#  (u'of columbia', 3),
#  (u'is not', 3),
#  (u'and to', 3),
#  (u'who have', 3),
#  (u'of great', 3),
#  (u'with their', 3),
#  (u'which in', 3),
#  (u'duties of', 3),
#  (u'country the', 3),
#  (u'to apply', 3),
#  (u'the true', 3),
#  (u'circumstances of', 3),
#  (u'upon to', 3),
#  (u'the continuance', 3),
#  (u'my fellow-citizens', 3),
#  (u'where the', 3),
#  (u'me it', 3),
#  (u'a party', 3),
#  (u'the means', 3),
#  (u'legislation of', 3),
#  (u'of her', 3),
#  (u'their affairs', 3),
#  (u'tendency of', 3),
#  (u'prescribed by', 3),
#  (u'power in', 3),
#  (u'but to', 3),
#  (u'which are', 3),
#  (u'the love', 3),
#  (u'true and', 3),
#  (u'under a', 3),
#  (u'confidence in', 3),
#  (u'be effected', 3),
#  (u'for their', 3),
#  (u'feelings of', 3),
#  (u'our citizens', 3),
#  (u'love of', 3),
#  (u'many of', 3),
#  (u'will the', 3),
#  (u'our confederacy', 3),
#  (u'a great', 3),
#  (u'government should', 3),
#  (u'a part', 3),
#  (u'amount of', 3),
#  (u'but in', 3),
#  (u'a free', 3),
#  (u'the circumstances', 3),
#  (u'and opinions', 3),
#  (u'as in', 3),
#  (u'produce the', 3),
#  (u'principles and', 3),
#  (u'not appear', 3),
#  (u'as far', 3),
#  (u'with our', 3),
#  (u'principle the', 2),
#  (u'pristine health', 2),
#  (u'lapse of', 2),
#  (u'defense of', 2),
#  (u'they may', 2),
#  (u'the leading', 2),
#  (u'the divorce', 2),
#  (u'and religious', 2),
#  (u'a state', 2),
#  (u'intention to', 2),
#  (u'is more', 2),
#  (u'is to', 2),
#  (u'the wants', 2),
#  (u'and beauty', 2),
#  (u'the more', 2),
#  (u'were made', 2),
#  (u'states and', 2),
#  (u'share of', 2),
#  (u'within the', 2),
#  (u'to grant', 2),
#  (u'the present', 2),
#  (u'upward of', 2),
#  (u'i consider', 2),
#  (u'subject of', 2),
#  (u'the amount', 2),
#  (u'made of', 2),
#  (u'construction of', 2),
#  (u'increase itself', 2),
#  (u'too well', 2),
#  (u'the case', 2),
#  (u'a similar', 2),
#  (u'the lapse', 2),
#  (u'only with', 2),
#  (u'my opinion', 2),
#  (u'its existence', 2),
#  (u'him to', 2),
#  (u'negative upon', 2),
#  (u'with them', 2),
#  (u'reference to', 2),
#  (u'aid of', 2),
#  (u'me by', 2),
#  (u'great increase', 2),
#  (u'of civil', 2),
#  (u'supposed to', 2),
#  (u'domestic concerns', 2),
#  (u'to commit', 2),
#  (u'of mine', 2),
#  (u'could have', 2),
#  (u'country that', 2),
#  (u'have placed', 2),
#  (u'instrument to', 2),
#  (u'it the', 2),
#  (u'that he', 2),
#  (u'their subjects', 2),
#  (u'or without', 2),
#  (u'authority to', 2),
#  (u'immediate representatives', 2),
#  (u'and credit', 2),
#  (u'the very', 2),
#  (u'he should', 2),
#  (u'if it', 2),
#  (u'the human', 2),
#  (u'schemes of', 2),
#  (u'in that', 2),
#  (u'be exercised', 2),
#  (u'executive will', 2),
#  (u'liberty and', 2),
#  (u'government by', 2),
#  (u'of interest', 2),
#  (u'whole the', 2),
#  (u'with no', 2),
#  (u'itself upon', 2),
#  (u'productive of', 2),
#  (u'two of', 2),
#  (u'just and', 2),
#  (u'has hitherto', 2),
#  (u'that celebrated', 2),
#  (u'its provisions', 2),
#  (u'we would', 2),
#  (u'officer at', 2),
#  (u'the mass', 2),
#  (u'reserved rights', 2),
#  (u'there were', 2),
#  (u'be realized', 2),
#  (u'the entire', 2),
#  (u'and prejudices', 2),
#  (u'principle that', 2),
#  (u'the result', 2),
#  (u'being in', 2),
#  (u'all true', 2),
#  (u'both houses', 2),
#  (u'the formation', 2),
#  (u'at first', 2),
#  (u'effect the', 2),
#  (u'no other', 2),
#  (u'the exercise', 2),
#  (u'and not', 2),
#  (u'constitution and', 2),
#  (u'with his', 2),
#  (u'as long', 2),
#  (u'the name', 2),
#  (u'the subject', 2),
#  (u'the instrument', 2),
#  (u'propose amendments', 2),
#  (u'disputed points', 2),
#  (u'the labors', 2),
#  (u'contrary no', 2),
#  (u'a people', 2),
#  (u'carry into', 2),
#  (u'if we', 2),
#  (u'they respectively', 2),
#  (u'the aid', 2),
#  (u'interests and', 2),
#  (u'the advantages', 2),
#  (u'a misconstruction', 2),
#  (u'are there', 2),
#  (u'the interests', 2),
#  (u'commencement of', 2),
#  (u'public money', 2),
#  (u'and patriotism', 2),
#  (u'their political', 2),
#  (u'among the', 2),
#  (u'remark of', 2),
#  (u'the fact', 2),
#  (u'difference in', 2),
#  (u'of democracy', 2),
#  (u'true spirit', 2),
#  (u'is called', 2),
#  (u'the sovereign', 2),
#  (u'like the', 2),
#  (u'participation in', 2),
#  (u'not well', 2),
#  (u'one time', 2),
#  (u'also to', 2),
#  (u'operations of', 2),
#  (u'in every', 2),
#  (u'each of', 2),
#  (u'and be', 2),
#  (u'interest of', 2),
#  (u'framed the', 2),
#  (u'the individual', 2),
#  (u'the forms', 2),
#  (u'by his', 2),
#  (u'see in', 2),
#  (u'defects of', 2),
#  (u'degree of', 2),
#  (u'to recommend', 2),
#  (u'deprecated by', 2),
#  (u'and this', 2),
#  (u'state governments', 2),
#  (u'the discharge', 2),
#  (u'there was', 2),
#  (u'characters of', 2),
#  (u'in part', 2),
#  (u"no one's", 2),
#  (u'confided to', 2),
#  (u'an exclusive', 2),
#  (u'the opinion', 2),
#  (u'sake of', 2),
#  (u'our own', 2),
#  (u'laws and', 2),
#  (u'it should', 2),
#  (u'heretofore given', 2),
#  (u'unite in', 2),
#  (u'mind of', 2),
#  (u'of party', 2),
#  (u'authorities of', 2),
#  (u'is one', 2),
#  (u'second term', 2),
#  (u'a most', 2),
#  (u'be thought', 2),
#  (u'us to', 2),
#  (u'independence and', 2),
#  (u'the master', 2),
#  (u'the source', 2),
#  (u'express grant', 2),
#  (u'of removal', 2),
#  (u'a just', 2),
#  (u'however that', 2),
#  (u'and safety', 2),
#  (u'i believe', 2),
#  (u'the first', 2),
#  (u'reserved powers', 2),
#  (u'interference in', 2),
#  (u'of confidence', 2),
#  (u'to you', 2),
#  (u'and as', 2),
#  (u'their former', 2),
#  (u'seem to', 2),
#  (u'we may', 2),
#  (u'of discord', 2),
#  (u'veto power', 2),
#  (u'do not', 2),
#  (u'one state', 2),
#  (u'the support', 2),
#  (u'of keeping', 2),
#  (u'the chief', 2),
#  (u'seems to', 2),
#  (u'his own', 2),
#  (u'its operations', 2),
#  (u'should never', 2),
#  (u'high office', 2),
#  (u'by renewing', 2),
#  (u'to propose', 2),
#  (u'continues to', 2),
#  (u'its pristine', 2),
#  (u'people but', 2),
#  (u'the currency', 2),
#  (u'through the', 2),
#  (u'say that', 2),
#  (u'upon another', 2),
#  (u'that body', 2),
#  (u'to govern', 2),
#  (u'than their', 2),
#  (u'who has', 2),
#  (u'individual members', 2),
#  (u'attributable to', 2),
#  (u'the destruction', 2),
#  (u'our ancestors', 2),
#  (u'more likely', 2),
#  (u'our people', 2),
#  (u'or either', 2),
#  (u'it becomes', 2),
#  (u'of political', 2),
#  (u'this error', 2),
#  (u'destructive of', 2),
#  (u'and more', 2),
#  (u'sometimes be', 2),
#  (u'religious liberty', 2),
#  (u'the high', 2),
#  (u'health and', 2),
#  (u'and so', 2),
#  (u'been committed', 2),
#  (u'all others', 2),
#  (u'as collisions', 2),
#  (u'majority of', 2),
#  (u'of athens', 2),
#  (u'renewing the', 2),
#  (u'misconstruction of', 2),
#  (u'tie of', 2),
#  (u'declare void', 2),
#  (u'in many', 2),
#  (u'parts of', 2),
#  (u'have made', 2),
#  (u'be in', 2),
#  (u'him the', 2),
#  (u'foreign relations', 2),
#  (u'not become', 2),
#  (u'placed at', 2),
#  (u'the rest', 2),
#  (u'we are', 2),
#  (u'armies and', 2),
#  (u'the pledge', 2),
#  (u'respects the', 2),
#  (u'our constitution', 2),
#  (u'of powers', 2),
#  (u'the results', 2),
#  (u'regards the', 2),
#  (u'wants and', 2),
#  (u'by my', 2),
#  (u'by mr', 2),
#  (u'the commonwealth', 2),
#  (u'representatives of', 2),
#  (u'them and', 2),
#  (u'members is', 2),
#  (u'to constitute', 2),
#  (u'is true', 2),
#  (u'possession of', 2),
#  (u'their part', 2),
#  (u'who would', 2),
#  (u'exercised by', 2),
#  (u'the idea', 2),
#  (u'not as', 2),
#  (u'all its', 2),
#  (u'none of', 2),
#  (u'period of', 2),
#  (u'a single', 2),
#  (u'for no', 2),
#  (u'the one', 2),
#  (u'the acknowledged', 2),
#  (u'be observed', 2),
#  (u'making it', 2),
#  (u'proceed to', 2),
#  (u'in controlling', 2),
#  (u'a full', 2),
#  (u'state authorities', 2),
#  (u'credit of', 2),
#  (u'other words', 2),
#  (u'granted by', 2),
#  (u'he holds', 2),
#  (u'at one', 2),
#  (u'constituted by', 2),
#  (u'course of', 2),
#  (u'power and', 2),
#  (u'exists in', 2),
#  (u'upon that', 2),
#  (u'party but', 2),
#  (u'civil and', 2),
#  (u'the domestic', 2),
#  (u'the commencement', 2),
#  (u'states as', 2),
#  (u'office of', 2),
#  (u'department of', 2),
#  (u'the security', 2),
#  (u'and consequently', 2),
#  (u'controlling the', 2),
#  (u'passion of', 2),
#  (u'a roman', 2),
#  (u'exclusive metallic', 2),
#  (u'the national', 2),
#  (u'the institutions', 2),
#  (u'conformity to', 2),
#  (u'an express', 2),
#  (u'long as', 2),
#  (u'by those', 2),
#  (u'so far', 2),
#  (u'be an', 2),
#  (u'that spirit', 2),
#  (u'the measures', 2),
#  (u'and perhaps', 2),
#  (u'metallic currency', 2),
#  (u'congress of', 2),
#  (u'and forms', 2),
#  (u'with or', 2),
#  (u'to create', 2),
#  (u'a fair', 2),
#  (u'i proceed', 2),
#  (u'their best', 2),
#  (u'of conformity', 2),
#  (u'states but', 2),
#  (u'body the', 2),
#  (u'the personal', 2),
#  (u'which is', 2),
#  (u'became the', 2),
#  (u'american citizens', 2),
#  (u'the sake', 2),
#  (u'been in', 2),
#  (u'as i', 2),
#  (u'was intended', 2),
#  (u'of course', 2),
#  (u'i should', 2),
#  (u'genuine spirit', 2),
#  (u'was observable', 2),
#  (u'keeping the', 2),
#  (u'language of', 2),
#  (u'to preserve', 2),
#  (u'that at', 2),
#  (u'not of', 2),
#  (u'free and', 2),
#  (u'idea of', 2),
#  (u'prevent the', 2),
#  (u'american citizen', 2),
#  (u'them the', 2),
#  (u'to bring', 2),
#  (u'those to', 2),
#  (u'against the', 2),
#  (u'for his', 2),
#  (u'several departments', 2),
#  (u'appears to', 2),
#  (u'a general', 2),
#  (u'consequences than', 2),
#  (u'support of', 2),
#  (u'used only', 2),
#  (u'me in', 2),
#  (u'the mode', 2),
#  (u'and their', 2),
#  (u'no part', 2),
#  (u'to perform', 2),
#  (u'each other', 2),
#  (u'the officer', 2),
#  (u'to it', 2),
#  (u'the duties', 2),
#  (u'the genuine', 2),
#  (u'if such', 2),
#  (u'principles of', 2),
#  (u'to carry', 2),
#  (u'repugnant to', 2),
#  (u'is i', 2),
#  (u'legislation and', 2),
#  (u'their passions', 2),
#  (u'discharge of', 2),
#  (u'it had', 2),
#  (u'the remark', 2),
#  (u'branch of', 2),
#  (u'president to', 2),
#  (u'others in', 2),
#  (u'all necessary', 2),
#  (u'and which', 2),
#  (u'and affection', 2),
#  (u'a republic', 2),
#  (u'found to', 2),
#  (u'a second', 2),
#  (u'power is', 2),
#  (u'used in', 2),
#  (u'the tendency', 2),
#  (u'and although', 2),
#  (u'the world', 2),
#  (u'the nation', 2),
#  (u'will ever', 2),
#  (u'federal government', 2),
#  (u'its members', 2),
#  (u'foreign aggression', 2),
#  (u'of another', 2),
#  (u'nothing more', 2),
#  (u'elective franchise', 2),
#  (u'that high', 2),
#  (u'labors of', 2),
#  (u'and his', 2),
#  (u'constitution in', 2),
#  (u'a process', 2),
#  (u'are the', 2),
#  (u'their country', 2),
#  (u'would not', 2),
#  (u'observed however', 2),
#  (u'the defense', 2),
#  (u'at times', 2),
#  (u'spirit which', 2),
#  (u'of executive', 2),
#  (u'are attributable', 2),
#  (u'can never', 2),
#  (u'the bosoms', 2),
#  (u'to any', 2),
#  (u'the false', 2),
#  (u'of want', 2),
#  (u'a thorough', 2),
#  (u'to others', 2),
#  (u'be expected', 2),
#  (u'understood and', 2),
#  (u'he has', 2),
#  (u'a few', 2),
#  (u'understand the', 2),
#  (u'since the', 2),
#  (u'with every', 2),
#  (u'free people', 2),
#  (u'executive power', 2),
#  (u'liberties of', 2),
#  (u'will not', 2),
#  (u'into effect', 2),
#  (u'executive the', 2),
#  (u'and those', 2),
#  (u'war and', 2),
#  (u'so much', 2),
#  (u'there are', 2),
#  (u'proper that', 2),
#  (u'or not', 2),
#  (u'the lines', 2),
#  (u'of citizens', 2),
#  (u'to adopt', 2),
#  (u'this danger', 2),
#  (u'by them', 2),
#  (u'the evils', 2),
#  (u'content with', 2),
#  (u'of some', 2),
#  (u'than to', 2),
#  (u'yet the', 2),
#  (u'harmony with', 2),
#  (u'from it', 2),
#  (u'but if', 2),
#  (u'of other', 2),
#  (u'constitution of', 2),
#  (u'bosoms of', 2),
#  (u'of two', 2),
#  (u'complained of', 2),
#  (u'strange indeed', 2),
#  (u'the elective', 2),
#  (u'the language', 2),
#  (u'we have', 2),
#  (u'them from', 2),
#  (u'there may', 2),
#  (u'that character', 2),
#  (u'respectively claim', 2),
#  (u'the others', 2),
#  (u'their respective', 2),
#  (u'a period', 2),
#  (u'to increase', 2),
#  (u'although there', 2),
#  (u'of law', 2),
#  (u'them by', 2),
#  (u'have occurred', 2),
#  (u'in this', 2),
#  (u'which their', 2),
#  (u'they could', 2),
#  (u'of wealth', 2),
#  (u'result in', 2),
#  (u'the liberties', 2),
#  (u'the parties', 2),
#  (u'more particularly', 2),
#  (u'honor of', 1),
#  (u'its various', 1),
#  (u'been considered', 1),
#  (u'and thirdly', 1),
#  (u'party amongst', 1),
#  (u'any sinister', 1),
#  (u'an administration', 1),
#  (u'here either', 1),
#  (u'me and', 1),
#  (u'in recommending', 1),
#  (u'and forbearance', 1),
#  (u'embracing so', 1),
#  (u'executive party', 1),
#  (u'who framed', 1),
#  (u'patriots will', 1),
#  (u'are as', 1),
#  (u'intrust to', 1),
#  (u'are at', 1),
#  (u'patriots have', 1),
#  (u'seeks to', 1),
#  (u'general grant', 1),
#  (u'dividend the', 1),
#  (u'constituents and', 1),
#  (u'ascertained a', 1),
#  (u'seldom fails', 1),
#  (u'greatly mitigated', 1),
#  (u'officer to', 1),
#  (u'the separate', 1),
#  (u'money by', 1),
#  (u'years been', 1),
#  (u'but exclusively', 1),
#  (u'be exerted', 1),
#  (u'obedience to', 1),
#  (u'another seem', 1),
#  (u'and uncompromising', 1),
#  (u'seize the', 1),
#  (u'speak warning', 1),
#  (u'every foreign', 1),
#  (u'all such', 1),
#  (u'house of', 1),
#  (u'constitution to', 1),
#  (u'republic and', 1),
#  (u'result to', 1),
#  (u'dangerous as', 1),
#  (u'great principles', 1),
#  (u'intercourse or', 1),
#  (u'union effected', 1),
#  (u'are others', 1),
#  (u'best historians', 1),
#  (u'humiliations than', 1),
#  (u'summary of', 1),
#  (u'athens to', 1),
#  (u'less from', 1),
#  (u'as effectual', 1),
#  (u'of devotion', 1),
#  (u'freemen under', 1),
#  (u'citizen which', 1),
#  (u'or a', 1),
#  (u'he claims', 1),
#  (u'whose situation', 1),
#  (u'my present', 1),
#  (u'another ground', 1),
#  (u'may meet', 1),
#  (u'better understand', 1),
#  (u'meet in', 1),
#  (u'chief executive', 1),
#  (u'first it', 1),
#  (u'of soil', 1),
#  (u'peculiar position', 1),
#  (u'convention that', 1),
#  (u'convention than', 1),
#  (u'early period', 1),
#  (u'of worship', 1),
#  (u'people proverbial', 1),
#  (u'of giving', 1),
#  (u'two and', 1),
#  (u'successively of', 1),
#  (u'all and', 1),
#  (u'persevering bold', 1),
#  (u'high trust', 1),
#  (u'are now', 1),
#  (u'are not', 1),
#  (u'to guard', 1),
#  (u'that most', 1),
#  (u'from foreign', 1),
#  (u'liberty at', 1),
#  (u'a selection', 1),
#  (u'most of', 1),
#  (u'his services', 1),
#  (u'less jealous', 1),
#  (u'is himself', 1),
#  (u'the direction', 1),
#  (u'leaving to', 1),
#  (u'as summary', 1),
#  (u'created by', 1),
#  (u'permanency in', 1),
#  (u'most approved', 1),
#  (u'prospered the', 1),
#  (u'such disputed', 1),
#  (u'a profound', 1),
#  (u'the supervision', 1),
#  (u'enabled me', 1),
#  (u'not much', 1),
#  (u'british orators', 1),
#  (u'direct opposition', 1),
#  (u'the pleasure', 1),
#  (u'much difficulty', 1),
#  (u'constitution all', 1),
#  (u'collected in', 1),
#  (u'injurious operation', 1),
#  (u'course not', 1),
#  (u'of checks', 1),
#  (u'may secure', 1),
#  (u'remove a', 1),
#  (u'of business', 1),
#  (u'their advice', 1),
#  (u'or from', 1),
#  (u'its transactions', 1),
#  (u'no more', 1),
#  (u'elections further', 1),
#  (u'of measures', 1),
#  (u'the origination', 1),
#  (u'our domestic', 1),
#  (u'the sacred', 1),
#  (u'exerted to', 1),
#  (u'umpire from', 1),
#  (u'roman consul', 1),
#  (u'been probably', 1),
#  (u'them which', 1),
#  (u'any indication', 1),
#  (u'see that', 1),
#  (u'govern and', 1),
#  (u'before concluding', 1),
#  (u'be so', 1),
#  (u'to gather', 1),
#  (u'it might', 1),
#  (u'which will', 1),
#  (u'the defender', 1),
#  (u'desirable than', 1),
#  (u'for one', 1),
#  (u'the forbearance', 1),
#  (u'of encroachments', 1),
#  (u'the sternest', 1),
#  (u'charter granted', 1),
#  (u'things likely', 1),
#  (u'pledge heretofore', 1),
#  (u'remedies which', 1),
#  (u'confederacy except', 1),
#  (u'one mode', 1),
#  (u'the residue', 1),
#  (u'a larger', 1),
#  (u'government would', 1),
#  (u'operations upon', 1),
#  (u'pockets become', 1),
#  (u'convention one', 1),
#  (u'that does', 1),
#  (u'constitution rather', 1),
#  (u'result of', 1),
#  (u'shall stand', 1),
#  (u'and all', 1),
#  (u'defend the', 1),
#  (u'our chief', 1),
#  (u'submit to', 1),
#  (u'origination of', 1),
#  (u'the aggrandizement', 1),
#  (u'hostile to', 1),
#  (u'purely democratic', 1),
#  (u'guard protect', 1),
#  (u'manner in', 1),
#  (u'now uttered', 1),
#  (u'past experience', 1),
#  (u'their american', 1),
#  (u'altogether different', 1),
#  (u'to both', 1),
#  (u'in times', 1),
#  (u'means and', 1),
#  (u'let us', 1),
#  (u'constitution prescribes', 1),
#  (u'oppression of', 1),
#  (u'are appalling', 1),
#  (u'some cases', 1),
#  (u'effectual an', 1),
#  (u'changed into', 1),
#  (u'foundation upon', 1),
#  (u'of country', 1),
#  (u'by causes', 1),
#  (u'jefferson to', 1),
#  (u'with regard', 1),
#  (u'of both', 1),
#  (u'of conduct', 1),
#  (u'his disposal', 1),
#  (u'and equitable', 1),
#  (u'political family', 1),
#  (u'by anyone', 1),
#  (u'great good', 1),
#  (u'an office', 1),
#  (u'them living', 1),
#  (u'down a', 1),
#  (u'a bad', 1),
#  (u'our relations', 1),
#  (u'harmony in', 1),
#  (u'guards of', 1),
#  (u'apparently repugnant', 1),
#  (u'when exercised', 1),
#  (u'democratic we', 1),
#  (u'power the', 1),
#  (u'year among', 1),
#  (u'is it', 1),
#  (u'right believing', 1),
#  (u'so constituted', 1),
#  (u'treasury from', 1),
#  (u'utopian dreams', 1),
#  (u'give firmness', 1),
#  (u'aristocracy of', 1),
#  (u'is however', 1),
#  (u'and temporary', 1),
#  (u'accomplished all', 1),
#  (u'the scheming', 1),
#  (u'informed as', 1),
#  (u'the restricted', 1),
#  (u'bolivar possessed', 1),
#  (u'communities which', 1),
#  (u'friendly intercourse', 1),
#  (u'ineffectual men', 1),
#  (u'fellow-man he', 1),
#  (u'a privilege', 1),
#  (u'not by', 1),
#  (u'from whom', 1),
#  (u'whole government', 1),
#  (u'constitution from', 1),
#  (u'citizen derives', 1),
#  (u'life to', 1),
#  (u'caesar became', 1),
#  (u'disparage the', 1),
#  (u'interfere with', 1),
#  (u'congress to', 1),
#  (u'so happily', 1),
#  (u'at my', 1),
#  (u'sovereignty acknowledged', 1),
#  (u'constitution making', 1),
#  (u'might deceive', 1),
#  (u'the advancement', 1),
#  (u'secretary of', 1),
#  (u'observations upon', 1),
#  (u'a settled', 1),
#  (u'me the', 1),
#  (u'than giving', 1),
#  (u'activity of', 1),
#  (u'no delay', 1),
#  (u'itself these', 1),
#  (u'neighbors the', 1),
#  (u'alternative then', 1),
#  (u'assumes the', 1),
#  (u'personal rights', 1),
#  (u'requires that', 1),
#  (u"the subjects'--in", 1),
#  (u'these there', 1),
#  (u'would become', 1),
#  (u'interpreted so', 1),
#  (u'develop similar', 1),
#  (u'legislature there', 1),
#  (u'fatal to', 1),
#  (u'orbits this', 1),
#  (u'acting within', 1),
#  (u'determination to', 1),
#  (u'prescribes as', 1),
#  (u'either prepared', 1),
#  (u'command it', 1),
#  (u'personal liberty', 1),
#  (u'our fellow-citizens', 1),
#  (u'unworthy of', 1),
#  (u'appear before', 1),
#  (u'in different', 1),
#  (u'conservative power', 1),
#  (u'its honor', 1),
#  (u'ardent patriotism', 1),
#  (u'dangerous temptations', 1),
#  (u'because he', 1),
#  (u'a pleasing', 1),
#  (u'action for', 1),
#  (u'subsists with', 1),
#  (u'madison that', 1),
#  (u'many years', 1),
#  (u'a despotism', 1),
#  (u'pleasure of', 1),
#  (u'ordinary legislation', 1),
#  (u'whence it', 1),
#  (u'they relied', 1),
#  (u'be overcome', 1),
#  (u'to fill', 1),
#  (u'false christs', 1),
#  (u'department has', 1),
#  (u'servant not', 1),
#  (u'helvetic confederacy', 1),
#  (u'passed under', 1),
#  (u'exist in', 1),
#  (u'his sword', 1),
#  (u'i refer', 1),
#  (u'union--is by', 1),
#  (u'pleasing guaranty', 1),
#  (u'a distinguished', 1),
#  (u'power placed', 1),
#  (u'incongruity and', 1),
#  (u'executive authority', 1),
#  (u'mistaken enthusiast', 1),
#  (u'affections changed', 1),
#  (u'my chief', 1),
#  (u'solemn to', 1),
#  (u'political instruments', 1),
#  (u'taught us', 1),
#  (u'rights so', 1),
#  (u'weaker and', 1),
#  (u'in amount', 1),
#  (u'a manner', 1),
#  (u'found ineffectual', 1),
#  (u'probably more', 1),
#  (u'the field', 1),
#  (u'afford a', 1),
#  (u'products and', 1),
#  (u'the obligations', 1),
#  (u'other cause', 1),
#  (u'disunion violence', 1),
#  (u'control congress', 1),
#  (u'the guilty', 1),
#  (u'and free', 1),
#  (u'overshadowed by', 1),
#  (u'independent action', 1),
#  (u'encroachments of', 1),
#  (u'rights and', 1),
#  (u'persons all', 1),
#  (u'which from', 1),
#  (u'often not', 1),
#  (u'bills have', 1),
#  (u'simple representative', 1),
#  (u'here not', 1),
#  (u'interests--hostile to', 1),
#  (u'jefferson forbidding', 1),
#  (u'leading states', 1),
#  (u'is preposterous', 1),
#  (u'be no', 1),
#  (u'from past', 1),
#  (u'certainly is', 1),
#  (u'a vote', 1),
#  (u'the predictions', 1),
#  (u'apply their', 1),
#  (u'removal with', 1),
#  (u'most essential', 1),
#  (u'it features', 1),
#  (u'his bosom', 1),
#  (u'his negative', 1),
#  (u'possess a', 1),
#  (u'dominant passions', 1),
#  (u'effectually checked', 1),
#  (u'say something', 1),
#  (u'require no', 1),
#  (u'as of', 1),
#  (u'introduced--a minister', 1),
#  (u'and gaze', 1),
#  (u'by creating', 1),
#  (u'ancient and', 1),
#  (u'government accompanied', 1),
#  (u'pass all', 1),
#  (u'never with', 1),
#  (u'a formidable', 1),
#  (u'the enlightened', 1),
#  (u'tranquillity preserved', 1),
#  (u'these patriots', 1),
#  (u'department upon', 1),
#  (u'impropriety of', 1),
#  (u'not within', 1),
#  (u'sincerely believe', 1),
#  (u'observable that', 1),
#  (u'still an', 1),
#  (u'principle does', 1),
#  (u'great and', 1),
#  (u'usefulness ends', 1),
#  (u'effects and', 1),
#  (u'union--cordial confiding', 1),
#  (u'the popular', 1),
#  (u'animates the', 1),
#  (u'once distinguished', 1),
#  (u'really exists', 1),
#  (u'present form', 1),
#  (u'power established', 1),
#  (u'the confident', 1),
#  (u'admissions if', 1),
#  (u'fled and', 1),
#  (u'causes will', 1),
#  (u'by indications', 1),
#  (u'constant and', 1),
#  (u'congress should', 1),
#  (u'the friend', 1),
#  (u'it as', 1),
#  (u'observable in', 1),
#  (u'shout for', 1),
#  (u'measures to', 1),
#  (u'experience of', 1),
#  (u'fraternal union--is', 1),
#  (u'my consent', 1),
#  (u'slaves--of their', 1),
#  (u'alarm in', 1),
#  (u'had the', 1),
#  (u'orators and', 1),
#  (u'in excellence', 1),
#  (u'former is', 1),
#  (u'feelings it', 1),
#  (u'contended as', 1),
#  (u'make nor', 1),
#  (u'plan for', 1),
#  (u'alliance and', 1),
#  (u'but still', 1),
#  (u'unlimited power', 1),
#  (u'fund of', 1),
#  (u'obligations of', 1),
#  (u'without the', 1),
#  (u'the ambition', 1),
#  (u'shall an', 1),
#  (u'either exonerated', 1),
#  (u'and disbursement', 1),
#  (u'to exist', 1),
#  (u'elapsed since', 1),
#  (u'a dominant', 1),
#  (u'instrument containing', 1),
#  (u'being the', 1),
#  (u'propriety of', 1),
#  (u'its interests', 1),
#  (u'of congress--that', 1),
#  (u'confederated states', 1),
#  (u'in other', 1),
#  (u'is union', 1),
#  (u'those collected', 1),
#  (u'to provide', 1),
#  (u'invested with', 1),
#  (u'entertained that', 1),
#  (u'no words', 1),
#  (u'their alliance', 1),
#  (u'exterior guards', 1),
#  (u'one measure', 1),
#  (u'presiding over', 1),
#  (u'never returned', 1),
#  (u'command of', 1),
#  (u'powerful in', 1),
#  (u'the sagacious', 1),
#  (u'as regards', 1),
#  (u'since it', 1),
#  (u'confident hopes', 1),
#  (u'treasury department', 1),
#  (u'officers i', 1),
#  (u'to present', 1),
#  (u'may originate', 1),
#  (u'no difficulty', 1),
#  (u'probably disregarded', 1),
#  (u'guaranteed by', 1),
#  (u'deprive them', 1),
#  (u'it makes', 1),
#  (u'men are', 1),
#  (u'single scheme', 1),
#  (u'or by', 1),
#  (u'increase the', 1),
#  (u'negotiations with', 1),
#  (u'preservation of', 1),
#  (u'demagogue rendered', 1),
#  (u'each acting', 1),
#  (u'fashioned by', 1),
#  (u'would subject', 1),
#  (u'the sole', 1),
#  (u'usury it', 1),
#  (u'anything imprudent', 1),
#  (u'pretension upon', 1),
#  (u'appearance of', 1),
#  (u'agency of', 1),
#  (u'our constant', 1),
#  (u'principal the', 1),
#  (u'highly expedient', 1),
#  (u'creator has', 1),
#  (u'divisions of', 1),
#  (u'judgments never', 1),
#  (u'was indeed', 1),
#  (u'body by', 1),
#  (u'attachment between', 1),
#  (u'will restore', 1),
#  (u'patriotism have', 1),
#  (u'checked by', 1),
#  (u'not always', 1),
#  (u'recognize as', 1),
#  (u'thought that', 1),
#  (u'it exclusively', 1),
#  (u'any distinct', 1),
#  (u'of mind', 1),
#  (u'has blessed', 1),
#  (u'conceive of', 1),
#  (u'a too', 1),
#  (u'be overshadowed', 1),
#  (u'have gone', 1),
#  (u'however which', 1),
#  (u'surrender being', 1),
#  (u'a citizen', 1),
#  (u'be interpreted', 1),
#  (u'and decii', 1),
#  (u'may exist', 1),
#  (u'or republic', 1),
#  (u'similar power', 1),
#  (u'long the', 1),
#  (u'some length', 1),
#  (u'remembrance of', 1),
#  (u'upon him', 1),
#  (u'legitimate right', 1),
#  (u'distinct lines', 1),
#  (u'ability and', 1),
#  (u'purpose to', 1),
#  (u'being realized', 1),
#  (u'have dreamed', 1),
#  (u'arises from', 1),
#  (u'us a', 1),
#  (u'any feature', 1),
#  (u'aid in', 1),
#  (u'complicated intrigues', 1),
#  (u'even to', 1),
#  (u'or hated', 1),
#  (u'other authorities', 1),
#  (u'only legitimate', 1),
#  (u'no room', 1),
#  (u'and authorizing', 1),
#  (u'now deliver', 1),
#  (u'keep down', 1),
#  (u'the defect', 1),
#  (u'abundant the', 1),
#  (u'misunderstanding the', 1),
#  (u'such removal', 1),
#  (u'them i', 1),
#  (u'language to', 1),
#  (u'liberty itself', 1),
#  (u'however repugnant', 1),
#  (u'in contradistinction', 1),
#  (u'the just', 1),
#  (u'be a', 1),
#  (u'errors had', 1),
#  (u'principle certainly', 1),
#  (u'faction--a spirit', 1),
#  (u'exclusively under', 1),
#  (u'containing this', 1),
#  (u'nation i', 1),
#  (u'constitution may', 1),
#  (u'not yet', 1),
#  (u'who under', 1),
#  (u'tendencies as', 1),
#  (u'parties in', 1),
#  (u'relations the', 1),
#  (u'of designing', 1),
#  (u'case here', 1),
#  (u'the demagogue', 1),
#  (u'to him', 1),
#  (u'or spirit', 1),
#  (u'equal to', 1),
#  (u'between free', 1),
#  (u'deprivation is', 1),
#  (u'the mutual', 1),
#  (u'attempt to', 1),
#  (u'attention from', 1),
#  (u'engagements into', 1),
#  (u'is my', 1),
#  (u'extensive and', 1),
#  (u'difference all', 1),
#  (u'fears of', 1),
#  (u'are told', 1),
#  (u'foregoing remarks', 1),
#  (u'necessary sacrifices', 1),
#  (u'observer our', 1),
#  (u'under varied', 1),
#  (u'of propriety', 1),
#  (u'similar character', 1),
#  (u'and wants', 1),
#  (u'state and', 1),
#  (u'fails to', 1),
#  (u'will i', 1),
#  (u'trust that', 1),
#  (u'they knew', 1),
#  (u'once takes', 1),
#  (u'possible would', 1),
#  (u'seldom carrying', 1),
#  (u'a common', 1),
#  (u'however largely', 1),
#  (u'preserved by', 1),
#  (u'its victim', 1),
#  (u'boasted privilege', 1),
#  (u'positive benefits', 1),
#  (u'operated upon', 1),
#  (u'their defective', 1),
#  (u'absence of', 1),
#  (u'in common', 1),
#  (u'enactment should', 1),
#  (u'himself a', 1),
#  (u'common government', 1),
#  (u'acknowledged to', 1),
#  (u'of difficulty', 1),
#  (u'the scipios', 1),
#  (u'its influence', 1),
#  (u'and religion', 1),
#  (u'only upon', 1),
#  (u'make but', 1),
#  (u'only first', 1),
#  (u'institutions it', 1),
#  (u'entire remedy', 1),
#  (u'institutions if', 1),
#  (u'has produced', 1),
#  (u'upon all', 1),
#  (u'to give', 1),
#  (u'the pretense', 1),
#  (u'this difference', 1),
#  (u'the lesser', 1),
#  (u'provisions of', 1),
#  (u'false from', 1),
#  (u'forces upon', 1),
#  (u'people respected', 1),
#  (u'adoption or', 1),
#  (u'have strictly', 1),
#  (u'the never-failing', 1),
#  (u'the instances', 1),
#  (u'than a', 1),
#  (u'judiciary and', 1),
#  (u'who promised', 1),
#  (u'trifling importance', 1),
#  (u'all future', 1),
#  (u'administration of', 1),
#  (u'elective governments', 1),
#  (u'states solely', 1),
#  (u'sphere will', 1),
#  (u'partiality has', 1),
#  (u'it shall', 1),
#  (u'to serve', 1),
#  (u'formed no', 1),
#  (u'that are', 1),
#  (u'against a', 1),
#  (u'thousand years', 1),
#  (u'used to', 1),
#  (u'treasure also', 1),
#  (u'more of', 1),
#  (u'investigation will', 1),
#  (u'agent not', 1),
#  (u'and attempts', 1),
#  (u'foreign powers', 1),
#  (u'influence in', 1),
#  (u'consequences will', 1),
#  (u'influence it', 1),
#  (u'respective parties', 1),
#  (u'offices of', 1),
#  (u'in gaul', 1),
#  (u'cherished if', 1),
#  (u'their peculiar', 1),
#  (u'the negative', 1),
#  (u'in such', 1),
#  (u'majority had', 1),
#  (u'sound morals', 1),
#  (u'yield long', 1),
#  (u'glory in', 1),
#  (u'civilized man', 1),
#  (u'a devoted', 1),
#  (u'judiciary is', 1),
#  (u'independence they', 1),
#  (u'the enactment', 1),
#  (u'governments nor', 1),
#  (u'instance where', 1),
#  (u'increase of', 1),
#  (u'resources of', 1),
#  (u'very cause', 1),
#  (u'other scheme', 1),
#  (u'congress might', 1),
#  (u'that acts', 1),
#  (u'person but', 1),
#  (u'unalienable rights', 1),
#  (u'be corrected', 1),
#  (u'coeval with', 1),
#  (u'if the', 1),
#  (u'tolerated but', 1),
#  (u'the annals', 1),
#  (u'discord and', 1),
#  (u'system presents', 1),
#  (u'fears the', 1),
#  (u'government has', 1),
#  (u'balm for', 1),
#  (u'alarmed at', 1),
#  (u'similar reasons', 1),
#  (u'or continue', 1),
#  (u'of but', 1),
#  (u'leading principle', 1),
#  (u'the two', 1),
#  (u'no very', 1),
#  (u'in conceiving', 1),
#  (u'to repeat', 1),
#  (u'authority and', 1),
#  (u"men's opinions", 1),
#  (u'objects for', 1),
#  (u'additional force', 1),
#  (u'the act', 1),
#  (u'not satisfy', 1),
#  (u'upon none', 1),
#  (u'fellow-citizens by', 1),
#  (u'allusion to', 1),
#  (u'means it', 1),
#  (u'condition by', 1),
#  (u'agree in', 1),
#  (u'granted or', 1),
#  (u'means in', 1),
#  (u'accept a', 1),
#  (u'has declared', 1),
#  (u'a moment', 1),
#  (u'given of', 1),
#  (u'only against', 1),
#  (u'course that', 1),
#  (u'authorizing him', 1),
#  (u'our souls', 1),
#  (u'of sufferings', 1),
#  (u'permitted them', 1),
#  (u'that state', 1),
#  (u'without any', 1),
#  (u'reckless as', 1),
#  (u'and freedom', 1),
#  (u'the declining', 1),
#  (u'the immediate', 1),
#  (u'countrymen never', 1),
#  (u'tendencies of', 1),
#  (u'expense but', 1),
#  (u'of constitutional', 1),
#  (u'wisdom for', 1),
#  (u'nation are', 1),
#  (u'see the', 1),
#  (u'advice and', 1),
#  (u'harmony so', 1),
#  (u'their performance', 1),
#  (u'infancy to', 1),
#  (u'whom introduced--a', 1),
#  (u'employment of', 1),
#  (u'may well', 1),
#  (u'has created', 1),
#  (u'other states', 1),
#  (u'weaker feeling', 1),
#  (u'is on', 1),
#  (u'confederacy and', 1),
#  (u'heightened as', 1),
#  (u'their financial', 1),
#  (u'produce that', 1),
#  (u'the fears', 1),
#  (u'to monarchy', 1),
#  (u'celebrated republic', 1),
#  (u'public treasure', 1),
#  (u'than another', 1),
#  (u'thus used', 1),
#  (u'them we', 1),
#  (u'intrusted the', 1),
#  (u'every tendency', 1),
#  (u'which that', 1),
#  (u'and we', 1),
#  (u'for unhallowed', 1),
#  (u'under their', 1),
#  (u'columbia can', 1),
#  (u'far the', 1),
#  (u'neither has', 1),
#  (u'from those', 1),
#  (u'granted still', 1),
#  (u'decision of', 1),
#  (u'something to', 1),
#  (u'of perfect', 1),
#  (u'proud democrat', 1),
#  (u'upon any', 1),
#  (u'constitution should', 1),
#  (u'will prove', 1),
#  (u'currency some', 1),
#  (u'course prescribed', 1),
#  (u'remark that', 1),
#  (u'approaches to', 1),
#  (u'attachment to', 1),
#  (u'enactment there', 1),
#  (u'could better', 1),
#  (u'require and', 1),
#  (u'on their', 1),
#  (u'other bearing', 1),
#  (u'forbidding their', 1),
#  (u'be warped', 1),
#  (u'countries that', 1),
#  (u'and anthony', 1),
#  (u'take an', 1),
#  (u'drawing a', 1),
#  (u'effect to', 1),
#  (u'partial and', 1),
#  (u'each individual', 1),
#  (u'liberty it', 1),
#  (u'devoted persevering', 1),
#  (u'members composing', 1),
#  (u'and neck', 1),
#  (u'magistrate to', 1),
#  (u'in perfect', 1),
#  (u'object for', 1),
#  (u'they would', 1),
#  (u'same effects', 1),
#  (u'made in', 1),
#  (u'time governed', 1),
#  (u'judiciary forms', 1),
#  (u'the alternative', 1),
#  (u'whom they', 1),
#  (u'good and', 1),
#  (u'has become', 1),
#  (u'most indigent', 1),
#  (u'expressing to', 1),
#  (u'has there', 1),
#  (u'one no', 1),
#  (u'spoils and', 1),
#  (u'within are', 1),
#  (u'the devoted', 1),
#  (u'arisen as', 1),
#  (u'exert in', 1),
#  (u'may regret', 1),
#  (u'distributer of', 1),
#  (u'such is', 1),
#  (u'franchise through', 1),
#  (u'its ordinary', 1),
#  (u'legislative by', 1),
#  (u'desired object', 1),
#  (u'the pledges', 1),
#  (u'sanctions to', 1),
#  (u'speculative statesmen', 1),
#  (u'and mode', 1),
#  (u'safety within', 1),
#  (u'until an', 1),
#  (u'reasons the', 1),
#  (u'modern europe', 1),
#  (u'countrymen has', 1),
#  (u'lines mischievous', 1),
#  (u'immunity in', 1),
#  (u'meaning nothing', 1),
#  (u'withheld the', 1),
#  (u'made that', 1),
#  (u'motive but', 1),
#  (u'behooves the', 1),
#  (u'place to', 1),
#  (u'which appeared', 1),
#  (u'greatest good', 1),
#  (u'limited sovereignty', 1),
#  (u'made accessible', 1),
#  (u'devoted attachment', 1),
#  (u'most stupid', 1),
#  (u'just sense', 1),
#  (u'observed i', 1),
#  (u'republics can', 1),
#  (u'destined to', 1),
#  (u'our declaration', 1),
#  (u'legislature from', 1),
#  (u'agents and', 1),
#  (u'the never-dying', 1),
#  (u'refer to', 1),
#  (u'prevent his', 1),
#  (u'of products', 1),
#  (u'her allies', 1),
#  (u'is final', 1),
#  (u'so awful', 1),
#  (u'any claim', 1),
#  (u'drawn as', 1),
#  (u'their interference', 1),
#  (u'determined never', 1),
#  (u'the necessary', 1),
#  (u'dominant passion', 1),
#  (u'which separate', 1),
#  (u'partaking in', 1),
#  (u'terms and', 1),
#  (u'apply the', 1),
#  (u'feelings which', 1),
#  (u'even the', 1),
#  (u'other i', 1),
#  (u'which we', 1),
#  (u'and enabled', 1),
#  (u'applied it', 1),
#  (u'sternest republicans', 1),
#  (u'manner as', 1),
#  (u'their partiality', 1),
#  (u'parent of', 1),
#  (u'the central', 1),
#  (u'people compensated', 1),
#  (u'greatly inferior', 1),
#  (u'some indications', 1),
#  (u'has gone', 1),
#  (u'constitute a', 1),
#  (u'same forbearance', 1),
#  (u'it certainly', 1),
#  (u'and its', 1),
#  (u'or keep', 1),
#  (u'the opposition--by', 1),
#  (u'bonds of', 1),
#  (u'mr madison', 1),
#  (u'given my', 1),
#  (u'that golden', 1),
#  (u'to this', 1),
#  (u'realize the', 1),
#  (u'the days', 1),
#  (u'had probably', 1),
#  (u'much favor', 1),
#  (u'important since', 1),
#  (u'long exist', 1),
#  (u'states would', 1),
#  (u'intimate a', 1),
#  (u'us by', 1),
#  (u'emperor in', 1),
#  (u'influences might', 1),
#  (u'up the', 1),
#  (u'none yet', 1),
#  (u'decision there', 1),
#  (u'most solemn', 1),
#  (u'wilds of', 1),
#  (u'words of', 1),
#  (u'only where', 1),
#  (u'character confers', 1),
#  (u'powers with', 1),
#  (u'giving their', 1),
#  (u'are destined', 1),
#  (u'republican patriot', 1),
#  (u'impose upon', 1),
#  (u'patriot from', 1),
#  (u'of violated', 1),
#  (u'is at', 1),
#  (u'transactions with', 1),
#  (u'and prudent', 1),
#  (u'separating powers', 1),
#  (u'ascertain whether', 1),
#  (u'existing in', 1),
#  (u'often found', 1),
#  (u'honor against', 1),
#  (u'be sacrificed', 1),
#  (u'liberator there', 1),
#  (u'rights possessed', 1),
#  (u'character which', 1),
#  (u'nor the', 1),
#  (u'governing a', 1),
#  (u'division of', 1),
#  (u'intimate union', 1),
#  (u'is therefore', 1),
#  (u'error and', 1),
#  (u'it secured', 1),
#  (u'nor by', 1),
#  (u'examples of', 1),
#  (u'influence how', 1),
#  (u'power necessary', 1),
#  (u'consent now', 1),
#  (u'employments of', 1),
#  (u'alone not', 1),
#  (u'fifty years', 1),
#  (u'persons at', 1),
#  (u'their commissions', 1),
#  (u'into penury', 1),
#  (u'idea that', 1),
#  (u'before and', 1),
#  (u'department which', 1),
#  (u'the temple', 1),
#  (u'patriotism to', 1),
#  (u'interests the', 1),
#  (u'commander in', 1),
#  (u'after fifty', 1),
#  (u'existing revenue', 1),
#  (u'respective orbits', 1),
#  (u'climate and', 1),
#  (u'our intercourse', 1),
#  (u'eligibility of', 1),
#  (u'illustrious predecessors', 1),
#  (u'there can', 1),
#  (u'the congress', 1),
#  (u'superintendent and', 1),
#  (u'to contain', 1),
#  (u'under which', 1),
#  (u'people depend', 1),
#  (u'fiction of', 1),
#  (u'which violate', 1),
#  (u'completely under', 1),
#  (u'their affections', 1),
#  (u'states may', 1),
#  (u'deceive and', 1),
#  (u'is termed', 1),
#  (u'adopt or', 1),
#  (u'beneficent creator', 1),
#  (u'has exalted', 1),
#  (u'conceive to', 1),
#  (u'my ability', 1),
#  (u'exercising this', 1),
#  (u'introduced in', 1),
#  (u'to intrust', 1),
#  (u'interrupted content', 1),
#  (u'such bills', 1),
#  (u'to use', 1),
#  (u'conferring the', 1),
#  (u'arrest the', 1),
#  (u'did not', 1),
#  (u'times of', 1),
#  (u'administration not', 1),
#  (u'country and', 1),
#  (u'legislature i', 1),
#  (u'citizen and', 1),
#  (u'six presidents--and', 1),
#  (u'my proposed', 1),
#  (u'principle of', 1),
#  (u'it depends', 1),
#  (u'species of', 1),
#  (u'without an', 1),
#  (u'one individual', 1),
#  (u'of parliament', 1),
#  (u'considered most', 1),
#  (u'it approaches', 1),
#  (u'to cast', 1),
#  (u'so emphatically', 1),
#  (u'his country', 1),
#  (u'could neither', 1),
#  (u'to attempt', 1),
#  (u'clause giving', 1),
#  (u'have left', 1),
#  (u'an assurance', 1),
#  (u'the mind', 1),
#  (u'of religious', 1),
#  (u'one case', 1),
#  (u'which can', 1),
#  (u'given him', 1),
#  (u'citizen he', 1),
#  (u'states the', 1),
#  (u'aristocracy the', 1),
#  (u'appropriate orbits', 1),
#  (u'of alleged', 1),
#  (u'and maturing', 1),
#  (u'forbearance for', 1),
#  (u'the independence', 1),
#  (u'to see', 1),
#  (u'assembly who', 1),
#  (u'i consent', 1),
#  (u'conceive that', 1),
#  (u'whose coming', 1),
#  (u'thought of', 1),
#  (u'the foregoing', 1),
#  (u'and duty', 1),
#  (u'any single', 1),
#  (u'the purely', 1),
#  (u'them therefore', 1),
#  (u'prescribed to', 1),
#  (u'the dictator', 1),
#  (u'his objections', 1),
#  (u'as settled', 1),
#  (u'no aid', 1),
#  (u'employs whilst', 1),
#  (u'aggression for', 1),
#  (u'if any', 1),
#  (u'of making', 1),
#  (u'pretense of', 1),
#  (u'this glorious', 1),
#  (u'principles to', 1),
#  (u'liberty without', 1),
#  (u'people that', 1),
#  (u'have anticipated', 1),
#  (u'periods like', 1),
#  (u'people than', 1),
#  (u'provide some', 1),
#  (u'state legislatures', 1),
#  (u'that asked', 1),
#  (u'provincial ruler', 1),
#  (u'the halls', 1),
#  (u'head and', 1),
#  (u'neck toleration', 1),
#  (u'as however', 1),
#  (u'amongst a', 1),
#  (u'every instance', 1),
#  (u'has never', 1),
#  (u'senate under', 1),
#  (u'is intangible', 1),
#  (u'that by', 1),
#  (u'are deprived', 1),
#  (u'not sometimes', 1),
#  (u'mine that', 1),
#  (u'their being', 1),
#  (u'systems of', 1),
#  (u'committed by', 1),
#  (u'office to', 1),
#  (u'the liberal', 1),
#  (u'new ones', 1),
#  (u'the officers', 1),
#  (u'one was', 1),
#  (u'best safeguards', 1),
#  (u'to betray', 1),
#  (u'power precisely', 1),
#  (u'government no', 1),
#  (u'begun will', 1),
#  (u'performance with', 1),
#  (u'the execution', 1),
#  (u'prosperity unpleasant', 1),
#  (u'institutions our', 1),
#  (u'administered and', 1),
#  (u'our fathers', 1),
#  (u'republicans by', 1),
#  (u'resemble the', 1),
#  (u'controlled by', 1),
#  (u'the sources', 1),
#  (u'interests which', 1),
#  (u'declared it', 1),
#  (u'are most', 1),
#  (u'this subject', 1),
#  (u'deprivation of', 1),
#  (u'the minority', 1),
#  (u'more than', 1),
#  (u'the magnitude', 1),
#  (u'sides of', 1),
#  (u'branch there', 1),
#  (u'its own', 1),
#  (u'wish for', 1),
#  (u'accountable agent', 1),
#  (u'deem the', 1),
#  (u'christs whose', 1),
#  (u'it if', 1),
#  (u'of high', 1),
#  (u'confidence and', 1),
#  (u'conformable with', 1),
#  (u'system like', 1),
#  (u'nation can', 1),
#  (u'latter case', 1),
#  (u'latter is', 1),
#  (u'process attended', 1),
#  (u'is its', 1),
#  (u'our actual', 1),
#  (u'attended with', 1),
#  (u'passion by', 1),
#  (u'own immediate', 1),
#  (u'the form', 1),
#  (u'allow to', 1),
#  (u'assent so', 1),
#  (u'argument acquires', 1),
#  (u'hand as', 1),
#  (u'part effected', 1),
#  (u'questions forces', 1),
#  (u'others lay', 1),
#  (u'in consummating', 1),
#  (u'enlightened character', 1),
#  (u'our foreign', 1),
#  (u'population of', 1),
#  (u'glorious union', 1),
#  (u'commonwealth had', 1),
#  (u'and safe', 1),
#  (u'most warmly', 1),
#  (u'destroy or', 1),
#  (u'the guardianship', 1),
#  (u'men can', 1),
#  (u'before you', 1),
#  (u'deliberate opinions', 1),
#  (u'be more', 1),
#  (u'sufferings secure', 1),
#  (u'such examples', 1),
#  (u'distinguished continue', 1),
#  (u'and every', 1),
#  (u'it behooves', 1),
#  (u'any one', 1),
#  (u'man fashioned', 1),
#  (u'necessarily resulted', 1),
#  (u'the head', 1),
#  (u'only to', 1),
#  (u'objects it', 1),
#  (u'over its', 1),
#  (u'the triple', 1),
#  (u'from no', 1),
#  (u'time were', 1),
#  (u'century has', 1),
#  (u'different is', 1),
#  (u'never has', 1),
#  (u'spirit a', 1),
#  (u'to administer', 1),
#  (u'credit for', 1),
#  (u'assembled countrymen', 1),
#  (u'a duty', 1),
#  (u'make him', 1),
#  (u'more sublime', 1),
#  (u'so important', 1),
#  (u'ensue which', 1),
#  (u'duty and', 1),
#  (u'power granted', 1),
#  (u'old trick', 1),
#  (u'triple tie', 1),
#  (u'a supposed', 1),
#  (u'points of', 1),
#  (u'is mainly', 1),
#  (u'be strictly', 1),
#  (u'ones has', 1),
#  (u'absorbed by', 1),
#  (u'apply all', 1),
#  (u'own principles', 1),
#  (u'nothing beyond', 1),
#  (u'unpatriotic motive', 1),
#  (u'was not', 1),
#  (u'they looked', 1),
#  (u'to insure', 1),
#  (u'greater sacrifices', 1),
#  (u'in two', 1),
#  (u'compact with', 1),
#  (u'or modify', 1),
#  (u'we shall', 1),
#  (u'for all', 1),
#  (u'states who', 1),
#  (u'freedom and', 1),
#  (u'and bound', 1),
#  (u'harbingers of', 1),
#  (u'which compose', 1),
#  (u'their liberties', 1),
#  (u'its views', 1),
#  (u'manhood for', 1),
#  (u'him it', 1),
#  (u'flattered with', 1),
#  (u'opinion may', 1),
#  (u'after obtaining', 1),
#  (u'interference with', 1),
#  (u'acted in', 1),
#  (u'relations are', 1),
#  (u'free operations', 1),
#  (u'legislature upon', 1),
#  (u'was afforded', 1),
#  (u"country's liberator", 1),
#  (u'find a', 1),
#  (u'parties to', 1),
#  (u'be permitted', 1),
#  (u'amongst men', 1),
#  (u'the friendly', 1),
#  (u'own discretion', 1),
#  (u'body constituted', 1),
#  (u'public virtue', 1),
#  (u'constant nurture', 1),
#  (u'inexpedient or', 1),
#  (u'she has', 1),
#  (u'present to', 1),
#  (u'fair exhibit', 1),
#  (u'governments with', 1),
#  (u'those essentially', 1),
#  (u'contrast was', 1),
#  (u'would console', 1),
#  (u'the employments', 1),
#  (u'union at', 1),
#  (u'this i', 1),
#  (u'subject the', 1),
#  (u'the tendencies', 1),
#  (u'rules prescribed', 1),
#  (u'disregarded or', 1),
#  (u'magistrate unworthy', 1),
#  (u'to shout', 1),
#  (u'executive interference', 1),
#  (u'own relief', 1),
#  (u'consent shall', 1),
#  (u'object more', 1),
#  (u'injury which', 1),
#  (u'to decay', 1),
#  (u'always justly', 1),
#  (u'for annual', 1),
#  (u'remaining to', 1),
#  (u'protection in', 1),
#  (u'much mischief', 1),
#  (u'these qualities', 1),
#  (u'improved in', 1),
#  (u'high place', 1),
#  (u'proper however', 1),
#  (u'departments will', 1),
#  (u'an intolerant', 1),
#  (u'this district', 1),
#  (u'portion great', 1),
#  (u'of protector', 1),
#  (u'and restore', 1),
#  (u'evils of', 1),
#  (u'great principle', 1),
#  (u'of representatives', 1),
#  (u'indigent fellow-citizens', 1),
#  (u'much less', 1),
#  (u'two bodies', 1),
#  (u'not permit', 1),
#  (u'doubt the', 1),
#  (u'however well', 1),
#  (u'rigid adherence', 1),
#  (u'people if', 1),
#  (u'one nation', 1),
#  (u'people it', 1),
#  (u'source and', 1),
#  (u'an affectionate', 1),
#  (u'as its', 1),
#  (u'in harmony', 1),
#  (u'statesmen that', 1),
#  (u'in modern', 1),
#  (u'which flow', 1),
#  (u'been that', 1),
#  (u'the sages', 1),
#  (u'forgetting that', 1),
#  (u'i know', 1),
#  (u'individual to', 1),
#  (u'similar instances', 1),
# ...
#  (u'rest i', 1),
#  (u'may receive', 1),
#  (u'will without', 1),
#  (u'citizen--the grant', 1),
#  (u'fair construction', 1),
#  (u'the sovereigns', 1),
#  (u'hasty legislation', 1),
#  (u'quarter whence', 1),
#  (u'measures which', 1),
#  (u'the maxim', 1),
#  (u'be not', 1),
#  (u'looks to', 1),
#  (u'strictly proper', 1),
#  (u'legacies which', 1),
#  (u'power on', 1),
#  (u'liberty although', 1),
#  (u'liberty from', 1),
#  (u'contended and', 1),
#  (u'fraught with', 1),
#  (u'govern we', 1),
#  (u'magnanimous and', 1),
#  (u'every year', 1),
#  (u'name of', 1),
#  (u'warfare may', 1),
#  (u'bitterness alienation', 1),
#  (u'of language', 1),
#  (u'tendency to', 1),
#  (u'lasting happiness', 1),
#  (u'this argument', 1),
#  (u'of independence', 1),
#  (u'are founded', 1),
#  (u'claim or', 1),
#  (u'defined by', 1),
#  (u'that created', 1),
#  (u'man had', 1),
#  (u'long will', 1),
#  (u'pledge i', 1),
#  (u'liberal feelings', 1),
#  (u'of england', 1),
#  (u'good being', 1),
#  (u'those feelings', 1),
#  (u'early saw', 1),
#  (u'the time', 1),
#  (u'the antagonist', 1),
#  (u'devising schemes', 1),
#  (u'of arresting', 1),
#  (u'privileges which', 1),
#  (u'the beautiful', 1),
#  (u'are necessary', 1),
#  (u'promises made', 1),
#  (u'exhibit a', 1),
#  (u'body i', 1),
#  (u'the forum', 1),
#  (u'principles governing', 1),
#  (u'stone upon', 1),
#  (u'that republics', 1),
#  (u'matter of', 1),
#  (u'no relation', 1),
#  (u'revolution the', 1),
#  (u'be your', 1),
#  (u'anything in', 1),
#  (u'is left', 1),
#  (u'of all--or', 1),
#  (u'gloriously contended', 1),
#  (u'force from', 1),
#  (u'treats of', 1),
#  (u'be ascribed', 1),
#  (u'every section', 1),
#  (u'breath can', 1),
#  (u'if bills', 1),
#  (u'prejudices our', 1),
#  (u'in particular', 1),
#  (u'hands there', 1),
#  (u'representatives who', 1),
#  (u'no jarring', 1),
#  (u'president and', 1),
#  (u'me i', 1),
#  (u'state unite', 1),
#  (u'that there', 1),
#  (u'party for', 1),
#  (u'how short', 1),
#  (u'insatiable it', 1),
#  (u'of caesar', 1),
#  (u'arrangement and', 1),
#  (u'theory those', 1),
#  (u'as are', 1),
#  (u'whom necessity', 1),
#  (u'given by', 1),
#  (u'a reference', 1),
#  (u'local interests', 1),
#  (u'rights alone', 1),
#  (u'authors it', 1),
#  (u'warning the', 1),
#  (u'are much', 1),
#  (u'the bounds', 1),
#  (u'the harmony', 1),
#  (u'emphatically insisted', 1),
#  (u'if that', 1),
#  (u'thorough examination', 1),
#  (u'was formed', 1),
#  (u'with that', 1),
#  (u'create or', 1),
#  (u'an officer', 1),
#  (u'i deem', 1),
#  (u'broad foundation', 1),
#  (u'our best', 1),
#  (u'latter also', 1),
#  (u'cheerfully to', 1),
#  (u'subject them', 1),
#  (u'sententious manner', 1),
#  (u'states have', 1),
#  (u'what it', 1),
#  (u'one department', 1),
#  (u'to and', 1),
#  (u'is complained', 1),
#  (u'for immutable', 1),
#  (u'impossible to', 1),
#  (u'no appearance', 1),
#  (u'but a', 1),
#  (u'but harmony', 1),
#  (u'his thoughts', 1),
#  (u'judiciary can', 1),
#  (u'the armies', 1),
#  (u'and with', 1),
#  (u'asia would', 1),
#  (u'organized associations', 1),
#  (u'alienation discord', 1),
#  (u'violence and', 1),
#  (u'disposal the', 1),
#  (u'his assembled', 1),
#  (u'sagacious mind', 1),
#  (u'understandings of', 1),
#  (u'secure tranquillity', 1),
#  (u'their agents', 1),
#  (u'never to', 1),
#  (u'judicial branches', 1),
#  (u'or injurious', 1),
#  (u'liability for', 1),
#  (u'people something', 1),
#  (u'religion as', 1),
#  (u'warmly disputed', 1),
#  (u'is for', 1),
#  (u'grants are', 1),
#  (u'much greater', 1),
#  (u'scarcely be', 1),
#  (u'single tyrant', 1),
#  (u'those scarcely', 1),
#  (u'countrymen who', 1),
#  (u'constitution have', 1),
#  (u'a weaker', 1),
#  (u'free governments', 1),
#  (u'expectations of', 1),
#  (u'condition when', 1),
#  (u'giving that', 1),
#  (u'holds his', 1),
#  (u'justice has', 1),
#  (u'authorities have', 1),
#  (u'never come', 1),
#  (u'despotism if', 1),
#  (u'under its', 1),
#  (u'and common', 1),
#  (u'blessings with', 1),
#  (u'exist without', 1),
#  (u'despotism is', 1),
#  (u'to yield', 1),
#  (u'delusion under', 1),
#  (u'any admission', 1),
#  (u'present purpose', 1),
#  (u'limit the', 1),
#  (u'its advocates', 1),
#  (u'good to', 1),
#  (u'in no', 1),
#  (u'however may', 1),
#  (u'early in', 1),
#  (u'attempts have', 1),
#  (u'to disfigure', 1),
#  (u'liberality and', 1),
#  (u'and activity', 1),
#  (u'citizens being', 1),
#  (u'so extensively', 1),
#  (u'found powerful', 1),
#  (u'and has', 1),
#  (u'different members', 1),
#  (u'station according', 1),
#  (u'violation of', 1),
#  (u'instrument which', 1),
#  (u'all our', 1),
#  (u'sincerity with', 1),
#  (u'they move', 1),
#  (u'intolerant and', 1),
#  (u'justify me', 1),
#  (u'if concentrated', 1),
#  (u'any or', 1),
#  (u'country so', 1),
#  (u'peace with', 1),
#  (u'concerned the', 1),
#  (u'govern is', 1),
#  (u'no greater', 1),
#  (u'changed this', 1),
#  (u'public opinion', 1),
#  (u'thought could', 1),
#  (u'might require', 1),
#  (u'itself particularly', 1),
#  (u'means which', 1),
#  (u'to discharge', 1),
#  (u'of freemen', 1),
#  (u'only result', 1),
#  (u'guilty or', 1),
#  (u'as they', 1),
#  (u'in expressing', 1),
#  (u'the statues', 1),
#  (u'principles upon', 1),
#  (u'to remove', 1),
#  (u'to disparage', 1),
#  (u'said indeed', 1),
#  (u'influence given', 1),
#  (u'saw and', 1),
#  (u'were in', 1),
#  (u'were it', 1),
#  (u'for talent', 1),
#  (u'you on', 1),
#  (u'bills and', 1),
#  (u'the specified', 1),
#  (u'so for', 1),
#  (u'thus separated', 1),
#  (u'sanction of', 1),
#  (u'of gold', 1),
#  (u'tolerant and', 1),
#  (u'were alarmed', 1),
#  (u'causes and', 1),
#  (u'disfigure our', 1),
#  (u'indeed offer', 1),
#  (u'to become', 1),
#  (u'article in', 1),
#  (u'nation tarnished', 1),
#  (u'radically changed', 1),
#  (u'the propriety', 1),
#  (u'supporting the', 1),
#  (u'when this', 1),
#  (u'for similar', 1),
#  (u'same persons', 1),
#  (u'never-dying worm', 1),
#  (u'their deliberate', 1),
#  (u'certain rights', 1),
#  (u'removal the', 1),
#  (u'denied by', 1),
#  (u'by writing', 1),
#  (u'to protect', 1),
#  (u'between all', 1),
#  (u'although the', 1),
#  (u'politician dissipated', 1),
#  (u'architects have', 1),
#  (u'any confidence', 1),
#  (u'striking contrast', 1),
#  (u'the presses', 1),
#  (u'so long', 1),
#  (u'confederacy more', 1),
#  (u'temple of', 1),
#  (u'are abundant', 1),
#  (u'tendency has', 1),
#  (u'such extensive', 1),
#  (u'departments this', 1),
#  (u'family and', 1),
#  (u'whereas in', 1),
#  (u'us we', 1),
#  (u'confers and', 1),
#  (u'their persons', 1),
#  (u'be quite', 1),
#  (u'our most', 1),
#  (u'but of', 1),
#  (u'removable only', 1),
#  (u'are compensated', 1),
#  (u'warped and', 1),
#  (u'and oppression', 1),
#  (u'corrupting nothing', 1),
#  (u'being changed', 1),
#  (u'parliament a', 1),
#  (u'experience the', 1),
#  (u'i give', 1),
#  (u'it--with the', 1),
#  (u'rests being', 1),
#  (u'distinguished english', 1),
#  (u'to despotism', 1),
#  (u'national compact', 1),
#  (u'associations of', 1),
#  (u'the ruin', 1),
#  (u'enough has', 1),
#  (u'no support', 1),
#  (u'no expense', 1),
#  (u'watchful of', 1),
#  (u'to union', 1),
#  (u'fathers and', 1),
#  (u'actually granted', 1),
#  (u'compose one', 1),
#  (u'confidence upon', 1),
#  (u'of free', 1),
#  (u'sovereign is', 1),
#  (u'every injury', 1),
#  (u'of feeling', 1),
#  (u'others of', 1),
#  (u'of combinations', 1),
#  (u'checked the', 1),
#  (u'rich are', 1),
#  (u'extensively complained', 1),
#  (u'property of', 1),
#  (u'england spoke', 1),
#  (u'jealous of', 1),
#  (u'share in', 1),
#  (u'enterprise are', 1),
#  (u'fabric of', 1),
#  (u'or classed', 1),
#  (u'democracy the', 1),
#  (u'circumstances in', 1),
#  (u'unusual professions', 1),
#  (u'produce such', 1),
#  (u'magistrates or', 1),
#  (u'profound reverence', 1),
#  (u'with a', 1),
#  (u'government not', 1),
#  (u'promised that', 1),
#  (u'of usury', 1),
#  (u'a thought', 1),
#  (u'anyone who', 1),
#  (u'the way', 1),
#  (u'the war', 1),
#  (u'removed it', 1),
#  (u'speaking unrestrained', 1),
#  (u'and submit', 1),
#  (u'duty upon', 1),
#  (u'a monarchical', 1),
#  (u'the engagements', 1),
#  (u'of freedom', 1),
#  (u'grant but', 1),
#  (u'as those', 1),
#  (u'takes possession', 1),
#  (u'their management', 1),
#  (u'withheld from', 1),
#  (u'that tendency', 1),
#  (u'men blinded', 1),
#  (u'fatal consequences', 1),
#  (u'tendency if', 1),
#  (u'the partial', 1),
#  (u'anticipated from', 1),
#  (u'motives which', 1),
#  (u'an early', 1),
#  (u'shadow only', 1),
#  (u'even by', 1),
#  (u'opinions have', 1),
#  (u'its authors', 1),
#  (u'for some', 1),
#  (u'public revenues', 1),
#  (u'restore former', 1),
#  (u'can conceive', 1),
#  (u'worst apprehensions', 1),
#  (u'them notwithstanding', 1),
#  (u'every means', 1),
#  (u'governments arises', 1),
#  (u'found one', 1),
#  (u'proper efforts', 1),
#  (u'intrusted power', 1),
#  (u'have acted', 1),
#  (u'but encouraged', 1),
#  (u'changed by', 1),
#  (u'constitution can', 1),
#  (u'immutable history', 1),
#  (u'with entire', 1),
#  (u'expected however', 1),
#  (u'of unalienable', 1),
#  (u'spirit contracted', 1),
#  (u'it does', 1),
#  (u'that however', 1),
#  (u'vigilance sufficient', 1),
#  (u'could then', 1),
#  (u'subject is', 1),
#  (u'that species', 1),
#  (u'accomplish all', 1),
#  (u'his fellow-man', 1),
#  (u'not think', 1),
#  (u'public finances', 1),
#  (u'appeared not', 1),
#  (u'administration become', 1),
#  (u'party assuming', 1),
#  (u'roman emperor', 1),
#  (u'that can', 1),
#  (u'expectations i', 1),
#  (u'violence of', 1),
#  (u'union produced', 1),
#  (u'observable as', 1),
#  (u'things so', 1),
#  (u'your homes', 1),
#  (u'deeply we', 1),
#  (u'case can', 1),
#  (u'greece to', 1),
#  (u'religious freedom', 1),
#  (u'is with', 1),
#  (u'safety from', 1),
#  (u'sovereignty possessed', 1),
#  (u'certain harbingers', 1),
#  (u'had sought', 1),
#  (u'great diversity', 1),
#  (u'which all', 1),
#  (u'authorities be', 1),
#  (u'appears perfectly', 1),
#  (u'these grants', 1),
#  (u'powerful as', 1),
#  (u'that is', 1),
#  (u'iron bonds', 1),
#  (u'advocates have', 1),
#  (u'government was', 1),
#  (u'provision so', 1),
#  (u'made us', 1),
#  (u'the american', 1),
#  (u'president the', 1),
#  (u'so powerful', 1),
#  (u'toleration of', 1),
#  (u'think proper', 1),
#  (u'confiding fraternal', 1),
#  (u'republic that', 1),
#  (u'become me', 1),
#  (u'affairs i', 1),
#  (u'leave no', 1),
#  (u'history and', 1),
#  (u'in domestic', 1),
#  (u'well informed', 1),
#  (u'devoted exterior', 1),
#  (u'object i', 1),
#  (u'community of', 1),
#  (u'predecessors when', 1),
#  (u'the beneficent', 1),
#  (u'republicans of', 1),
#  (u'but it', 1),
#  (u'ever be', 1),
#  (u'constitutions are', 1),
#  (u'local authorities', 1),
#  (u'how much', 1),
#  (u'indication that', 1),
#  (u'a discrepancy', 1),
#  (u'not see', 1),
#  (u'in war', 1),
#  (u'departure from', 1),
#  (u'or increase', 1),
#  (u'constitution or', 1),
#  (u'recommending it', 1),
#  (u'two separate', 1),
#  (u'entirely extinguished', 1),
#  (u'several cantons', 1),
#  (u'compare our', 1),
#  (u'the fiat', 1),
#  (u'veto was', 1),
#  (u'latter condition', 1),
#  (u'may claim', 1),
#  (u'the reign', 1),
#  (u'powers no', 1),
#  (u'the construction', 1),
#  (u'no division', 1),
#  (u'has elapsed', 1),
#  (u'discharge all', 1),
#  (u'least have', 1),
#  (u'business and', 1),
#  (u'mine the', 1),
#  (u'will and', 1),
#  (u'may indeed', 1),
#  (u'i see', 1),
#  (u'people seldom', 1),
#  (u'the parent', 1),
#  (u'shackles by', 1),
#  (u'forms no', 1),
#  (u'the quarter', 1),
#  (u'political career', 1),
#  (u'particularly of', 1),
#  (u'affording to', 1),
#  (u'injustice and', 1),
#  (u'be exposed', 1),
#  (u'and dispassionate', 1),
#  (u'currency the', 1),
#  (u'a usurpation', 1),
#  (u'other person', 1),
#  (u'open warfare', 1),
#  (u'in feelings', 1),
#  (u'hitherto protected', 1),
#  (u'the progress', 1),
#  (u'to revenue', 1),
#  (u'suggestions of', 1),
#  (u'the eligibility', 1),
#  (u'the mistaken', 1),
#  (u'deeper into', 1),
#  (u'be one', 1),
#  (u'declining years', 1),
#  (u'votes for', 1),
#  (u'an armed', 1),
#  (u'the command', 1),
#  (u'extinguished or', 1),
#  (u'it leads', 1),
#  (u'and decay', 1),
#  (u'our republican', 1),
#  (u'largely partaking', 1),
#  (u'camp--that their', 1),
#  (u'so marked', 1),
#  (u'and cheerfully', 1),
#  (u'purposes compose', 1),
#  (u'representatives with', 1),
#  (u'maxims and', 1),
#  (u'unwillingness of', 1),
#  (u'be supposed', 1),
#  (u'and sectional', 1),
#  (u'carrying out', 1),
#  (u'own sphere', 1),
#  (u'it finds', 1),
#  (u'monarchy and', 1),
#  (u'years since', 1),
#  (u'religion and', 1),
#  (u'relief on', 1),
#  (u'heretofore confided', 1),
#  (u'daily adding', 1),
#  (u'at once', 1),
#  (u'for generosity', 1),
#  (u'assembled in', 1),
#  (u'senate continued', 1),
#  (u'stand either', 1),
#  (u'arresting at', 1),
#  (u'the errors', 1),
#  (u'as is', 1),
#  (u'principles which', 1),
#  (u'exchanged for', 1),
#  (u'these objects', 1),
#  (u'to bind', 1),
#  (u'govern me', 1),
#  (u'a vestige', 1),
#  (u'power given', 1),
#  (u'acting under', 1),
#  (u'preserve the', 1),
#  (u'and most', 1),
#  (u'grant by', 1),
#  (u'of half', 1),
#  (u'and lamented', 1),
#  (u'independence secured', 1),
#  (u'presidents--and two', 1),
#  (u'the day', 1),
#  (u'mine it', 1),
#  (u'the words', 1),
#  (u'have prepared', 1),
#  (u'it agreeably', 1),
#  (u'as that', 1),
#  (u'union between', 1),
#  (u'thorough conviction', 1),
#  (u'and interests', 1),
#  (u'the demand', 1),
#  (u'of faction--a', 1),
#  (u'constituted should', 1),
#  (u'high degree', 1),
#  (u'sentence of', 1),
#  (u'left to', 1),
#  (u'where american', 1),
#  (u'sinking deeper', 1),
#  (u'system without', 1),
#  (u'collisions may', 1),
#  (u'great difficulty', 1),
#  (u'may observe', 1),
#  (u'parties at', 1),
#  (u'watched over', 1),
#  (u'legislation could', 1),
#  (u'scheming politician', 1),
#  (u'might become', 1),
#  (u'but free', 1),
#  (u'also it', 1),
#  (u'matter in', 1),
#  (u'supposed violation', 1),
#  (u'fulfill their', 1),
#  (u'powers any', 1),
#  (u'of upward', 1),
#  (u'jarring they', 1),
#  (u'a conservative', 1),
#  (u'and nobleness', 1),
#  (u'they did', 1),
#  (u'ruler whilst', 1),
#  (u'instruments for', 1),
#  (u'enjoyed much', 1),
#  (u'as meaning', 1),
#  (u'a camp--that', 1),
#  (u'believe to', 1),
#  (u'will soon', 1),
#  (u'hitherto preserved', 1),
#  (u'our countrymen', 1),
#  (u'increase and', 1),
#  (u'great political', 1),
#  (u'mitigated if', 1),
#  (u'and even', 1),
#  (u'his species', 1),
#  (u'to state', 1),
#  (u'the long', 1),
#  (u'beautiful remark', 1),
#  (u'results can', 1),
#  (u'own constant', 1),
#  (u'their countrymen', 1),
#  (u'their direction', 1),
#  (u'the expectations', 1),
#  (u'adding to', 1),
#  (u'the press', 1),
#  (u'but after', 1),
#  (u'actual condition', 1),
#  (u'knowing the', 1),
#  (u'him a', 1),
#  (u'we admit', 1),
#  (u'and scrupulous', 1),
#  (u'agreeably to', 1),
#  (u'but have', 1),
#  (u'ascertaining the', 1),
#  (u'those i', 1),
#  (u'called from', 1),
#  (u'may sometimes', 1),
#  (u'a member', 1),
#  (u'power with', 1),
#  (u'will ensue', 1),
#  (u'propriety it', 1),
#  (u'family are', 1),
#  (u'the arrangement', 1),
#  (u'only be', 1),
#  (u'only by', 1),
#  (u'short as', 1),
#  (u'safe-keeping and', 1),
#  (u'of duty', 1),
#  (u'operation of', 1),
#  (u'the worst', 1),
#  (u'it continues', 1),
#  (u'between these', 1),
#  (u'would seem', 1),
#  (u'more elements', 1),
#  (u'countrymen were', 1),
#  (u'are raised', 1),
#  (u'causes inherent', 1),
#  (u'and perpetuate', 1),
#  (u'they become', 1),
#  (u'become dangerous', 1),
#  (u'opposition of', 1),
#  (u'more corrupting', 1),
#  (u'addition to', 1),
#  (u'from such', 1),
#  (u'laws are', 1),
#  (u'species and', 1),
#  (u'regret anything', 1),
#  (u'forum not', 1),
#  (u'pass upon', 1),
#  (u'i apprehend', 1),
#  (u'first to', 1),
#  (u'so distinctly', 1),
#  (u'others however', 1),
#  (u'friend of', 1),
#  (u'obliges them', 1),
#  (u'their decline', 1),
#  (u'been found', 1),
#  (u'susceptible of', 1),
#  (u'and however', 1),
#  (u'continue any', 1),
#  (u'members to', 1),
#  (u'of aristocracy', 1),
#  (u'by making', 1),
#  (u'revenue laws', 1),
#  (u'amount as', 1),
#  (u'appears strange', 1),
#  (u'are produced', 1),
#  (u'and vigor', 1),
#  (u'occasion sufficiently', 1),
#  (u'this duty', 1),
#  (u"country's rights", 1),
#  (u'jurisdictions the', 1),
#  (u'the amendatory', 1),
#  (u'and solemn', 1),
#  (u'have ultimately', 1),
#  (u'of pending', 1),
#  (u'members but', 1),
#  (u'came from', 1),
#  (u'has the', 1),
#  (u'without communicating', 1),
#  (u'occurred between', 1),
#  (u'the opposition', 1),
#  (u'laws suggested', 1),
#  (u'it many', 1),
#  (u'his observations', 1),
#  (u'president a', 1),
#  (u'the free', 1),
#  (u'use which', 1),
#  (u'an alleged', 1),
#  (u'great danger', 1),
#  (u'prove effectual', 1),
#  (u'refusing to', 1),
#  (u'lay claim', 1),
#  (u'a calm', 1),
#  (u'condition after', 1),
#  (u'afforded by', 1),
#  (u'tarnished by', 1),
#  (u'relied as', 1),
#  (u'justly regard', 1),
#  (u'prepared it', 1),
#  (u'intrigues of', 1),
#  (u'my exalted', 1),
#  (u'more influence', 1),
#  (u'there any', 1),
#  (u'advanced of', 1),
#  (u'egypt and', 1)]

# %% [markdown]
# ## 3.1 Getting rid of unwanted words like 'the' using the BYU corpus ##

# %%
# import sys
# reload(sys)
# sys.setdefaultencoding("utf-8")

# -*- coding: utf-8 -*-
from __future__ import unicode_literals

from urllib2 import urlopen
from bs4 import BeautifulSoup
import re
import string
import codecs
import operator


# BYU corpus of common words
def isCommon(ngram):
    commonWords = ["the", "be", "and", "of", "a", "in", "to", "have", "it", "i", "that", "for", "you", "he", 
                   "with", "on", "do", "say", "this", "they", "is", "an", "at", "but","we", "his", "from", 
                   "that", "not", "by", "she", "or", "as", "what", "go", "their","can", "who", "get", "if", 
                   "would", "her", "all", "my", "make", "about", "know", "will","as", "up", "one", "time", "has", 
                   "been", "there", "year", "so", "think", "when", "which", "them", "some", "me", "people", 
                   "take", "out", "into", "just", "see", "him", "your", "come", "could", "now", "than", "like", 
                   "other", "how", "then", "its", "our", "two", "more", "these", "want", "way", "look", "first", 
                   "also", "new", "because", "day", "more", "use", "no", "man", "find", "here", "thing", "give", 
                   "many", "well"]
    for word in ngram:
        if word in commonWords:
            return True
    return False

# Remove newlines, double spaces, citation marks
def cleanText(input):
    input = re.sub('\n+', " ", input).lower()
    input = re.sub('\[[0-9]*\]', "", input)
    input = re.sub(' +', " ", input)
    input = re.sub("u\.s\.", "us", input)
    input = input.encode('utf-8')
#     input = input.decode('ascii')
    input = input.decode("ascii", "ignore")
    return input

# Remove punctuation and single character words
def cleanInput(input):
    input = cleanText(input)
    cleanInput = []
    input = input.split(' ')
    for item in input:
        item = item.strip(string.punctuation)
        if len(item) > 1 or (item.lower() == 'a' or item.lower() == 'i'):
            cleanInput.append(item)
    return cleanInput

def getNgrams(input, n):
    input = cleanInput(input)
    output = {}
    for i in range(len(input)-n+1):
        ngramTemp = " ".join(input[i:i+n])
        if ngramTemp not in output:
            output[ngramTemp] = 0
        output[ngramTemp] += 1
    return output

def getFirstSentenceContaining(ngram, content):
    #print(ngram)
    sentences = content.split(".")
    for sentence in sentences: 
        if ngram in sentence:
            return sentence
    return ""

content = str(urlopen("http://pythonscraping.com/files/space.txt").read())
# content = codecs.decode(content.encode("UTF-8"))
ngrams = getNgrams(content, 2)
sortedNGrams = sorted(ngrams.items(), 
                      key = operator.itemgetter(1), 
                      reverse = True)
print(sortedNGrams)
